# %%
"""
Error Code:
    0: Error opening file
"""

import pandas as pd
import numpy as np
import zipfile

# Clarify the mission N number for this .ipynb
N_number = 3

# %%
def namestr(obj, namespace):
    return [name for name in namespace if namespace[name] is obj]

def display(items):
    print(namestr(items, globals()))
    for item in items:
        print("     {0}".format(item))

# Test display
test_dict = {"A": [1, 2, 3], "B": [4, 5, 6]}
display(test_dict)
# Out:
# ['test_dict']
#      B
#      A

# %%
from os import listdir
from os.path import isfile, join

mypath = "./"
zip_file_name = "receipt-id-773931-part-001"
zip_file = zipfile.ZipFile(mypath + zip_file_name + ".zip")
file_name_list = zip_file.namelist()
# Should return 4 folders if testing on ASG Zip
print("{0} files detected under current directory. ".format(len(file_name_list)))
# Out:
# 53528 files detected under current directory.

# %%
def filter_by_filename(files_list):
    """Function filtering files by filenames.
    Only accepts files starts with "journal-article"
    """
    filtered_list = []
    mask_match = "ngram" + str(N_number) + "/journal-article"
    for filename in files_list:
        # Check if the filename starts with "journal-article"
        assert isinstance(filename, str)
        # Check the first 20 characters of the file name
        if filename.startswith(mask_match, 0, len(mask_match)):
            filtered_list.append(filename)
    return filtered_list

# Run "filter_by_filename" for current directory
filtered_list = filter_by_filename(file_name_list)
print("{0} files remained after filename filtering. ".format(len(filtered_list)))
# Out:
# 13382 files remained after filename filtering.

# %%
# Functions checking word attributes (single-letter, starts/ends with numebr)
def is_single_letter(word):
    assert isinstance(word, str)
    return len(word) <= 1

def starts_with_number(word):
    assert isinstance(word, str)
    try:
        return word[0].isdigit()
    except:
        return False

def ends_with_number(word):
    assert isinstance(word, str)
    try:
        return word[len(word) - 1].isdigit()
    except:
        return False

# Summary of check functions
check_funcs = [
#     is_single_letter, # Only applies for 1-gram
    starts_with_number, 
    ends_with_number,
]

# Summary of checking mechanisms
def check_words(words):
    for word in words:
        check_result = [check_func(word) for check_func in check_funcs]
        if any(check_result):
            return True
    return False

# %%
""" TEST
- Try implementing algorithms on single file
"""
file_0 = filtered_list[0]
try:
    journal_0 = zip_file.open(file_0, mode="r")
except IOError:
    print("Error opening file {0}".format(file_0))
    exit(0)
    
# Track the meaningful dictonaries
freq_list = []

# Read file line by line
for line in journal_0: 
    line = line.decode("ascii")
    
    # line -> "teachers who taught 5"
    assert isinstance(line, str)
    
    # pair -> "["teachers", "who", "taught", "5"]
    pair = line.strip().split() #
    
    assert len(pair) == 4
    
    # Separate word/freq
    words, freq = pair[:-1], pair[-1]
    
    assert len(words) == 3
    assert freq.isdigit()
    
    # Filter by word's attribute
    if check_words(words):
        continue
    freq_list.append([words, freq])

journal_0.close()
display(freq_list)
# Out:
# ['freq_list']
#      [['planning', 'information', 'systems'], '11']
#      [['low', 'risk', 'omission'], '8']
#      [['p', 'i', 'p'], '8']
#      [['design', 'planning', 'information'], '6']
#      [['management', 'review', 'october'], '6']
#      [['creativity', 'low', 'risk'], '5']
#      [['i', 'p', 'i'], '5']
#      [['p', 'r', 'p'], '5']
#      [['r', 'p', 'r'], '5']
#      [['simple', 'complex', 'environments'], '5']
#      [['i', 'i', 'i'], '4']
#      [['i', 'r', 'p'], '4']
#      [['p', 'i', 'i'], '4']
#      [['person', 'centered', 'information'], '4']
#      [['preferred', 'information', 'sets'], '4']
#      [['risk', 'omis', 'sion'], '4']
#      [['simple', 'environ', 'ments'], '4']
#      [['van', 'de', 'ven'], '4']
#      [['complex', 'envi', 'ronments'], '3']
#      [['each', 'stage', 'planning'], '3']
#      [['form', 'p', 'i'], '3']
#      [['higher', 'order', 'terms'], '3']
#      [['information', 'generated', 'when'], '3']
#      [['information', 'system', 'design'], '3']
#      [['management', 'information', 'systems'], '3']
#      [['management', 'science', 'vol'], '3']
#      [['nonperson', 'centered', 'information'], '3']
#      [['ohio', 'state', 'university'], '3']
#      [['p', 'r', 'r'], '3']
#      [['person', 'centered', 'modes'], '3']
#      [['planning', 'problem', 's'], '3']
#      [['planning', 'simple', 'complex'], '3']
#      [['preferred', 'information', 'set'], '3']
#      [['r', 'p', 'i'], '3']
#      [['r', 'r', 'p'], '3']
#      [['american', 'psychologist', 'vol'], '2']
#      [['cen', 'tered', 'information'], '2']
#      [['centered', 'infor', 'mation'], '2']
#      [['centered', 'information', 'modes'], '2']
#      [['centered', 'information', 'systems'], '2']
#      [['centered', 'modes', 'information'], '2']
#      [['com', 'plexity', 'complex'], '2']
#      [['complex', 'environ', 'ments'], '2']
#      [['complex', 'environments', 'information'], '2']
#      [['complex', 'environments', 'makes'], '2']
#      [['complex', 'environments', 'planner'], '2']
#      [['complex', 'planning', 'problems'], '2']
#      [['conceptualization', 'detailing', 'evaluation'], '2']
#      [['cost', 'effec', 'tive'], '2']
#      [['de', 'ven', 'delbecq'], '2']
#      [['define', 'planning', 'problems'], '2']
#      [['delbecq', 'van', 'de'], '2']
#      [['detailing', 'evaluation', 'implementation'], '2']
#      [['environ', 'ment', 'can'], '2']
#      [['faculty', 'management', 'sciences'], '2']
#      [['have', 'low', 'risk'], '2']
#      [['i', 'i', 'participation'], '2']
#      [['i', 'p', 'information'], '2']
#      [['i', 'th', 'planner'], '2']
#      [['infor', 'mation', 'sets'], '2']
#      [['infor', 'mation', 'should'], '2']
#      [['informa', 'tion', 'generation'], '2']
#      [['information', 'genera', 'tion'], '2']
#      [['information', 'modes', 'environmental'], '2']
#      [['information', 'sets', 'have'], '2']
#      [['information', 'sets', 'include'], '2']
#      [['information', 'system', 'attributes'], '2']
#      [['information', 'systems', 'complex'], '2']
#      [['input', 'output', 'analysis'], '2']
#      [['john', 'c', 'henderson'], '2']
#      [['low', 'cost', 'complex'], '2']
#      [['low', 'risk', 'omis'], '2']
#      [['management', 'review', 'vol'], '2']
#      [['models', 'should', 'used'], '2']
#      [['new', 'york', 'basic'], '2']
#      [['new', 'york', 'mcgraw'], '2']
#      [['new', 'york', 'russell'], '2']
#      [['non', 'person', 'centered'], '2']
#      [['nonperson', 'cen', 'tered'], '2']
#      [['nonperson', 'centered', 'modes'], '2']
#      [['nutt', 'p', 'c'], '2']
#      [['organization', 's', 'products'], '2']
#      [['p', 'i', 'r'], '2']
#      [['p', 'p', 'r'], '2']
#      [['paul', 'c', 'nutt'], '2']
#      [['person', 'centered', 'infor'], '2']
#      [['person', 'centered', 'systems'], '2']
#      [['ph', 'd', 'university'], '2']
#      [['pi', 'i', 'j'], '2']
#      [['plan', 'complex', 'environ'], '2']
#      [['plan', 'ning', 'stages'], '2']
#      [['planning', 'methods', 'can'], '2']
#      [['planning', 'methods', 'like'], '2']
#      [['planning', 'prob', 'lem'], '2']
#      [['planning', 'problems', 'have'], '2']
#      [['preferred', 'data', 'sets'], '2']
#      [['preferred', 'infor', 'mation'], '2']
#      [['r', 'i', 'r'], '2']
#      [['r', 'information', 'set'], '2']
#      [['reduce', 'risk', 'omission'], '2']
#      [['sci', 'ences', 'vol'], '2']
#      [['science', 'quarterly', 'vol'], '2']
#      [['sets', 'include', 'r'], '2']
#      [['simple', 'environments', 'planning'], '2']
#      [['stage', 'planning', 'process'], '2']
#      [['stage', 'simple', 'environments'], '2']
#      [['support', 'planning', 'process'], '2']
#      [['systems', 'complex', 'environments'], '2']
#      [['terms', 'can', 'interpreted'], '2']
#      [['york', 'basic', 'books'], '2']
#      [['york', 'mcgraw', 'hill'], '2']
#      [['york', 'russell', 'sage'], '2']
#      [['abilities', 'multi', 'attribute'], '1']
#      [['ability', 'system', 'produce'], '1']
#      [['about', 'company', 'found'], '1']
#      [['about', 'how', 'solve'], '1']
#      [['ac', 'counts', 'major'], '1']
#      [['ac', 'curate', 'less'], '1']
#      [['ac', 'tivities', 'like'], '1']
#      [['academy', 'management', 'review'], '1']
#      [['acceptance', 'con', 'sidered'], '1']
#      [['accountant', 'personnel', 'manager'], '1']
#      [['accounting', 'environmental', 'dif'], '1']
#      [['accounting', 'methods', 'applied'], '1']
#      [['accounting', 'other', 'reports'], '1']
#      [['accounting', 'reports', 'summarize'], '1']
#      [['accuracy', 'accurate', 'information'], '1']
#      [['accuracy', 'con', 'sistency'], '1']
#      [['accuracy', 'consis', 'tency'], '1']
#      [['accuracy', 'consistency', 'complex'], '1']
#      [['accuracy', 'etc', 'table'], '1']
#      [['accuracy', 'high', 'consistency'], '1']
#      [['accuracy', 'information', 'systems'], '1']
#      [['accuracy', 'low', 'risk'], '1']
#      [['accuracy', 'predictable', 'environments'], '1']
#      [['accuracy', 'well', 'timeliness'], '1']
#      [['accurate', 'con', 'sistent'], '1']
#      [['accurate', 'consis', 'tent'], '1']
#      [['accurate', 'consistent', 'timely'], '1']
#      [['accurate', 'his', 'torical'], '1']
#      [['accurate', 'inexpensive', 'can'], '1']
#      [['accurate', 'inexpensive', 'creativity'], '1']
#      [['accurate', 'information', 'sys'], '1']
#      [['accurate', 'information', 'tends'], '1']
#      [['accurately', 'described', 'person'], '1']
#      [['achieved', 'without', 'focusing'], '1']
#      [['ackoff', 'r', 'f'], '1']
#      [['acquisition', 'costs', 'can'], '1']
#      [['acquisition', 'right', 'left'], '1']
#      [['action', 'new', 'york'], '1']
#      [['action', 'programs', 'new'], '1']
#      [['action', 'tend', 'avoid'], '1']
#      [['activ', 'ities', 'examples'], '1']
#      [['activities', 'like', 'structure'], '1']
#      [['activity', 'described', 'i'], '1']
#      [['adaptation', 'partially', 'overlapping'], '1']
#      [['adapted', 'organizational', 'situation'], '1']
#      [['adapting', 'solutions', 'can'], '1']
#      [['address', 'high', 'pri'], '1']
#      [['adminis', 'strative', 'science'], '1']
#      [['adminis', 'trative', 'science'], '1']
#      [['administration', 'faculty', 'management'], '1']
#      [['administration', 're', 'search'], '1']
#      [['administration', 'review', 'july'], '1']
#      [['administrative', 'science', 'quarterly'], '1']
#      [['administrator', 'interro', 'gating'], '1']
#      [['administrator', 'public', 'administration'], '1']
#      [['administrators', 'framework', 'suggested'], '1']
#      [['administrators', 'often', 'visit'], '1']
#      [['admissions', 'application', 'three'], '1']
#      [['adoption', 'operations', 'research'], '1']
#      [['advises', 'client', 'buy'], '1']
#      [['advocates', 'may', 'differ'], '1']
#      [['affected', 'avoid', 'con'], '1']
#      [['against', 'criteria', 'firms'], '1']
#      [['age', 'ethnic', 'group'], '1']
#      [['agencies', 'have', 'both'], '1']
#      [['agent', 'complex', 'p'], '1']
#      [['agent', 'who', 'guides'], '1']
#      [['aggregate', 'combine', 'formation'], '1']
#      [['aggregate', 'infor', 'mation'], '1']
#      [['agreement', 'synthesis', 'partially'], '1']
#      [['aid', 'group', 'through'], '1']
#      [['aid', 'planner', 'decomposing'], '1']
#      [['aid', 'selection', 'targets'], '1']
#      [['aided', 'analysis', 'utilities'], '1']
#      [['aids', 'administrator', 'interro'], '1']
#      [['ail', 'pi', 'pi'], '1']
#      [['all', 'formation', 'sets'], '1']
#      [['all', 'stress', 'direct'], '1']
#      [['all', 'those', 'affected'], '1']
#      [['allows', 'planner', 'deal'], '1']
#      [['alone', 'chance', 'particular'], '1']
#      [['also', 'been', 'used'], '1']
#      [['also', 'can', 'used'], '1']
#      [['also', 'consider', 'attributes'], '1']
#      [['also', 'have', 'credibility'], '1']
#      [['also', 'provide', 'information'], '1']
#      [['also', 'use', 'approach'], '1']
#      [['also', 'used', 'prescribe'], '1']
#      [['alter', 'native', 'plan'], '1']
#      [['alternative', 'ar', 'rangements'], '1']
#      [['alternative', 'plan', 'solutions'], '1']
#      [['alters', 'objectives', 'social'], '1']
#      [['always', 'places', 'value'], '1']
#      [['ambiguity', 'com', 'plexity'], '1']
#      [['amenability', 'solution', 'known'], '1']
#      [['american', 'psy', 'chologists'], '1']
#      [['amibiguity', 'planning', 'problems'], '1']
#      [['among', 'alternative', 'plan'], '1']
#      [['among', 'experts', 'higher'], '1']
#      [['among', 'overlapping', 'experts'], '1']
#      [['amort', 'ized', 'information'], '1']
#      [['amortize', 'costs', 'automated'], '1']
#      [['amortized', 'deterministic', 'features'], '1']
#      [['amounts', 'ordered', 'remaining'], '1']
#      [['anal', 'ysis', 'features'], '1']
#      [['analy', 'sis', 'example'], '1']
#      [['analy', 'tic', 'information'], '1']
#      [['analy', 'zability', 'extent'], '1']
#      [['analysis', 'aided', 'analysis'], '1']
#      [['analysis', 'applied', 'particular'], '1']
#      [['analysis', 'conceptualize', 'innovative'], '1']
#      [['analysis', 'environmental', 'differences'], '1']
#      [['analysis', 'examples', 'mason'], '1']
#      [['analysis', 'features', 'linear'], '1']
#      [['analysis', 'involves', 'formal'], '1']
#      [['analysis', 'mode', 'allows'], '1']
#      [['analysis', 'model', 'shown'], '1']
#      [['analysis', 'preferred', 'information'], '1']
#      [['analysis', 'proposals', 'yielding'], '1']
#      [['analysis', 'reports', 'introspection'], '1']
#      [['analysis', 'sequence', 'data'], '1']
#      [['analysis', 'sequence', 'which'], '1']
#      [['analysis', 'sys', 'tems'], '1']
#      [['analysis', 'utilities', 'persuasion'], '1']
#      [['analyst', 'accountant', 'personnel'], '1']
#      [['analyst', 'consultant', 'common'], '1']
#      [['analytic', 'methods', 'used'], '1']
#      [['analytic', 'technique', 'e'], '1']
#      [['analytic', 'technique', 'i'], '1']
#      [['analytical', 'infor', 'mation'], '1']
#      [['analyzed', 'relative', 'potential'], '1']
#      [['ance', 'against', 'criteria'], '1']
#      [['angeles', 'center', 'information'], '1']
#      [['another', 'indi', 'vidual'], '1']
#      [['another', 'individual', 's'], '1']
#      [['application', 'classical', 'problem'], '1']
#      [['application', 'three', 'principles'], '1']
#      [['applied', 'behavioral', 'science'], '1']
#      [['applied', 'design', 'p'], '1']
#      [['applied', 'each', 'stage'], '1']
#      [['applied', 'imagination', 'new'], '1']
#      [['applied', 'particular', 'sequence'], '1']
#      [['applied', 'reports', 'planner'], '1']
#      [['apply', 'mathematical', 'models'], '1']
#      [['apply', 'planning', 'methods'], '1']
#      [['apply', 'them', 'consistently'], '1']
#      [['appro', 'priate', 'example'], '1']
#      [['appro', 'priate', 'information'], '1']
#      [['approach', 'new', 'york'], '1']
#      [['approach', 'p', 'we'], '1']
#      [['approach', 'strategic', 'plan'], '1']
#      [['appropriate', 'evaluation', 'complex'], '1']
#      [['appropriate', 'sym', 'bol'], '1']
#      [['ar', 'rangements', 'components'], '1']
#      [['areas', 'interactive', 'informa'], '1']
#      [['argues', 'task', 'environ'], '1']
#      [['article', 'relate', 'plan'], '1']
#      [['articulate', 'preferred', 'system'], '1']
#      [['artificial', 'cambridge', 'mass'], '1']
#      [['aspects', 'plan', 'grei'], '1']
#      [['aspects', 'plan', 'solution'], '1']
#      [['aspects', 'planning', 'problem'], '1']
#      [['assess', 'impor', 'tant'], '1']
#      [['assistant', 'professor', 'faculty'], '1']
#      [['associate', 'professor', 'graduate'], '1']
#      [['associated', 'formal', 'information'], '1']
#      [['associated', 'one', 'its'], '1']
#      [['assumed', 'information', 'can'], '1']
#      [['assumes', 'environment', 'can'], '1']
#      [['assumes', 'full', 'client'], '1']
#      [['ate', 'disability', 'mortality'], '1']
#      [['ativity', 'carefully', 'managed'], '1']
#      [['attempt', 'replace', 'them'], '1']
#      [['attri', 'butes', 'high'], '1']
#      [['attrib', 'utes', 'considered'], '1']
#      [['attrib', 'utes', 'known'], '1']
#      [['attribute', 'utilities', 'decision'], '1']
#      [['attributes', 'consistency', 'accuracy'], '1']
#      [['attributes', 'environment', 'relationship'], '1']
#      [['attributes', 'high', 'creativity'], '1']
#      [['attributes', 'information', 'can'], '1']
#      [['attributes', 'information', 'system'], '1']
#      [['attributes', 'less', 'important'], '1']
#      [['attributes', 'more', 'difficult'], '1']
#      [['attributes', 'preferred', 'information'], '1']
#      [['attributes', 'simple', 'complex'], '1']
#      [['attributes', 'thus', 'new'], '1']
#      [['attributes', 'timeliness', 'creativity'], '1']
#      [['audits', 'historical', 'models'], '1']
#      [['augmented', 'per', 'sonal'], '1']
#      [['aus', 'tin', 'assistant'], '1']
#      [['authority', 'has', 'been'], '1']
#      [['automated', 'data', 'systems'], '1']
#      [['automation', 'often', 'used'], '1']
#      [['automotive', 'supplier', 'very'], '1']
#      [['available', 'administrators', 'framework'], '1']
#      [['avoid', 'con', 'fusion'], '1']
#      [['avoid', 'reports', 'me'], '1']
#      [['b', 'management', 'information'], '1']
#      [['b', 'sketch', 'executive'], '1']
#      [['background', 'other', 'personal'], '1']
#      [['backoff', 'r', 'cahoon'], '1']
#      [['base', 'service', 'plan'], '1']
#      [['based', 'attributes', 'thus'], '1']
#      [['based', 'conclusions', 'drawn'], '1']
#      [['based', 'information', 'augmented'], '1']
#      [['based', 'past', 'experience'], '1']
#      [['based', 'sales', 'forecasts'], '1']
#      [['based', 'usage', 'sales'], '1']
#      [['bases', 'stress', 'timely'], '1']
#      [['basic', 'cate', 'gories'], '1']
#      [['basic', 'modes', 'may'], '1']
#      [['basis', 'evaluate', 'formal'], '1']
#      [['because', 'both', 'criteria'], '1']
#      [['because', 'components', 'relationships'], '1']
#      [['because', 'efficient', 'task'], '1']
#      [['because', 'environment', 'pre'], '1']
#      [['because', 'historical', 'mod'], '1']
#      [['because', 'planning', 'tasks'], '1']
#      [['because', 'precise', 'information'], '1']
#      [['because', 'range', 'sales'], '1']
#      [['becomes', 'objective', 'planning'], '1']
#      [['been', 'dele', 'gated'], '1']
#      [['been', 'found', 'overcome'], '1']
#      [['been', 'used', 'complex'], '1']
#      [['been', 'used', 'nutt'], '1']
#      [['before', 'can', 'fully'], '1']
#      [['behavior', 'comparative', 'administration'], '1']
#      [['behavior', 'glenview', 'iii'], '1']
#      [['behavior', 'hu', 'man'], '1']
#      [['behavior', 'necessary', 'implement'], '1']
#      [['behavioral', 'theory', 'firm'], '1']
#      [['believe', 'r', 'i'], '1']
#      [['believe', 'superior', 'planning'], '1']
#      [['below', 'while', 'set'], '1']
#      [['benefactors', 'regulations', 'het'], '1']
#      [['benefactors', 'when', 'organization'], '1']
#      [['better', 'structured', 'components'], '1']
#      [['between', 'environment', 'information'], '1']
#      [['between', 'environment', 'planning'], '1']
#      [['between', 'existing', 'state'], '1']
#      [['between', 'manager', 'analyst'], '1']
#      [['between', 'oc', 'currence'], '1']
#      [['between', 'planner', 'sponsor'], '1']
#      [['between', 'sponsor', 'planner'], '1']
#      [['between', 'two', 'more'], '1']
#      [['bias', 'may', 'timely'], '1']
#      [['ble', 'environments', 'lack'], '1']
#      [['ble', 'over', 'comparatively'], '1']
#      [['bol', 'f', 'u'], '1']
#      [['bono', 'e', 'new'], '1']
#      [['books', 'often', 'provide'], '1']
#      [['both', 'criteria', 'cause'], '1']
#      [['both', 'develop', 'ment'], '1']
#      [['both', 'shifting', 'budgets'], '1']
#      [['boundary', 'span', 'ning'], '1']
#      [['brainstorming', 'i', 'i'], '1']
#      [['brainstorming', 'p', 'ip'], '1']
#      [['brainwriting', 'cooptation', 'p'], '1']
#      [['brainwriting', 'p', 'r'], '1']
#      [['broken', 'manageable', 'pieces'], '1']
#      [['broker', 'advises', 'client'], '1']
#      [['budgets', 'shifting', 'mandates'], '1']
#      [['build', 'informal', 'historical'], '1']
#      [['builds', 'alternative', 'ar'], '1']
#      [['built', 'permit', 'planner'], '1']
#      [['built', 'through', 'application'], '1']
#      [['bureau', 'economic', 'business'], '1']
#      [['business', 'research', 'kent'], '1']
#      [['business', 'review', 'vol'], '1']
#      [['butes', 'high', 'consistency'], '1']
#      [['buy', 'particular', 'given'], '1']
#      [['c', 'experimental', 'comparison'], '1']
#      [['c', 'h', 'r'], '1']
#      [['c', 'henderson', 'paul'], '1']
#      [['c', 'henderson', 'ph'], '1']
#      [['c', 'models', 'decision'], '1']
#      [['c', 'nutt', 'ohio'], '1']
#      [['c', 'nutt', 'ph'], '1']
#      [['c', 'r', 'j'], '1']
#      [['c', 'r', 'r'], '1']
#      [['c', 'urban', 'institute'], '1']
#      [['c', 'w', 'design'], '1']
#      [['cahoon', 'w', 'j'], '1']
#      [['cal', 'form', 'transportation'], '1']
#      [['cal', 'precedent', 'so'], '1']
#      [['call', 'upon', 'another'], '1']
#      [['calls', 'change', 'agent'], '1']
#      [['cambridge', 'mass', 'mit'], '1']
#      [['camp', 'bell', 's'], '1']
#      [['campbell', 'd', 't'], '1']
#      [['can', 'achieved', 'without'], '1']
#      [['can', 'also', 'provide'], '1']
#      [['can', 'also', 'use'], '1']
#      [['can', 'also', 'used'], '1']
#      [['can', 'amort', 'ized'], '1']
#      [['can', 'amortized', 'deterministic'], '1']
#      [['can', 'applied', 'each'], '1']
#      [['can', 'apply', 'planning'], '1']
#      [['can', 'built', 'through'], '1']
#      [['can', 'conceptualized', 'broken'], '1']
#      [['can', 'conceptualized', 'using'], '1']
#      [['can', 'constructed', 'john'], '1']
#      [['can', 'constructed', 'which'], '1']
#      [['can', 'de', 'rived'], '1']
#      [['can', 'defined', 'its'], '1']
#      [['can', 'described', 'using'], '1']
#      [['can', 'fully', 'ex'], '1']
#      [['can', 'identified', 'support'], '1']
#      [['can', 'identify', 'decision'], '1']
#      [['can', 'improved', 'through'], '1']
#      [['can', 'interpreted', 'follows'], '1']
#      [['can', 'interpreted', 'similar'], '1']
#      [['can', 'justified', 'principally'], '1']
#      [['can', 'ob', 'tained'], '1']
#      [['can', 'obtained', 'stages'], '1']
#      [['can', 'operationalized', 'using'], '1']
#      [['can', 'provide', 'cost'], '1']
#      [['can', 'provide', 'formation'], '1']
#      [['can', 'provide', 'wealth'], '1']
#      [['can', 'provided', 'simulation'], '1']
#      [['can', 'quite', 'useful'], '1']
#      [['can', 'reasonably', 'consistent'], '1']
#      [['can', 'sub', 'stantially'], '1']
#      [['can', 'timely', 'accurate'], '1']
#      [['can', 'timely', 'may'], '1']
#      [['can', 'timely', 'tends'], '1']
#      [['can', 'understood', 'making'], '1']
#      [['can', 'use', 'data'], '1']
#      [['can', 'used', 'because'], '1']
#      [['can', 'used', 'define'], '1']
#      [['can', 'used', 'develop'], '1']
#      [['can', 'used', 'generate'], '1']
#      [['can', 'used', 'illustrate'], '1']
#      [['can', 'used', 'provide'], '1']
#      [['can', 'used', 're'], '1']
#      [['can', 'used', 'specify'], '1']
#      [['can', 'useful', 'complex'], '1']
#      [['can', 'yield', 'requisite'], '1']
#      [['careful', 'formulation', 'planning'], '1']
#      [['carefully', 'managed', 'can'], '1']
#      [['carefully', 'selected', 'ex'], '1']
#      [['case', 'study', 'graduate'], '1']
#      [['cate', 'gories', 'information'], '1']
#      [['cated', 'techniques', 'used'], '1']
#      [['categorizing', 'level', 'helps'], '1']
#      [['cause', 'effect', 'relations'], '1']
#      [['cedures', 'demand', 'factors'], '1']
#      [['ceived', 'value', 'planning'], '1']
#      [['center', 'advocates', 'may'], '1']
#      [['center', 'information', 'studies'], '1']
#      [['centered', 'costly', 'develop'], '1']
#      [['centered', 'data', 'stable'], '1']
#      [['centered', 'details', 'each'], '1']
#      [['centered', 'informa', 'tion'], '1']
#      [['centered', 'information', 'designs'], '1']
#      [['centered', 'information', 'instance'], '1']
#      [['centered', 'information', 'system'], '1']
#      [['centered', 'modes', 'exam'], '1']
#      [['centered', 'modes', 'r'], '1']
#      [['centered', 'person', 'centered'], '1']
#      [['centered', 'sources', 'should'], '1']
#      [['centered', 'systems', 'have'], '1']
#      [['centered', 'systems', 'like'], '1']
#      [['centered', 'systems', 'should'], '1']
#      [['centered', 'type', 'design'], '1']
#      [['centers', 'can', 'provide'], '1']
#      [['ceptualized', 'listing', 'components'], '1']
#      [['certain', 'resources', 'over'], '1']
#      [['certainty', 'under', 'risk'], '1']
#      [['cessful', 'past', 'experiences'], '1']
#      [['chance', 'particular', 'sales'], '1']
#      [['change', 'agent', 'complex'], '1']
#      [['change', 'agent', 'who'], '1']
#      [['change', 'development', 'homewood'], '1']
#      [['change', 'ganizatio', 'nal'], '1']
#      [['change', 'ganizational', 'change'], '1']
#      [['change', 'organization', 's'], '1']
#      [['change', 'read', 'ings'], '1']
#      [['change', 'strategy', 'applied'], '1']
#      [['change', 'well', 'reduce'], '1']
#      [['changes', 'complex', 'planning'], '1']
#      [['changes', 'from', 'non'], '1']
#      [['changes', 'performance', 'measures'], '1']
#      [['changes', 'plan', 'formulated'], '1']
#      [['changes', 'stimulated', 'planning'], '1']
#      [['changes', 'thus', 'tend'], '1']
#      [['changing', 'environment', 'requires'], '1']
#      [['chaos', 'new', 'york'], '1']
#      [['checks', 'agreement', 'synthesis'], '1']
#      [['checks', 'represent', 'information'], '1']
#      [['chicago', 'aldine', 'atherton'], '1']
#      [['churchman', 'c', 'w'], '1']
#      [['clasen', 'evaluation', 'education'], '1']
#      [['classi', 'cal', 'form'], '1']
#      [['classical', 'problem', 'representation'], '1']
#      [['clear', 'cut', 'solution'], '1']
#      [['client', 'buy', 'particular'], '1']
#      [['client', 'participation', 'en'], '1']
#      [['clinical', 'judgments', 'american'], '1']
#      [['closely', 'associated', 'one'], '1']
#      [['coerce', 'planner', 'work'], '1']
#      [['col', 'lect', 'store'], '1']
#      [['college', 'adminis', 'trative'], '1']
#      [['columbus', 'ohio', 'college'], '1']
#      [['columbus', 'ohio', 'received'], '1']
#      [['com', 'plexity', 'longer'], '1']
#      [['com', 'ponents', 'identify'], '1']
#      [['combine', 'formation', 'use'], '1']
#      [['commissions', 'often', 'formed'], '1']
#      [['common', 'example', 'formation'], '1']
#      [['communicating', 'employees', 'studies'], '1']
#      [['communication', 'systems', 'information'], '1']
#      [['company', 'found', 'nearly'], '1']
#      [['comparable', 'settings', 'offer'], '1']
#      [['comparative', 'administration', 're'], '1']
#      [['comparative', 'study', 'subjective'], '1']
#      [['comparatively', 'long', 'periods'], '1']
#      [['comparison', 'adaptation', 'partially'], '1']
#      [['comparison', 'effective', 'ness'], '1']
#      [['competitors', 'has', 'simple'], '1']
#      [['complex', 'among', 'overlapping'], '1']
#      [['complex', 'because', 'range'], '1']
#      [['complex', 'conditions', 'formulation'], '1']
#      [['complex', 'environ', 'ment'], '1']
#      [['complex', 'environment', 'information'], '1']
#      [['complex', 'environment', 'personal'], '1']
#      [['complex', 'environments', 'analytical'], '1']
#      [['complex', 'environments', 'because'], '1']
#      [['complex', 'environments', 'can'], '1']
#      [['complex', 'environments', 'complex'], '1']
#      [['complex', 'environments', 'evaluation'], '1']
#      [['complex', 'environments', 'have'], '1']
#      [['complex', 'environments', 'interactive'], '1']
#      [['complex', 'environments', 'planners'], '1']
#      [['complex', 'environments', 'planning'], '1']
#      [['complex', 'environments', 'purpose'], '1']
#      [['complex', 'environments', 'requires'], '1']
#      [['complex', 'environments', 'see'], '1']
#      [['complex', 'environments', 'stages'], '1']
#      [['complex', 'marketing', 'plans'], '1']
#      [['complex', 'p', 'p'], '1']
#      [['complex', 'plan', 'ning'], '1']
#      [['complex', 'planning', 'environments'], '1']
#      [['complex', 'planning', 'task'], '1']
#      [['complex', 'planning', 'tasks'], '1']
#      [['complex', 'simple', 'envi'], '1']
#      [['complex', 'simple', 'environments'], '1']
#      [['complexity', 'de', 'fined'], '1']
#      [['complexity', 'environmental', 'complexity'], '1']
#      [['complexity', 'example', 'consider'], '1']
#      [['complexity', 'informa', 'tion'], '1']
#      [['complexity', 'propositions', 'developed'], '1']
#      [['complexity', 'terms', 'planning'], '1']
#      [['complexity', 'used', 'illus'], '1']
#      [['complexity', 'when', 'personal'], '1']
#      [['component', 'defined', 'models'], '1']
#      [['components', 'builds', 'alternative'], '1']
#      [['components', 'morphol', 'ogy'], '1']
#      [['components', 'new', 'problem'], '1']
#      [['components', 'planning', 'methods'], '1']
#      [['components', 'relationships', 'merely'], '1']
#      [['components', 'two', 'basic'], '1']
#      [['comprehensive', 'flow', 'components'], '1']
#      [['computer', 'simulation', 'data'], '1']
#      [['computerized', 'reports', 'often'], '1']
#      [['con', 'ceptualized', 'listing'], '1']
#      [['con', 'fusion', 'insure'], '1']
#      [['con', 'sidered', 'implementation'], '1']
#      [['con', 'sistency', 'less'], '1']
#      [['con', 'sistent', 'have'], '1']
#      [['con', 'trol', 'vol'], '1']
#      [['concep', 'tual', 'foundations'], '1']
#      [['concept', 'stage', 'planning'], '1']
#      [['conceptualization', 'complex', 'environ'], '1']
#      [['conceptualization', 'planning', 'stages'], '1']
#      [['conceptualization', 'stage', 'complex'], '1']
#      [['conceptualization', 'stage', 'should'], '1']
#      [['conceptualize', 'innovative', 'comprehensive'], '1']
#      [['conceptualize', 'planning', 'problem'], '1']
#      [['conceptualized', 'broken', 'manageable'], '1']
#      [['conceptualized', 'using', 'classi'], '1']
#      [['conclusions', 'developing', 'large'], '1']
#      [['conclusions', 'drawn', 'simple'], '1']
#      [['concurrence', 'among', 'experts'], '1']
#      [['conditions', 'formulation', 'conceptualization'], '1']
#      [['conditions', 'repeated', 'trials'], '1']
#      [['conditions', 'semi', 'complexity'], '1']
#      [['conduct', 'planning', 'each'], '1']
#      [['consider', 'attributes', 'preferred'], '1']
#      [['consider', 'demands', 'organization'], '1']
#      [['consider', 'environment', 'has'], '1']
#      [['considered', 'design', 'information'], '1']
#      [['consis', 'tency', 'low'], '1']
#      [['consis', 'tent', 'than'], '1']
#      [['consistency', 'accuracy', 'low'], '1']
#      [['consistency', 'accuracy', 'well'], '1']
#      [['consistency', 'complex', 'environments'], '1']
#      [['consistency', 'consistent', 'information'], '1']
#      [['consistency', 'precision', 'evaluation'], '1']
#      [['consistency', 'represent', 'substan'], '1']
#      [['consistency', 'stems', 'from'], '1']
#      [['consistency', 'timeli', 'ness'], '1']
#      [['consistent', 'accurate', 'inexpensive'], '1']
#      [['consistent', 'accurate', 'information'], '1']
#      [['consistent', 'example', 'opinions'], '1']
#      [['consistent', 'information', 'systems'], '1']
#      [['consistent', 'than', 'nonperson'], '1']
#      [['consistent', 'timely', 'low'], '1']
#      [['constant', 'conditions', 'repeated'], '1']
#      [['constraints', 'placed', 'method'], '1']
#      [['constructed', 'john', 'c'], '1']
#      [['constructed', 'which', 'aggregate'], '1']
#      [['consultant', 'common', 'example'], '1']
#      [['consuming', 'strategies', 'described'], '1']
#      [['contact', 'plan', 'users'], '1']
#      [['contain', 'bias', 'may'], '1']
#      [['contains', 'information', 'which'], '1']
#      [['contends', 'unfreezing', 'needed'], '1']
#      [['contextual', 'variables', 'which'], '1']
#      [['contin', 'ue', 'seek'], '1']
#      [['contingencies', 'model', 'used'], '1']
#      [['contingent', 'model', 'work'], '1']
#      [['convenience', 'final', 'p'], '1']
#      [['cooptation', 'p', 'r'], '1']
#      [['cost', 'complex', 'environment'], '1']
#      [['cost', 'complex', 'environments'], '1']
#      [['cost', 'cost', 'incurred'], '1']
#      [['cost', 'creativity', 'diminishes'], '1']
#      [['cost', 'creativity', 'seldom'], '1']
#      [['cost', 'incurred', 'both'], '1']
#      [['cost', 'one', 'moves'], '1']
#      [['cost', 'settings', 'formation'], '1']
#      [['cost', 'through', 'person'], '1']
#      [['cost', 'timeliness', 'accuracy'], '1']
#      [['cost', 'using', 'model'], '1']
#      [['cost', 'variance', 'reports'], '1']
#      [['costly', 'develop', 'ment'], '1']
#      [['costs', 'automated', 'data'], '1']
#      [['costs', 'can', 'amort'], '1']
#      [['costs', 'can', 'amortized'], '1']
#      [['costs', 'costs', 'can'], '1']
#      [['costs', 'forecasting', 'sales'], '1']
#      [['costs', 'quality', 'becomes'], '1']
#      [['costs', 'up', 'quality'], '1']
#      [['could', 'adapted', 'organizational'], '1']
#      [['could', 'described', 'p'], '1']
#      [['could', 'treated', 'terms'], '1']
#      [['counts', 'major', 'portion'], '1']
#      [['cpm', 'input', 'output'], '1']
#      [['cre', 'ativity', 'carefully'], '1']
#      [['creativ', 'ity', 'low'], '1']
#      [['creative', 'accurate', 'his'], '1']
#      [['creative', 'consistent', 'example'], '1']
#      [['creativity', 'because', 'components'], '1']
#      [['creativity', 'cost', 'effec'], '1']
#      [['creativity', 'creativity', 'refers'], '1']
#      [['creativity', 'diminishes', 'risk'], '1']
#      [['creativity', 'individ', 'uals'], '1']
#      [['creativity', 'lacking', 'essential'], '1']
#      [['creativity', 'modest', 'cost'], '1']
#      [['creativity', 're', 'duce'], '1']
#      [['creativity', 'reduces', 'risk'], '1']
#      [['creativity', 'refers', 'ability'], '1']
#      [['creativity', 'reports', 'measure'], '1']
#      [['creativity', 'seldom', 'occurs'], '1']
#      [['creativity', 'simple', 'environments'], '1']
#      [['creativity', 'thus', 'nonperson'], '1']
#      [['credibility', 'nature', 'planning'], '1']
#      [['cretion', 'goals', 'change'], '1']
#      [['criteria', 'cause', 'effect'], '1']
#      [['criteria', 'evaluate', 'plan'], '1']
#      [['criteria', 'exception', 'checks'], '1']
#      [['criteria', 'firms', 'simple'], '1']
#      [['criteria', 'sketching', 'relationship'], '1']
#      [['criterion', 'checks', 'agreement'], '1']
#      [['criterion', 'decision', 'variable'], '1']
#      [['critical', 'path', 'method'], '1']
#      [['critically', 'important', 'informa'], '1']
#      [['cular', 'time', 'horizons'], '1']
#      [['curate', 'less', 'consistent'], '1']
#      [['cure', 'chaos', 'new'], '1']
#      [['currence', 'need', 'information'], '1']
#      [['current', 'ideal', 'states'], '1']
#      [['current', 'practices', 'delbecq'], '1']
#      [['cut', 'solution', 'procedures'], '1']
#      [['cyert', 'r', 'm'], '1']
#      [['d', 'c', 'urban'], '1']
#      [['d', 'h', 'gustafson'], '1']
#      [['d', 'organizations', 'action'], '1']
#      [['d', 'r', 'shukla'], '1']
#      [['d', 'raisinghani', 'theoret'], '1']
#      [['d', 't', 'systematic'], '1']
#      [['d', 'university', 'texas'], '1']
#      [['d', 'university', 'wiscon'], '1']
#      [['dalton', 'g', 'w'], '1']
#      [['danger', 'change', 'dalton'], '1']
#      [['data', 'acquisition', 'right'], '1']
#      [['data', 'bases', 'stress'], '1']
#      [['data', 'can', 'justified'], '1']
#      [['data', 'evaluation', 'analytic'], '1']
#      [['data', 'files', 'books'], '1']
#      [['data', 'have', 'per'], '1']
#      [['data', 'processing', 'activ'], '1']
#      [['data', 'reduction', 'routine'], '1']
#      [['data', 'sets', 'determined'], '1']
#      [['data', 'sets', 'each'], '1']
#      [['data', 'sets', 'information'], '1']
#      [['data', 'sets', 'judgments'], '1']
#      [['data', 'stable', 'environments'], '1']
#      [['data', 'system', 'interactive'], '1']
#      [['data', 'systems', 'aggregate'], '1']
#      [['data', 'systems', 'apply'], '1']
#      [['data', 'systems', 'can'], '1']
#      [['davis', 'g', 'b'], '1']
#      [['dawes', 'r', 'm'], '1']
#      [['de', 'bono', 'e'], '1']
#      [['de', 'fined', 'terms'], '1']
#      [['de', 'fined', 'thus'], '1']
#      [['de', 'rived', 'simple'], '1']
#      [['de', 'termine', 'expected'], '1']
#      [['de', 'ven', 'd'], '1']
#      [['de', 'ven', 'group'], '1']
#      [['deal', 'one', 'more'], '1']
#      [['deal', 'planning', 'problems'], '1']
#      [['dearden', 'j', 'mis'], '1']
#      [['deci', 'sion', 'makers'], '1']
#      [['deci', 'sion', 'systems'], '1']
#      [['decision', 'based', 'information'], '1']
#      [['decision', 'mak', 'ing'], '1']
#      [['decision', 'making', 'organiza'], '1']
#      [['decision', 'processed', 'adminis'], '1']
#      [['decision', 'rules', 'do'], '1']
#      [['decision', 'sci', 'ences'], '1']
#      [['decision', 'sciences', 'vol'], '1']
#      [['decision', 'social', 'change'], '1']
#      [['decision', 'style', 'its'], '1']
#      [['decision', 'variable', 'p'], '1']
#      [['decisions', 'henderson', 'mcdaniel'], '1']
#      [['decisions', 'under', 'un'], '1']
#      [['decomposing', 'planning', 'problems'], '1']
#      [['decree', 'can', 'also'], '1']
#      [['define', 'analy', 'zability'], '1']
#      [['define', 'existing', 'states'], '1']
#      [['define', 'needs', 'health'], '1']
#      [['define', 'planning', 'problem'], '1']
#      [['define', 'simple', 'complex'], '1']
#      [['defined', 'data', 'have'], '1']
#      [['defined', 'discrepancy', 'between'], '1']
#      [['defined', 'its', 'degree'], '1']
#      [['defined', 'its', 'mode'], '1']
#      [['defined', 'models', 'solu'], '1']
#      [['defined', 'plan', 'ning'], '1']
#      [['defined', 'planning', 'methods'], '1']
#      [['defined', 'problems', 'when'], '1']
#      [['defining', 'simple', 'complex'], '1']
#      [['definition', 'solution', 'check'], '1']
#      [['degree', 'homo', 'geneity'], '1']
#      [['degree', 'stability', 'fac'], '1']
#      [['delay', 'between', 'oc'], '1']
#      [['delbecq', 'et', 'al'], '1']
#      [['delbecq', 'g', 'wallester'], '1']
#      [['delbecq', 'task', 'contingent'], '1']
#      [['dele', 'gated', 'planner'], '1']
#      [['delegation', 'analysis', 'aided'], '1']
#      [['delegation', 'im', 'plementation'], '1']
#      [['delegation', 'strat', 'egy'], '1']
#      [['delimits', 'participation', 'specific'], '1']
#      [['delphi', 'groups', 'nominal'], '1']
#      [['delphi', 'groups', 'p'], '1']
#      [['delphi', 'p', 'r'], '1']
#      [['demand', 'factors', 'planner'], '1']
#      [['demands', 'organization', 's'], '1']
#      [['demands', 'planning', 'interactions'], '1']
#      [['demands', 'regression', 'mod'], '1']
#      [['demonstrates', 'deci', 'sion'], '1']
#      [['departures', 'from', 'past'], '1']
#      [['depending', 'upon', 'stage'], '1']
#      [['depicts', 'nature', 'ideal'], '1']
#      [['derived', 'from', 'synthesis'], '1']
#      [['describe', 'desirable', 'features'], '1']
#      [['describe', 'ideal', 'states'], '1']
#      [['describe', 'nodes', 'formed'], '1']
#      [['described', 'highly', 'complex'], '1']
#      [['described', 'i', 'could'], '1']
#      [['described', 'one', 'more'], '1']
#      [['described', 'p', 'i'], '1']
#      [['described', 'person', 'centered'], '1']
#      [['described', 'process', 'terms'], '1']
#      [['described', 'using', 'nonpersonal'], '1']
#      [['describes', 'generation', 'information'], '1']
#      [['describes', 'node', 'network'], '1']
#      [['describes', 'one', 'view'], '1']
#      [['describes', 'use', 'reports'], '1']
#      [['describing', 'its', 'components'], '1']
#      [['design', 'can', 'operationalized'], '1']
#      [['design', 'can', 'timely'], '1']
#      [['design', 'form', 'p'], '1']
#      [['design', 'georgetown', 'ontario'], '1']
#      [['design', 'has', 'been'], '1']
#      [['design', 'information', 'system'], '1']
#      [['design', 'inquiring', 'systems'], '1']
#      [['design', 'nonperson', 'centered'], '1']
#      [['design', 'p', 'i'], '1']
#      [['design', 'post', 'minnowbrook'], '1']
#      [['design', 'proposed', 'swanson'], '1']
#      [['design', 'r', 'information'], '1']
#      [['design', 'related', 'planning'], '1']
#      [['design', 'should', 'lead'], '1']
#      [['design', 'specified', 'environment'], '1']
#      [['designing', 'planning', 'information'], '1']
#      [['designing', 'viking', 'mars'], '1']
#      [['designs', 'can', 'identified'], '1']
#      [['designs', 'described', 'one'], '1']
#      [['designs', 'each', 'planning'], '1']
#      [['designs', 'far', 'more'], '1']
#      [['designs', 'often', 'form'], '1']
#      [['designs', 'planning', 'mis'], '1']
#      [['designs', 'required', 'complex'], '1']
#      [['desirable', 'features', 'prior'], '1']
#      [['desirable', 'information', 'sets'], '1']
#      [['detail', 'alter', 'native'], '1']
#      [['detail', 'example', 'personal'], '1']
#      [['detail', 'plan', 'complex'], '1']
#      [['detailing', 'evaluation', 'plan'], '1']
#      [['detailing', 'evaluation', 'planning'], '1']
#      [['detailing', 'evaluation', 'stages'], '1']
#      [['detailing', 'stage', 'variables'], '1']
#      [['details', 'each', 'information'], '1']
#      [['determinants', 'planning', 'problem'], '1']
#      [['determine', 'how', 'each'], '1']
#      [['determine', 'why', 'costs'], '1']
#      [['determined', 'information', 'modes'], '1']
#      [['deterministic', 'features', 'simple'], '1']
#      [['devel', 'oped', 'designs'], '1']
#      [['develop', 'ment', 'maintenance'], '1']
#      [['develop', 'ment', 'often'], '1']
#      [['develop', 'ment', 'time'], '1']
#      [['develop', 'plan', 'ning'], '1']
#      [['developed', 'illustrate', 'optimum'], '1']
#      [['developing', 'large', 'integrated'], '1']
#      [['development', 'homewood', 'iii'], '1']
#      [['development', 'new', 'york'], '1']
#      [['development', 'time', 'meas'], '1']
#      [['device', 'which', 'used'], '1']
#      [['devices', 'form', 'p'], '1']
#      [['devices', 'we', 'believe'], '1']
#      [['diagnostic', 'information', 'drawn'], '1']
#      [['dialectic', 'information', 'system'], '1']
#      [['dialectical', 'approach', 'strategic'], '1']
#      [['dictable', 'past', 'experience'], '1']
#      [['dictated', 'nature', 'project'], '1']
#      [['dif', 'ferences', 'instance'], '1']
#      [['differ', 'low', 'consistency'], '1']
#      [['differences', 'p', 'r'], '1']
#      [['difficult', 'amortize', 'costs'], '1']
#      [['difficult', 'ob', 'tain'], '1']
#      [['diminishes', 'creativity', 'because'], '1']
#      [['diminishes', 'risk', 'omis'], '1']
#      [['direct', 'systematic', 'contact'], '1']
#      [['direction', 'magnitude', 'needed'], '1']
#      [['dis', 'cretion', 'goals'], '1']
#      [['disability', 'mortality', 'rates'], '1']
#      [['disaggregated', 'systems', 'relying'], '1']
#      [['discovery', 'invention', 'research'], '1']
#      [['discrepancy', 'between', 'existing'], '1']
#      [['discretion', 'who', 'participates'], '1']
#      [['discussion', 'another', 'indi'], '1']
#      [['discussion', 'perhaps', 'explain'], '1']
#      [['disproportion', 'ate', 'disability'], '1']
#      [['distributed', 'all', 'those'], '1']
#      [['distribution', 'problem', 'simple'], '1']
#      [['divided', 'form', 'several'], '1']
#      [['do', 'apply', 'them'], '1']
#      [['does', 'deal', 'one'], '1']
#      [['domain', 'its', 'role'], '1']
#      [['down', 'sponsor', 's'], '1']
#      [['draw', 'his', 'her'], '1']
#      [['drawn', 'from', 'cost'], '1']
#      [['drawn', 'from', 'planners'], '1']
#      [['drawn', 'simple', 'from'], '1']
#      [['duce', 'amibiguity', 'planning'], '1']
#      [['duce', 'risk', 'omission'], '1']
#      [['duffy', 'j', 's'], '1']
#      [['dures', 'known', 'states'], '1']
#      [['during', 'detailing', 'evaluation'], '1']
#      [['during', 'formalization', 'stage'], '1']
#      [['during', 'plan', 'ning'], '1']
#      [['dynamics', 'environment', 'make'], '1']
#      [['e', 'b', 'sketch'], '1']
#      [['e', 'clasen', 'evaluation'], '1']
#      [['e', 'evaluation', 'research'], '1']
#      [['e', 'g', 'linear'], '1']
#      [['e', 'new', 'think'], '1']
#      [['e', 'patterns', 'organizational'], '1']
#      [['each', 'basic', 'modes'], '1']
#      [['each', 'component', 'defined'], '1']
#      [['each', 'criteria', 'sketching'], '1']
#      [['each', 'criterion', 'decision'], '1']
#      [['each', 'design', 'related'], '1']
#      [['each', 'influenced', 'stability'], '1']
#      [['each', 'information', 'system'], '1']
#      [['each', 'information', 'type'], '1']
#      [['each', 'phase', 'planning'], '1']
#      [['each', 'planning', 'stages'], '1']
#      [['each', 'qualification', 'described'], '1']
#      [['each', 'should', 'considered'], '1']
#      [['each', 'stage', 'simple'], '1']
#      [['each', 'terms', 'describes'], '1']
#      [['economic', 'business', 'research'], '1']
#      [['education', 'background', 'other'], '1']
#      [['education', 'itasca', 'ill'], '1']
#      [['effec', 'tive', 'planning'], '1']
#      [['effec', 'tive', 'plans'], '1']
#      [['effect', 'relations', 'can'], '1']
#      [['effective', 'ness', 'three'], '1']
#      [['effectiveness', 'complex', 'envi'], '1']
#      [['effectiveness', 'literature', 'searches'], '1']
#      [['efficient', 'task', 'force'], '1']
#      [['effort', 'particular', 'envi'], '1']
#      [['effort', 'should', 'distributed'], '1']
#      [['effort', 'similarly', 'national'], '1']
#      [['efforts', 'can', 'achieved'], '1']
#      [['egy', 'assumes', 'full'], '1']
#      [['el', 'feasible', 'only'], '1']
#      [['el', 'personalized', 'information'], '1']
#      [['el', 'problem', 'identification'], '1']
#      [['elementary', 'nodes', 'terms'], '1']
#      [['els', 'often', 'suggest'], '1']
#      [['emery', 'purposefulsystem', 'chicago'], '1']
#      [['empha', 'sized', 'p'], '1']
#      [['employees', 'studies', 'personnel'], '1']
#      [['en', 'hances', 'implementation'], '1']
#      [['ence', 'type', 'information'], '1']
#      [['ences', 'high', 'creativity'], '1']
#      [['end', 'implicit', 'p'], '1']
#      [['enhance', 'intuitive', 'processes'], '1']
#      [['enhances', 'creativity', 'modest'], '1']
#      [['enhancing', 'implementation', 'prospects'], '1']
#      [['enironmental', 'personal', 'non'], '1']
#      [['envi', 'ronment', 're'], '1']
#      [['envi', 'ronments', 'design'], '1']
#      [['envi', 'ronments', 'environmental'], '1']
#      [['envi', 'ronments', 'models'], '1']
#      [['envi', 'ronments', 'planning'], '1']
#      [['envi', 'ronments', 'top'], '1']
#      [['environ', 'ment', 'panel'], '1']
#      [['environ', 'ments', 'can'], '1']
#      [['environ', 'ments', 'complex'], '1']
#      [['environ', 'ments', 'makes'], '1']
#      [['environ', 'ments', 'multidisciplinary'], '1']
#      [['environ', 'ments', 'preferred'], '1']
#      [['environ', 'ments', 'reports'], '1']
#      [['environment', 'assumed', 'information'], '1']
#      [['environment', 'attributes', 'simple'], '1']
#      [['environment', 'can', 'yield'], '1']
#      [['environment', 'complex', 'simple'], '1']
#      [['environment', 'formulation', 'conceptualization'], '1']
#      [['environment', 'has', 'known'], '1']
#      [['environment', 'information', 'examined'], '1']
#      [['environment', 'information', 'system'], '1']
#      [['environment', 'make', 'difficult'], '1']
#      [['environment', 'personal', 'infor'], '1']
#      [['environment', 'planning', 'information'], '1']
#      [['environment', 'pre', 'dictable'], '1']
#      [['environment', 'relationship', 'between'], '1']
#      [['environment', 'requires', 'information'], '1']
#      [['environment', 'results', 'example'], '1']
#      [['environment', 'well', 'requirements'], '1']
#      [['environmental', 'complexity', 'environmental'], '1']
#      [['environmental', 'complexity', 'propositions'], '1']
#      [['environmental', 'complexity', 'used'], '1']
#      [['environmental', 'complexity', 'when'], '1']
#      [['environmental', 'dif', 'ferences'], '1']
#      [['environmental', 'differences', 'p'], '1']
#      [['environmental', 'enironmental', 'personal'], '1']
#      [['environmental', 'factors', 'also'], '1']
#      [['environmental', 'factors', 'planning'], '1']
#      [['environmental', 'features', 'information'], '1']
#      [['environmental', 'settings', 'exploring'], '1']
#      [['environments', 'ambiguity', 'com'], '1']
#      [['environments', 'analytical', 'infor'], '1']
#      [['environments', 'attrib', 'utes'], '1']
#      [['environments', 'because', 'historical'], '1']
#      [['environments', 'can', 'sub'], '1']
#      [['environments', 'complex', 'environments'], '1']
#      [['environments', 'data', 'systems'], '1']
#      [['environments', 'designs', 'far'], '1']
#      [['environments', 'evaluation', 'tends'], '1']
#      [['environments', 'have', 'attributes'], '1']
#      [['environments', 'have', 'similar'], '1']
#      [['environments', 'implementation', 'plans'], '1']
#      [['environments', 'information', 'attributes'], '1']
#      [['environments', 'information', 'set'], '1']
#      [['environments', 'information', 'systems'], '1']
#      [['environments', 'interactive', 'infor'], '1']
#      [['environments', 'lack', 'creativity'], '1']
#      [['environments', 'makes', 'nonperson'], '1']
#      [['environments', 'makes', 'systems'], '1']
#      [['environments', 'non', 'person'], '1']
#      [['environments', 'permit', 'planner'], '1']
#      [['environments', 'planner', 'aids'], '1']
#      [['environments', 'planner', 'must'], '1']
#      [['environments', 'planners', 'contin'], '1']
#      [['environments', 'planning', 'conceptualization'], '1']
#      [['environments', 'planning', 'environment'], '1']
#      [['environments', 'planning', 'information'], '1']
#      [['environments', 'planning', 'problems'], '1']
#      [['environments', 'predictability', 'found'], '1']
#      [['environments', 'provide', 'ten'], '1']
#      [['environments', 'purpose', 'article'], '1']
#      [['environments', 'quantitative', 'methods'], '1']
#      [['environments', 'reports', 'can'], '1']
#      [['environments', 'requires', 'interactive'], '1']
#      [['environments', 'see', 'table'], '1']
#      [['environments', 'stages', 'planning'], '1']
#      [['environments', 'synthesis', 'nonpersonal'], '1']
#      [['environments', 'we', 'pro'], '1']
#      [['eoq', 'models', 'used'], '1']
#      [['erogeneous', 'subject', 'many'], '1']
#      [['error', 'free', 'standardization'], '1']
#      [['error', 'part', 'human'], '1']
#      [['es', 'tablished', 'information'], '1']
#      [['essential', 'changes', 'stimulated'], '1']
#      [['essential', 'enhancing', 'implementation'], '1']
#      [['essential', 'further', 'unex'], '1']
#      [['essential', 'preferred', 'infor'], '1']
#      [['essentially', 'person', 'centered'], '1']
#      [['esteem', 'reinforces', 'positive'], '1']
#      [['estimates', 'made', 'individuals'], '1']
#      [['etc', 'p', 'i'], '1']
#      [['etc', 'reports', 'traditionally'], '1']
#      [['ethnic', 'group', 'has'], '1']
#      [['eval', 'uated', 'determine'], '1']
#      [['evaluate', 'formal', 'informal'], '1']
#      [['evaluate', 'plan', 'sponsor'], '1']
#      [['evaluation', 'analytic', 'methods'], '1']
#      [['evaluation', 'complex', 'envi'], '1']
#      [['evaluation', 'education', 'itasca'], '1']
#      [['evaluation', 'implementation', 'performance'], '1']
#      [['evaluation', 'implementation', 'planning'], '1']
#      [['evaluation', 'plan', 'ning'], '1']
#      [['evaluation', 'planning', 'stages'], '1']
#      [['evaluation', 'policy', 'washington'], '1']
#      [['evaluation', 'research', 'principles'], '1']
#      [['evaluation', 'review', 'technique'], '1']
#      [['evaluation', 'stage', 'used'], '1']
#      [['evaluation', 'stages', 'planning'], '1']
#      [['evaluation', 'tends', 'situational'], '1']
#      [['even', 'general', 'categorizing'], '1']
#      [['even', 'sophisti', 'cated'], '1']
#      [['ex', 'ist', 'variability'], '1']
#      [['ex', 'perts', 'using'], '1']
#      [['ex', 'ploited', 'disaggregated'], '1']
# ...
#      [['tend', 'less', 'ac'], '1']
#      [['tend', 'mallea', 'ble'], '1']
#      [['tendency', 'person', 'centered'], '1']
#      [['tends', 'creative', 'consistent'], '1']
#      [['tends', 'expensive', 'time'], '1']
#      [['tends', 'inconsistent', 'may'], '1']
#      [['tends', 'situational', 'incorporate'], '1']
#      [['tent', 'than', 'person'], '1']
#      [['teraction', 'between', 'planner'], '1']
#      [['tered', 'information', 'complexity'], '1']
#      [['tered', 'information', 'systems'], '1']
#      [['term', 'describes', 'generation'], '1']
#      [['termine', 'expected', 'performance'], '1']
#      [['terms', 'describe', 'nodes'], '1']
#      [['terms', 'describes', 'node'], '1']
#      [['terms', 'its', 'scope'], '1']
#      [['terms', 'planning', 'problem'], '1']
#      [['terms', 'several', 'attributes'], '1']
#      [['terms', 'several', 'interrelated'], '1']
#      [['terms', 'temporal', 'procedural'], '1']
#      [['terms', 'well', 'higher'], '1']
#      [['terms', 'where', 'pirai'], '1']
#      [['terms', 'which', 'assumes'], '1']
#      [['texas', 'aus', 'tin'], '1']
#      [['th', 'person', 'pi'], '1']
#      [['th', 'planner', 'personal'], '1']
#      [['th', 'planner', 'uses'], '1']
#      [['th', 'report', 'type'], '1']
#      [['than', 'informa', 'tion'], '1']
#      [['than', 'nonperson', 'cen'], '1']
#      [['than', 'person', 'centered'], '1']
#      [['them', 'designing', 'viking'], '1']
#      [['them', 'type', 'informa'], '1']
#      [['theoret', 'structure', 'unstructured'], '1']
#      [['theory', 'firm', 'new'], '1']
#      [['theory', 'practice', 'social'], '1']
#      [['think', 'new', 'york'], '1']
#      [['thompson', 'j', 'd'], '1']
#      [['those', 'affected', 'avoid'], '1']
#      [['those', 'experience', 'neighbor'], '1']
#      [['those', 'planning', 'outpatient'], '1']
#      [['thought', 'simple', 'when'], '1']
#      [['three', 'planning', 'methods'], '1']
#      [['three', 'principles', 'human'], '1']
#      [['through', 'analysis', 'environmental'], '1']
#      [['through', 'application', 'classical'], '1']
#      [['through', 'discussion', 'another'], '1']
#      [['through', 'interpretation', 'analysis'], '1']
#      [['through', 'involvement', 'person'], '1']
#      [['through', 'morphological', 'approach'], '1']
#      [['through', 'person', 'centered'], '1']
#      [['through', 'pro', 'gramming'], '1']
#      [['through', 'process', 'which'], '1']
#      [['thus', 'complex', 'because'], '1']
#      [['thus', 'new', 'potentially'], '1']
#      [['thus', 'nonper', 'sonal'], '1']
#      [['thus', 'nonperson', 'cen'], '1']
#      [['thus', 'pira', 'model'], '1']
#      [['thus', 'tend', 'mallea'], '1']
#      [['thus', 'would', 'described'], '1']
#      [['tial', 'departures', 'from'], '1']
#      [['tic', 'information', 'i'], '1']
#      [['tice', 'public', 'service'], '1']
#      [['ticular', 'age', 'ethnic'], '1']
#      [['ties', 'self', 'esteem'], '1']
#      [['time', 'consuming', 'strategies'], '1']
#      [['time', 'heuristic', 'search'], '1']
#      [['time', 'horizons', 'incorporate'], '1']
#      [['time', 'horizons', 'schematic'], '1']
#      [['time', 'interac', 'tive'], '1']
#      [['time', 'ly', 'introduction'], '1']
#      [['time', 'meas', 'ure'], '1']
#      [['time', 'often', 'renders'], '1']
#      [['time', 'period', 'find'], '1']
#      [['time', 'plan', 's'], '1']
#      [['timeli', 'ness', 'result'], '1']
#      [['timeliness', 'accuracy', 'consis'], '1']
#      [['timeliness', 'accuracy', 'etc'], '1']
#      [['timeliness', 'creativity', 'low'], '1']
#      [['timeliness', 'delay', 'between'], '1']
#      [['timeliness', 'low', 'cost'], '1']
#      [['timely', 'accuracy', 'con'], '1']
#      [['timely', 'accurate', 'con'], '1']
#      [['timely', 'consistent', 'accurate'], '1']
#      [['timely', 'creative', 'accurate'], '1']
#      [['timely', 'extent', 'possible'], '1']
#      [['timely', 'information', 'systems'], '1']
#      [['timely', 'large', 'organizations'], '1']
#      [['timely', 'low', 'cost'], '1']
#      [['timely', 'low', 'risk'], '1']
#      [['timely', 'may', 'have'], '1']
#      [['timely', 'tends', 'inconsistent'], '1']
#      [['tin', 'assistant', 'professor'], '1']
#      [['tion', 'accurately', 'described'], '1']
#      [['tion', 'attributes', 'information'], '1']
#      [['tion', 'between', 'two'], '1']
#      [['tion', 'built', 'permit'], '1']
#      [['tion', 'example', 'tends'], '1']
#      [['tion', 'generated', 'via'], '1']
#      [['tion', 'generation', 'complex'], '1']
#      [['tion', 'generation', 'should'], '1']
#      [['tion', 'information', 'system'], '1']
#      [['tion', 'levels', 'environmental'], '1']
#      [['tion', 'models', 'preferred'], '1']
#      [['tion', 'modes', 'personal'], '1']
#      [['tion', 'reports', 'used'], '1']
#      [['tion', 's', 'key'], '1']
#      [['tion', 'sources', 'provide'], '1']
#      [['tion', 'system', 'design'], '1']
#      [['tions', 'articulate', 'preferred'], '1']
#      [['tions', 'set', 's'], '1']
#      [['tions', 'some', 'contextual'], '1']
#      [['tive', 'information', 'systems'], '1']
#      [['tive', 'planning', 'efforts'], '1']
#      [['tive', 'plans', 'models'], '1']
#      [['tive', 'reports', 'analysis'], '1']
#      [['tivities', 'like', 'problem'], '1']
#      [['top', 'managers', 'rely'], '1']
#      [['torical', 'models', 'r'], '1']
#      [['tors', 'consider', 'demands'], '1']
#      [['traditionally', 'associated', 'formal'], '1']
#      [['training', 'interpret', 'expand'], '1']
#      [['transportation', 'model', 'solution'], '1']
#      [['trate', 'impact', 'environmental'], '1']
#      [['trates', 'some', 'desirable'], '1']
#      [['trative', 'science', 'ohio'], '1']
#      [['treated', 'terms', 'its'], '1']
#      [['trial', 'management', 'review'], '1']
#      [['trials', 'like', 'accuracy'], '1']
#      [['tribute', 'models', 'interestingly'], '1']
#      [['tributes', 'timeliness', 'accuracy'], '1']
#      [['true', 'only', 'stable'], '1']
#      [['tual', 'foundations', 'structure'], '1']
#      [['tween', 'each', 'criterion'], '1']
#      [['two', 'basic', 'cate'], '1']
#      [['two', 'more', 'elementary'], '1']
#      [['two', 'more', 'individuals'], '1']
#      [['two', 'types', 'environments'], '1']
#      [['type', 'design', 'has'], '1']
#      [['type', 'formation', 'accurate'], '1']
#      [['type', 'il', 'information'], '1']
#      [['type', 'informa', 'tion'], '1']
#      [['type', 'information', 'sought'], '1']
#      [['type', 'used', 'propositions'], '1']
#      [['types', 'environments', 'provide'], '1']
#      [['types', 'excep', 'tion'], '1']
#      [['typical', 'sources', 'representing'], '1']
#      [['typically', 'terms', 'needs'], '1']
#      [['u', 'used', 'promote'], '1']
#      [['uals', 'groups', 'new'], '1']
#      [['uated', 'determine', 'how'], '1']
#      [['ue', 'seek', 'information'], '1']
#      [['ular', 'environmental', 'settings'], '1']
#      [['un', 'certainty', 'under'], '1']
#      [['uncertainty', 'risk', 'unknown'], '1']
#      [['under', 'conditions', 'semi'], '1']
#      [['under', 'constant', 'conditions'], '1']
#      [['under', 'risk', 'may'], '1']
#      [['under', 'semi', 'complex'], '1']
#      [['under', 'un', 'certainty'], '1']
#      [['understood', 'making', 'planning'], '1']
#      [['unex', 'plained', 'dynamics'], '1']
#      [['unfreezing', 'needed', 'induce'], '1']
#      [['unilateral', 'decree', 'can'], '1']
#      [['unilateral', 'power', 'shared'], '1']
#      [['unique', 'priori', 'little'], '1']
#      [['unique', 'procedural', 'known'], '1']
#      [['unit', 'fully', 'describing'], '1']
#      [['unit', 'structures', 'administrative'], '1']
#      [['university', 'columbus', 'ohio'], '1']
#      [['university', 'system', 'designs'], '1']
#      [['university', 'texas', 'aus'], '1']
#      [['university', 'wiscon', 'sin'], '1']
#      [['unknown', 'states', 'states'], '1']
#      [['unstructured', 'decision', 'processed'], '1']
#      [['up', 'quality', 'down'], '1']
#      [['up', 'smaller', 'better'], '1']
#      [['upon', 'another', 'individual'], '1']
#      [['upon', 'information', 'gained'], '1']
#      [['upon', 'stage', 'planning'], '1']
#      [['usage', 'sales', 'rates'], '1']
#      [['use', 'academy', 'management'], '1']
#      [['use', 'approach', 'p'], '1']
#      [['use', 'data', 'systems'], '1']
#      [['use', 'detailing', 'evaluation'], '1']
#      [['use', 'experience', 'build'], '1']
#      [['use', 'infor', 'mation'], '1']
#      [['use', 'information', 'systems'], '1']
#      [['use', 'large', 'data'], '1']
#      [['use', 'patterns', 'stable'], '1']
#      [['use', 'personal', 'experience'], '1']
#      [['use', 'reports', 'present'], '1']
#      [['used', 'because', 'precise'], '1']
#      [['used', 'complex', 'envi'], '1']
#      [['used', 'conceptualize', 'planning'], '1']
#      [['used', 'define', 'needs'], '1']
#      [['used', 'define', 'planning'], '1']
#      [['used', 'define', 'simple'], '1']
#      [['used', 'detail', 'alter'], '1']
#      [['used', 'develop', 'plan'], '1']
#      [['used', 'enhance', 'intuitive'], '1']
#      [['used', 'experts', 'provided'], '1']
#      [['used', 'formation', 'set'], '1']
#      [['used', 'generate', 'planning'], '1']
#      [['used', 'help', 'plan'], '1']
#      [['used', 'identify', 'direction'], '1']
#      [['used', 'identify', 'needs'], '1']
#      [['used', 'illus', 'trate'], '1']
#      [['used', 'illustrate', 'how'], '1']
#      [['used', 'improve', 'accuracy'], '1']
#      [['used', 'individual', 'organizational'], '1']
#      [['used', 'judge', 'impact'], '1']
#      [['used', 'list', 'amounts'], '1']
#      [['used', 'nonpersonal', 'formation'], '1']
#      [['used', 'obtain', 'formation'], '1']
#      [['used', 'planning', 'group'], '1']
#      [['used', 'preferred', 'information'], '1']
#      [['used', 'prescribe', 'behavior'], '1']
#      [['used', 'promote', 'simplicity'], '1']
#      [['used', 'propositions', 'also'], '1']
#      [['used', 'provide', 'formation'], '1']
#      [['used', 're', 'duce'], '1']
#      [['used', 're', 'order'], '1']
#      [['used', 'reoccurring', 'plan'], '1']
#      [['used', 'select', 'among'], '1']
#      [['used', 'simple', 'environ'], '1']
#      [['used', 'specify', 'current'], '1']
#      [['used', 'stress', 'interaction'], '1']
#      [['used', 'sup', 'port'], '1']
#      [['used', 'support', 'planning'], '1']
#      [['useful', 'complex', 'environments'], '1']
#      [['useful', 'essential', 'changes'], '1']
#      [['useful', 'generating', 'information'], '1']
#      [['user', 'always', 'places'], '1']
#      [['user', 'services', 'careful'], '1']
#      [['users', 'insure', 'im'], '1']
#      [['users', 'through', 'process'], '1']
#      [['uses', 'analytic', 'technique'], '1']
#      [['uses', 'k', 'th'], '1']
#      [['uses', 'nonperson', 'centered'], '1']
#      [['using', 'analytic', 'technique'], '1']
#      [['using', 'classi', 'cal'], '1']
#      [['using', 'historical', 'models'], '1']
#      [['using', 'interactive', 'modes'], '1']
#      [['using', 'methodologies', 'sensitivity'], '1']
#      [['using', 'model', 'improves'], '1']
#      [['using', 'nonpersonal', 'informational'], '1']
#      [['using', 'past', 'experience'], '1']
#      [['using', 'person', 'centered'], '1']
#      [['using', 'two', 'more'], '1']
#      [['utes', 'considered', 'article'], '1']
#      [['utes', 'known', 'can'], '1']
#      [['utilities', 'decision', 'sciences'], '1']
#      [['utilities', 'persuasion', 'morphology'], '1']
#      [['utility', 'intended', 'user'], '1']
#      [['utility', 'than', 'informa'], '1']
#      [['value', 'judgment', 'formation'], '1']
#      [['value', 'planning', 'decisions'], '1']
#      [['variability', 'frequency', 'occurrence'], '1']
#      [['variable', 'available', 'administrators'], '1']
#      [['variable', 'consistent', 'churchman'], '1']
#      [['variable', 'p', 'i'], '1']
#      [['variables', 'para', 'meters'], '1']
#      [['variables', 'which', 'stipulate'], '1']
#      [['variance', 'reports', 'other'], '1']
#      [['variety', 'sources', 'permit'], '1']
#      [['various', 'neighborhood', 'health'], '1']
#      [['various', 'person', 'centered'], '1']
#      [['various', 'planning', 'methods'], '1']
#      [['vary', 'decisions', 'under'], '1']
#      [['vary', 'depending', 'upon'], '1']
#      [['ven', 'd', 'h'], '1']
#      [['ven', 'delbecq', 'task'], '1']
#      [['ven', 'group', 'process'], '1']
#      [['verbal', 'interaction', 'live'], '1']
#      [['very', 'few', 'competitors'], '1']
#      [['vestigated', 'sources', 'people'], '1']
#      [['via', 'interac', 'tion'], '1']
#      [['vides', 'information', 'needed'], '1']
#      [['vidual', 'example', 'broker'], '1']
#      [['view', 'complexity', 'terms'], '1']
#      [['view', 'how', 'planning'], '1']
#      [['view', 'planning', 'prob'], '1']
#      [['viewing', 'method', 'pol'], '1']
#      [['viewpoints', 'plan', 'ners'], '1']
#      [['viking', 'mars', 'lander'], '1']
#      [['visit', 'organizations', 'find'], '1']
#      [['vogt', 'federal', 'evaluation'], '1']
#      [['volume', 'occur', 'unknown'], '1']
#      [['w', 'backoff', 'r'], '1']
#      [['w', 'design', 'inquiring'], '1']
#      [['w', 'f', 'process'], '1']
#      [['w', 'influence', 'organizational'], '1']
#      [['w', 'j', 'stiffen'], '1']
#      [['wallester', 'comparative', 'study'], '1']
#      [['washington', 'd', 'c'], '1']
#      [['ways', 'generate', 'information'], '1']
#      [['we', 'believe', 'r'], '1']
#      [['we', 'believe', 'superior'], '1']
#      [['we', 'pro', 'pose'], '1']
#      [['wealth', 'formation', 'those'], '1']
#      [['weight', 'each', 'criteria'], '1']
#      [['well', 'higher', 'order'], '1']
#      [['well', 'reduce', 'perceptions'], '1']
#      [['well', 'requirements', 'each'], '1']
#      [['well', 'timeliness', 'low'], '1']
#      [['were', 'found', 'preferred'], '1']
#      [['when', 'changes', 'performance'], '1']
#      [['when', 'decision', 'based'], '1']
#      [['when', 'eoq', 'models'], '1']
#      [['when', 'i', 'th'], '1']
#      [['when', 'organization', 's'], '1']
#      [['when', 'part', 'pre'], '1']
#      [['when', 'person', 'j'], '1']
#      [['when', 'personal', 'interactive'], '1']
#      [['when', 'planner', 'i'], '1']
#      [['when', 'planning', 'complex'], '1']
#      [['when', 'properly', 'managed'], '1']
#      [['when', 'speed', 'essential'], '1']
#      [['when', 'sponsor', 'initiates'], '1']
#      [['when', 'states', 'ill'], '1']
#      [['when', 'survey', 'indicates'], '1']
#      [['when', 'use', 'patterns'], '1']
#      [['where', 'pirai', 'information'], '1']
#      [['where', 'represents', 'change'], '1']
#      [['which', 'aggregate', 'combine'], '1']
#      [['which', 'alters', 'objectives'], '1']
#      [['which', 'assumes', 'environment'], '1']
#      [['which', 'diminishes', 'creativity'], '1']
#      [['which', 'each', 'information'], '1']
#      [['which', 'enhances', 'creativity'], '1']
#      [['which', 'guide', 'planning'], '1']
#      [['which', 'inexpensive', 'timely'], '1']
#      [['which', 'stimulates', 'new'], '1']
#      [['which', 'stipulate', 'optimal'], '1']
#      [['which', 'true', 'only'], '1']
#      [['which', 'used', 'nonpersonal'], '1']
#      [['while', 'i', 'i'], '1']
#      [['while', 'set', 'notation'], '1']
#      [['while', 'shared', 'power'], '1']
#      [['who', 'guides', 'users'], '1']
#      [['who', 'participates', 'management'], '1']
#      [['wholey', 'j', 'j'], '1']
#      [['why', 'costs', 'up'], '1']
#      [['wider', 'view', 'planning'], '1']
#      [['wiscon', 'sin', 'madison'], '1']
#      [['without', 'accounting', 'environmental'], '1']
#      [['without', 'focusing', 'creativity'], '1']
#      [['work', 'because', 'both'], '1']
#      [['work', 'new', 'york'], '1']
#      [['work', 'rigid', 'framework'], '1']
#      [['work', 'systems', 'design'], '1']
#      [['work', 'unit', 'structures'], '1']
#      [['working', 'pa', 'per'], '1']
#      [['worth', 'given', 'set'], '1']
#      [['would', 'described', 'highly'], '1']
#      [['yield', 'requisite', 'infor'], '1']
#      [['yielding', 'i', 'p'], '1']
#      [['york', 'brooks', 'cole'], '1']
#      [['york', 'harper', 'row'], '1']
#      [['york', 'holt', 'reinhart'], '1']
#      [['york', 'macmillan', 'co'], '1']
#      [['york', 'national', 'industrial'], '1']
#      [['york', 'prentice', 'hall'], '1']
#      [['york', 'scrib', 'ners'], '1']
#      [['ysis', 'features', 'linear'], '1']
#      [['zability', 'extent', 'solution'], '1']
#      [['zwicky', 'f', 'discovery'], '1']

# %%
"""
Create Dataframe
""" 
# Data
data = []
for words, freq in freq_list:
    assert len(words) == 3
    data.append([words[0], words[1], words[2], freq])

# Columns
columns = ["word1", "word2", "word3", "freq"]

# Index
index = list(range(len(freq_list)))

# DataFrame
dataframe = pd.DataFrame(data, columns=columns, index=index)

# Print Test
dataframe.head()
# Out:
#         word1        word2        word3 freq
# 0    planning  information      systems   11
# 1         low         risk     omission    8
# 2           p            i            p    8
# 3      design     planning  information    6
# 4  management       review      october    6

# %%
"""
Run filtering for each file
"""
progress = list(range(0, len(filtered_list), len(filtered_list) // 99))

for file_num in range(0, len(filtered_list)):
    
    file = filtered_list[file_num]
    # Open file
    try:
        file_open = zip_file.open(file, mode="r")
    except IOError:
        print("Error opening file {0}".format(file))
        exit(0)
    
    # Create output file
    output_name = mypath + "Results_3/" + file[len("/ngram" + str(N_number)):]
    # Note: Output file encoding set to UTF-8
    output_file = open(output_name, mode="w+", encoding="utf-8")
    
    # Track for max length word
    # Used for formatting output data
    max_length = [float("-inf")] * 3
        
    # Initiate freq_list -> [[words0, freq0], [words1, freq1]]
    freq_list = []
    
    # Read by line
    for line in file_open:
        # Line decode using UTF-8
        line = line.decode("utf-8")
        
        # line -> "teachers who taught 5"
        assert isinstance(line, str)
        
        # pair -> ["teachers", "who", "taught", "5"]
        pair = line.strip().split()
        
        assert len(pair) == 4
    
        # Separate word/freq
        words, freq = pair[:-1], pair[-1]
        assert len(words) == 3
        assert freq.isdigit()
        
        # Filter by word's attribute
        if check_words(words):
            continue
        
        # Update max_length
        for i in range(len(words)):
            if len(words[i]) > max_length[i]:
                max_length[i] = len(words[i])
            
        # Append new pair to freq_list
        freq_list.append([words, freq])
    
    # Close reading file
    file_open.close()
    
    # Create Dataframe
    # Data
    data = []
    for words, freq in freq_list:
        assert len(words) == 3
        data.append([words[0], words[1], words[2], freq])

    # Columns
    columns = ["word1", "word2", "word3", "freq"]

    # Index
    index = list(range(len(freq_list)))

    # DataFrame
    dataframe = pd.DataFrame(data, columns=columns, index=index)
    
    # Write to output file
    for words, freq in freq_list:
        for i in range(len(words)):
            output_file.write(words[i].ljust(max_length[i] + 5))
        output_file.write(freq + "\n")
    
    # Close output_file
    output_file.close()
    
    # Track Progress
    if len(progress) > 0 and file_num >= progress[0]:
        print("Progress: {}%".format(100 - len(progress)))
        progress.pop(0)

# Print Sample Output
print(dataframe.head())
# Out:
# Progress: 0%
# Progress: 1%
