# %%
"""
The file analylizes the .txt files (which contains ngram2 data) in ngram2 folder 
in a zip file and output in a folder 
"""

import pandas as pd
import numpy as np
import zipfile

# Clarify the mission N number for this .ipynb
N_number = 2

# %%
def namestr(obj, namespace):
    return [name for name in namespace if namespace[name] is obj]

def display(items):
    print(namestr(items, globals()))
    for item in items:
        print("     {0}".format(item))

# Test display
test_dict = {"A": [1, 2, 3], "B": [4, 5, 6]}
display(test_dict)
# Out:
# ['test_dict']
#      A
#      B

# %%
from os import listdir
from os.path import isfile, join

mypath = "./"
zip_file_name = "receipt-id-773931-part-001"
zip_file = zipfile.ZipFile(mypath + zip_file_name + ".zip")
file_name_list = zip_file.namelist()
# Should return 4 folders if testing on ASG Zip
print("{0} files detected under current directory. ".format(len(file_name_list)))
# Out:
# 53528 files detected under current directory.

# %%
def filter_by_filename(files_list):
    """Function filtering files by filenames.
    Only accepts files starts with "journal-article"
    """
    filtered_list = []
    mask_match = "ngram" + str(N_number) + "/journal-article"
    for filename in files_list:
        # Check if the filename starts with "journal-article"
        assert isinstance(filename, str)
        # Check the first 20 characters of the file name
        if filename.startswith(mask_match, 0, len(mask_match)):
            filtered_list.append(filename)
    return filtered_list

# Run "filter_by_filename" for current directory
filtered_list = filter_by_filename(file_name_list)
print("{0} files remained after filename filtering. ".format(len(filtered_list)))
# Out:
# 13382 files remained after filename filtering.

# %%
# Functions checking word attributes (single-letter, starts/ends with numebr)
def is_single_letter(word):
    assert isinstance(word, str)
    return len(word) <= 1

def starts_with_number(word):
    assert isinstance(word, str)
    try:
        return word[0].isdigit()
    except:
        return False

def ends_with_number(word):
    assert isinstance(word, str)
    try:
        return word[len(word) - 1].isdigit()
    except:
        return False

# Summary of check functions
check_funcs = [
#     is_single_letter, # Only applies for 1-gram
    starts_with_number, 
    ends_with_number,
]

# Summary of checking mechanisms
def check_words(words):
    for word in words:
        check_result = [check_func(word) for check_func in check_funcs]
        if any(check_result):
            return True
    return False

# %%
file_0 = filtered_list[0]
try:
    journal_0 = zip_file.open(file_0, mode="r")
except IOError:
    print("Error opening file {0}".format(file_0))
    exit(0)
    
# Track the meaningful dictonaries
freq_list = []

# Read file line by line
for line in journal_0:
    line = line.decode("ascii") 
    
    assert isinstance(line, str)
    pair = line.strip().split()
    
    assert len(pair) == 3
    
    # Separate word/freq
    words, freq = pair[:-1], pair[-1]
    assert len(words) == 2
    assert freq.isdigit()
    
    # Filter by word's attribute
    if check_words(words):
        continue
    freq_list.append([words, freq])

journal_0.close()
display(freq_list)
# Out:
# ['freq_list']
#      [['information', 'systems'], '27']
#      [['p', 'i'], '21']
#      [['complex', 'environments'], '19']
#      [['planning', 'information'], '16']
#      [['new', 'york'], '15']
#      [['person', 'centered'], '15']
#      [['simple', 'environments'], '15']
#      [['information', 'system'], '14']
#      [['risk', 'omission'], '13']
#      [['i', 'i'], '12']
#      [['infor', 'mation'], '12']
#      [['p', 'r'], '12']
#      [['r', 'p'], '12']
#      [['i', 'p'], '11']
#      [['low', 'risk'], '11']
#      [['r', 'r'], '11']
#      [['information', 'sets'], '10']
#      [['planning', 'problems'], '10']
#      [['information', 'set'], '9']
#      [['management', 'review'], '9']
#      [['plan', 'ning'], '9']
#      [['can', 'used'], '8']
#      [['informa', 'tion'], '8']
#      [['nonperson', 'centered'], '8']
#      [['planning', 'problem'], '8']
#      [['simple', 'complex'], '8']
#      [['centered', 'information'], '7']
#      [['planning', 'methods'], '7']
#      [['planning', 'process'], '7']
#      [['preferred', 'information'], '7']
#      [['design', 'planning'], '6']
#      [['environ', 'ments'], '6']
#      [['i', 'r'], '6']
#      [['information', 'modes'], '6']
#      [['review', 'october'], '6']
#      [['should', 'used'], '6']
#      [['stage', 'planning'], '6']
#      [['centered', 'modes'], '5']
#      [['complex', 'planning'], '5']
#      [['creativity', 'low'], '5']
#      [['detailing', 'evaluation'], '5']
#      [['envi', 'ronments'], '5']
#      [['nominal', 'groups'], '5']
#      [['organization', 's'], '5']
#      [['personal', 'interactive'], '5']
#      [['planning', 'stages'], '5']
#      [['r', 'ik'], '5']
#      [['simple', 'environ'], '5']
#      [['data', 'sets'], '4']
#      [['de', 'ven'], '4']
#      [['each', 'stage'], '4']
#      [['environmental', 'complexity'], '4']
#      [['environments', 'planning'], '4']
#      [['higher', 'order'], '4']
#      [['information', 'can'], '4']
#      [['information', 'generated'], '4']
#      [['low', 'cost'], '4']
#      [['methods', 'like'], '4']
#      [['omis', 'sion'], '4']
#      [['planning', 'environment'], '4']
#      [['risk', 'omis'], '4']
#      [['stages', 'planning'], '4']
#      [['state', 'university'], '4']
#      [['system', 'design'], '4']
#      [['system', 'designs'], '4']
#      [['van', 'de'], '4']
#      [['can', 'also'], '3']
#      [['can', 'provide'], '3']
#      [['can', 'timely'], '3']
#      [['centered', 'systems'], '3']
#      [['com', 'plexity'], '3']
#      [['complex', 'envi'], '3']
#      [['complex', 'environ'], '3']
#      [['data', 'systems'], '3']
#      [['define', 'planning'], '3']
#      [['develop', 'ment'], '3']
#      [['environ', 'ment'], '3']
#      [['environments', 'information'], '3']
#      [['form', 'p'], '3']
#      [['generated', 'when'], '3']
#      [['has', 'been'], '3']
#      [['have', 'low'], '3']
#      [['historical', 'models'], '3']
#      [['i', 'j'], '3']
#      [['i', 'th'], '3']
#      [['input', 'output'], '3']
#      [['j', 'g'], '3']
#      [['management', 'information'], '3']
#      [['management', 'science'], '3']
#      [['mathematical', 'models'], '3']
#      [['mod', 'el'], '3']
#      [['modes', 'information'], '3']
#      [['modest', 'cost'], '3']
#      [['often', 'used'], '3']
#      [['ohio', 'state'], '3']
#      [['order', 'terms'], '3']
#      [['past', 'experience'], '3']
#      [['pi', 'i'], '3']
#      [['planning', 'effort'], '3']
#      [['planning', 'simple'], '3']
#      [['prob', 'lem'], '3']
#      [['problem', 's'], '3']
#      [['r', 'information'], '3']
#      [['review', 'vol'], '3']
#      [['science', 'vol'], '3']
#      [['sets', 'include'], '3']
#      [['stage', 'simple'], '3']
#      [['support', 'planning'], '3']
#      [['systems', 'have'], '3']
#      [['used', 'define'], '3']
#      [['accurate', 'inexpensive'], '2']
#      [['accurate', 'information'], '2']
#      [['american', 'psychologist'], '2']
#      [['analysis', 'sequence'], '2']
#      [['analytic', 'technique'], '2']
#      [['appro', 'priate'], '2']
#      [['aspects', 'plan'], '2']
#      [['attrib', 'utes'], '2']
#      [['attributes', 'information'], '2']
#      [['basic', 'books'], '2']
#      [['been', 'used'], '2']
#      [['between', 'environment'], '2']
#      [['c', 'henderson'], '2']
#      [['c', 'nutt'], '2']
#      [['c', 'r'], '2']
#      [['can', 'conceptualized'], '2']
#      [['can', 'constructed'], '2']
#      [['can', 'interpreted'], '2']
#      [['cen', 'tered'], '2']
#      [['centered', 'infor'], '2']
#      [['change', 'agent'], '2']
#      [['columbus', 'ohio'], '2']
#      [['complex', 'environment'], '2']
#      [['complex', 'simple'], '2']
#      [['conceptualization', 'detailing'], '2']
#      [['conceptualization', 'stage'], '2']
#      [['consistency', 'accuracy'], '2']
#      [['consistent', 'accurate'], '2']
#      [['cost', 'complex'], '2']
#      [['cost', 'creativity'], '2']
#      [['cost', 'effec'], '2']
#      [['costs', 'can'], '2']
#      [['d', 'university'], '2']
#      [['de', 'fined'], '2']
#      [['deci', 'sion'], '2']
#      [['defined', 'its'], '2']
#      [['delbecq', 'van'], '2']
#      [['delphi', 'groups'], '2']
#      [['design', 'can'], '2']
#      [['drawn', 'from'], '2']
#      [['each', 'information'], '2']
#      [['effec', 'tive'], '2']
#      [['ences', 'vol'], '2']
#      [['environment', 'information'], '2']
#      [['environmental', 'factors'], '2']
#      [['environments', 'have'], '2']
#      [['environments', 'makes'], '2']
#      [['environments', 'planner'], '2']
#      [['et', 'al'], '2']
#      [['evaluation', 'implementation'], '2']
#      [['faculty', 'management'], '2']
#      [['features', 'linear'], '2']
#      [['field', 'experiments'], '2']
#      [['form', 'i'], '2']
#      [['form', 'r'], '2']
#      [['formation', 'set'], '2']
#      [['formulation', 'conceptualization'], '2']
#      [['genera', 'tion'], '2']
#      [['generate', 'information'], '2']
#      [['have', 'attributes'], '2']
#      [['health', 'planning'], '2']
#      [['high', 'consistency'], '2']
#      [['high', 'creativity'], '2']
#      [['i', 'information'], '2']
#      [['i', 'participation'], '2']
#      [['ideal', 'states'], '2']
#      [['ill', 'defined'], '2']
#      [['implementation', 'prospects'], '2']
#      [['include', 'r'], '2']
#      [['individual', 's'], '2']
#      [['inexpensive', 'creativity'], '2']
#      [['information', 'genera'], '2']
#      [['information', 'generation'], '2']
#      [['information', 'needed'], '2']
#      [['information', 'sys'], '2']
#      [['information', 'using'], '2']
#      [['interac', 'tive'], '2']
#      [['interaction', 'between'], '2']
#      [['its', 'degree'], '2']
#      [['j', 'information'], '2']
#      [['j', 's'], '2']
#      [['john', 'c'], '2']
#      [['judgments', 'based'], '2']
#      [['less', 'important'], '2']
#      [['linear', 'programming'], '2']
#      [['making', 'planning'], '2']
#      [['management', 'sciences'], '2']
#      [['mason', 'mitroff'], '2']
#      [['mason', 'r'], '2']
#      [['mation', 'sets'], '2']
#      [['mation', 'should'], '2']
#      [['may', 'timely'], '2']
#      [['mcgraw', 'hill'], '2']
#      [['ment', 'can'], '2']
#      [['methods', 'can'], '2']
#      [['methods', 'used'], '2']
#      [['mintzberg', 'h'], '2']
#      [['models', 'can'], '2']
#      [['models', 'should'], '2']
#      [['modes', 'environmental'], '2']
#      [['modes', 'r'], '2']
#      [['ning', 'stages'], '2']
#      [['non', 'person'], '2']
#      [['nonperson', 'cen'], '2']
#      [['nutt', 'p'], '2']
#      [['one', 'more'], '2']
#      [['only', 'when'], '2']
#      [['organizational', 'behavior'], '2']
#      [['organizational', 'change'], '2']
#      [['output', 'analysis'], '2']
#      [['p', 'c'], '2']
#      [['p', 'delphi'], '2']
#      [['p', 'information'], '2']
#      [['p', 'p'], '2']
#      [['paul', 'c'], '2']
#      [['performance', 'measures'], '2']
#      [['permit', 'planner'], '2']
#      [['personal', 'experience'], '2']
#      [['ph', 'd'], '2']
#      [['plan', 'complex'], '2']
#      [['plan', 'solutions'], '2']
#      [['plan', 'sponsor'], '2']
#      [['plan', 'sponsors'], '2']
#      [['planner', 'i'], '2']
#      [['planner', 'may'], '2']
#      [['planner', 'uses'], '2']
#      [['planning', 'complex'], '2']
#      [['planning', 'groups'], '2']
#      [['planning', 'prob'], '2']
#      [['planning', 'tasks'], '2']
#      [['planning', 'when'], '2']
#      [['plexity', 'complex'], '2']
#      [['pre', 'ferred'], '2']
#      [['preferred', 'data'], '2']
#      [['preferred', 'infor'], '2']
#      [['problem', 'solving'], '2']
#      [['problems', 'have'], '2']
#      [['program', 'planning'], '2']
#      [['provide', 'formation'], '2']
#      [['psychologist', 'vol'], '2']
#      [['quantitative', 'methods'], '2']
#      [['quarterly', 'vol'], '2']
#      [['r', 'f'], '2']
#      [['r', 'i'], '2']
#      [['r', 'm'], '2']
#      [['re', 'duce'], '2']
#      [['re', 'ports'], '2']
#      [['re', 'search'], '2']
#      [['reduce', 'risk'], '2']
#      [['reduces', 'risk'], '2']
#      [['reports', 'analysis'], '2']
#      [['requirements', 'each'], '2']
#      [['right', 'left'], '2']
#      [['russell', 'sage'], '2']
#      [['s', 'products'], '2']
#      [['sales', 'rates'], '2']
#      [['sci', 'ences'], '2']
#      [['science', 'quarterly'], '2']
#      [['see', 'table'], '2']
#      [['set', 'notation'], '2']
#      [['sets', 'have'], '2']
#      [['sets', 'information'], '2']
#      [['shared', 'power'], '2']
#      [['should', 'lead'], '2']
#      [['simon', 'h'], '2']
#      [['simple', 'planning'], '2']
#      [['solu', 'tion'], '2']
#      [['solution', 'procedures'], '2']
#      [['sponsor', 's'], '2']
#      [['stable', 'environments'], '2']
#      [['stage', 'used'], '2']
#      [['states', 'nature'], '2']
#      [['system', 'attributes'], '2']
#      [['systems', 'complex'], '2']
#      [['systems', 'information'], '2']
#      [['systems', 'like'], '2']
#      [['systems', 'should'], '2']
#      [['tered', 'information'], '2']
#      [['terms', 'can'], '2']
#      [['terms', 'several'], '2']
#      [['th', 'planner'], '2']
#      [['time', 'horizons'], '2']
#      [['timeliness', 'accuracy'], '2']
#      [['timely', 'low'], '2']
#      [['tion', 'generation'], '2']
#      [['two', 'more'], '2']
#      [['used', 'identify'], '2']
#      [['used', 're'], '2']
#      [['ven', 'delbecq'], '2']
#      [['we', 'believe'], '2']
#      [['york', 'basic'], '2']
#      [['york', 'mcgraw'], '2']
#      [['york', 'russell'], '2']
#      [['abilities', 'multi'], '1']
#      [['ability', 'system'], '1']
#      [['about', 'company'], '1']
#      [['about', 'how'], '1']
#      [['ac', 'counts'], '1']
#      [['ac', 'curate'], '1']
#      [['ac', 'tivities'], '1']
#      [['academy', 'management'], '1']
#      [['acceptance', 'con'], '1']
#      [['accountant', 'personnel'], '1']
#      [['accounting', 'environmental'], '1']
#      [['accounting', 'methods'], '1']
#      [['accounting', 'other'], '1']
#      [['accounting', 'reports'], '1']
#      [['accuracy', 'accurate'], '1']
#      [['accuracy', 'con'], '1']
#      [['accuracy', 'consis'], '1']
#      [['accuracy', 'consistency'], '1']
#      [['accuracy', 'etc'], '1']
#      [['accuracy', 'high'], '1']
#      [['accuracy', 'information'], '1']
#      [['accuracy', 'low'], '1']
#      [['accuracy', 'predictable'], '1']
#      [['accuracy', 'well'], '1']
#      [['accurate', 'con'], '1']
#      [['accurate', 'consis'], '1']
#      [['accurate', 'consistent'], '1']
#      [['accurate', 'his'], '1']
#      [['accurately', 'described'], '1']
#      [['achieved', 'without'], '1']
#      [['ackoff', 'emery'], '1']
#      [['ackoff', 'r'], '1']
#      [['acquisition', 'costs'], '1']
#      [['acquisition', 'right'], '1']
#      [['action', 'new'], '1']
#      [['action', 'programs'], '1']
#      [['action', 'tend'], '1']
#      [['activ', 'ities'], '1']
#      [['activities', 'like'], '1']
#      [['activity', 'described'], '1']
#      [['adaptation', 'partially'], '1']
#      [['adapted', 'organizational'], '1']
#      [['adapting', 'solutions'], '1']
#      [['address', 'high'], '1']
#      [['adminis', 'strative'], '1']
#      [['adminis', 'trative'], '1']
#      [['administration', 'faculty'], '1']
#      [['administration', 're'], '1']
#      [['administration', 'review'], '1']
#      [['administrative', 'science'], '1']
#      [['administrator', 'interro'], '1']
#      [['administrator', 'public'], '1']
#      [['administrators', 'framework'], '1']
#      [['administrators', 'often'], '1']
#      [['admissions', 'application'], '1']
#      [['adoption', 'operations'], '1']
#      [['advises', 'client'], '1']
#      [['advocates', 'may'], '1']
#      [['affected', 'avoid'], '1']
#      [['against', 'criteria'], '1']
#      [['age', 'ethnic'], '1']
#      [['agencies', 'have'], '1']
#      [['agent', 'complex'], '1']
#      [['agent', 'who'], '1']
#      [['aggregate', 'combine'], '1']
#      [['aggregate', 'infor'], '1']
#      [['agreement', 'synthesis'], '1']
#      [['aid', 'group'], '1']
#      [['aid', 'planner'], '1']
#      [['aid', 'selection'], '1']
#      [['aided', 'analysis'], '1']
#      [['aids', 'administrator'], '1']
#      [['ail', 'pi'], '1']
#      [['aldine', 'atherton'], '1']
#      [['all', 'formation'], '1']
#      [['all', 'stress'], '1']
#      [['all', 'those'], '1']
#      [['allows', 'planner'], '1']
#      [['alone', 'chance'], '1']
#      [['also', 'been'], '1']
#      [['also', 'can'], '1']
#      [['also', 'consider'], '1']
#      [['also', 'have'], '1']
#      [['also', 'provide'], '1']
#      [['also', 'use'], '1']
#      [['also', 'used'], '1']
#      [['alter', 'native'], '1']
#      [['alternative', 'ar'], '1']
#      [['alternative', 'plan'], '1']
#      [['alters', 'objectives'], '1']
#      [['always', 'places'], '1']
#      [['ambiguity', 'com'], '1']
#      [['amenability', 'solution'], '1']
#      [['american', 'psy'], '1']
#      [['amibiguity', 'planning'], '1']
#      [['among', 'alternative'], '1']
#      [['among', 'experts'], '1']
#      [['among', 'overlapping'], '1']
#      [['amort', 'ized'], '1']
#      [['amortize', 'costs'], '1']
#      [['amortized', 'deterministic'], '1']
#      [['amounts', 'ordered'], '1']
#      [['anal', 'ysis'], '1']
#      [['analy', 'sis'], '1']
#      [['analy', 'tic'], '1']
#      [['analy', 'zability'], '1']
#      [['analysis', 'aided'], '1']
#      [['analysis', 'applied'], '1']
#      [['analysis', 'conceptualize'], '1']
#      [['analysis', 'environmental'], '1']
#      [['analysis', 'examples'], '1']
#      [['analysis', 'features'], '1']
#      [['analysis', 'involves'], '1']
#      [['analysis', 'mode'], '1']
#      [['analysis', 'model'], '1']
#      [['analysis', 'preferred'], '1']
#      [['analysis', 'proposals'], '1']
#      [['analysis', 'reports'], '1']
#      [['analysis', 'sys'], '1']
#      [['analysis', 'utilities'], '1']
#      [['analyst', 'accountant'], '1']
#      [['analyst', 'consultant'], '1']
#      [['analytic', 'methods'], '1']
#      [['analytical', 'infor'], '1']
#      [['analyzed', 'relative'], '1']
#      [['ance', 'against'], '1']
#      [['angeles', 'center'], '1']
#      [['another', 'indi'], '1']
#      [['another', 'individual'], '1']
#      [['application', 'classical'], '1']
#      [['application', 'three'], '1']
#      [['applied', 'behavioral'], '1']
#      [['applied', 'design'], '1']
#      [['applied', 'each'], '1']
#      [['applied', 'imagination'], '1']
#      [['applied', 'particular'], '1']
#      [['applied', 'reports'], '1']
#      [['apply', 'mathematical'], '1']
#      [['apply', 'planning'], '1']
#      [['apply', 'them'], '1']
#      [['approach', 'new'], '1']
#      [['approach', 'p'], '1']
#      [['approach', 'strategic'], '1']
#      [['appropriate', 'evaluation'], '1']
#      [['appropriate', 'sym'], '1']
#      [['ar', 'rangements'], '1']
#      [['areas', 'interactive'], '1']
#      [['argues', 'task'], '1']
#      [['article', 'relate'], '1']
#      [['articulate', 'preferred'], '1']
#      [['artificial', 'cambridge'], '1']
#      [['aspects', 'planning'], '1']
#      [['assess', 'impor'], '1']
#      [['assistant', 'professor'], '1']
#      [['associate', 'professor'], '1']
#      [['associated', 'formal'], '1']
#      [['associated', 'one'], '1']
#      [['assumed', 'information'], '1']
#      [['assumes', 'environment'], '1']
#      [['assumes', 'full'], '1']
#      [['ate', 'disability'], '1']
#      [['ativity', 'carefully'], '1']
#      [['attempt', 'replace'], '1']
#      [['attri', 'butes'], '1']
#      [['attribute', 'utilities'], '1']
#      [['attributes', 'consistency'], '1']
#      [['attributes', 'environment'], '1']
#      [['attributes', 'high'], '1']
#      [['attributes', 'less'], '1']
#      [['attributes', 'more'], '1']
#      [['attributes', 'preferred'], '1']
#      [['attributes', 'simple'], '1']
#      [['attributes', 'thus'], '1']
#      [['attributes', 'timeliness'], '1']
#      [['audits', 'historical'], '1']
#      [['augmented', 'per'], '1']
#      [['aus', 'tin'], '1']
#      [['authority', 'has'], '1']
#      [['automated', 'data'], '1']
#      [['automated', 'systems'], '1']
#      [['automation', 'often'], '1']
#      [['automotive', 'supplier'], '1']
#      [['available', 'administrators'], '1']
#      [['avoid', 'con'], '1']
#      [['avoid', 'reports'], '1']
#      [['b', 'management'], '1']
#      [['b', 'sketch'], '1']
#      [['background', 'other'], '1']
#      [['backoff', 'r'], '1']
#      [['base', 'service'], '1']
#      [['based', 'attributes'], '1']
#      [['based', 'conclusions'], '1']
#      [['based', 'information'], '1']
#      [['based', 'past'], '1']
#      [['based', 'sales'], '1']
#      [['based', 'usage'], '1']
#      [['bases', 'stress'], '1']
#      [['basic', 'cate'], '1']
#      [['basic', 'modes'], '1']
#      [['basis', 'evaluate'], '1']
#      [['because', 'both'], '1']
#      [['because', 'components'], '1']
#      [['because', 'efficient'], '1']
#      [['because', 'environment'], '1']
#      [['because', 'historical'], '1']
#      [['because', 'planning'], '1']
#      [['because', 'precise'], '1']
#      [['because', 'range'], '1']
#      [['becomes', 'objective'], '1']
#      [['been', 'dele'], '1']
#      [['been', 'found'], '1']
#      [['before', 'can'], '1']
#      [['behavior', 'comparative'], '1']
#      [['behavior', 'glenview'], '1']
#      [['behavior', 'hu'], '1']
#      [['behavior', 'necessary'], '1']
#      [['behavioral', 'science'], '1']
#      [['behavioral', 'theory'], '1']
#      [['believe', 'r'], '1']
#      [['believe', 'superior'], '1']
#      [['bell', 's'], '1']
#      [['below', 'while'], '1']
#      [['benefactors', 'regulations'], '1']
#      [['benefactors', 'when'], '1']
#      [['better', 'structured'], '1']
#      [['between', 'existing'], '1']
#      [['between', 'manager'], '1']
#      [['between', 'oc'], '1']
#      [['between', 'planner'], '1']
#      [['between', 'sponsor'], '1']
#      [['between', 'two'], '1']
#      [['bias', 'may'], '1']
#      [['ble', 'environments'], '1']
#      [['ble', 'over'], '1']
#      [['bol', 'f'], '1']
#      [['bono', 'e'], '1']
#      [['books', 'often'], '1']
#      [['both', 'criteria'], '1']
#      [['both', 'develop'], '1']
#      [['both', 'shifting'], '1']
#      [['boundary', 'span'], '1']
#      [['brainstorm', 'ing'], '1']
#      [['brainstorming', 'i'], '1']
#      [['brainstorming', 'p'], '1']
#      [['brainwriting', 'cooptation'], '1']
#      [['brainwriting', 'p'], '1']
#      [['broken', 'manageable'], '1']
#      [['broker', 'advises'], '1']
#      [['brooks', 'cole'], '1']
#      [['budgets', 'shifting'], '1']
#      [['build', 'informal'], '1']
#      [['builds', 'alternative'], '1']
#      [['built', 'permit'], '1']
#      [['built', 'through'], '1']
#      [['bureau', 'economic'], '1']
#      [['business', 'research'], '1']
#      [['business', 'review'], '1']
#      [['butes', 'high'], '1']
#      [['buy', 'particular'], '1']
#      [['c', 'experimental'], '1']
#      [['c', 'h'], '1']
#      [['c', 'models'], '1']
#      [['c', 'urban'], '1']
#      [['c', 'w'], '1']
#      [['cahoon', 'w'], '1']
#      [['cal', 'form'], '1']
#      [['cal', 'precedent'], '1']
#      [['call', 'upon'], '1']
#      [['calls', 'change'], '1']
#      [['cambridge', 'mass'], '1']
#      [['camp', 'bell'], '1']
#      [['campbell', 'd'], '1']
#      [['can', 'achieved'], '1']
#      [['can', 'amort'], '1']
#      [['can', 'amortized'], '1']
#      [['can', 'applied'], '1']
#      [['can', 'apply'], '1']
#      [['can', 'built'], '1']
#      [['can', 'de'], '1']
#      [['can', 'defined'], '1']
#      [['can', 'described'], '1']
#      [['can', 'fully'], '1']
#      [['can', 'identified'], '1']
#      [['can', 'identify'], '1']
#      [['can', 'improved'], '1']
#      [['can', 'justified'], '1']
#      [['can', 'ob'], '1']
#      [['can', 'obtained'], '1']
#      [['can', 'operationalized'], '1']
#      [['can', 'provided'], '1']
#      [['can', 'quite'], '1']
#      [['can', 'reasonably'], '1']
#      [['can', 'sub'], '1']
#      [['can', 'understood'], '1']
#      [['can', 'use'], '1']
#      [['can', 'useful'], '1']
#      [['can', 'yield'], '1']
#      [['careful', 'formulation'], '1']
#      [['carefully', 'managed'], '1']
#      [['carefully', 'selected'], '1']
#      [['case', 'study'], '1']
#      [['cate', 'gories'], '1']
#      [['cated', 'techniques'], '1']
#      [['categorizing', 'level'], '1']
#      [['cause', 'effect'], '1']
#      [['cedures', 'demand'], '1']
#      [['ceived', 'value'], '1']
#      [['center', 'advocates'], '1']
#      [['center', 'information'], '1']
#      [['centered', 'costly'], '1']
#      [['centered', 'data'], '1']
#      [['centered', 'details'], '1']
#      [['centered', 'informa'], '1']
#      [['centered', 'person'], '1']
#      [['centered', 'sources'], '1']
#      [['centered', 'type'], '1']
#      [['centers', 'can'], '1']
#      [['ceptualized', 'listing'], '1']
#      [['certain', 'resources'], '1']
#      [['certainty', 'under'], '1']
#      [['cessful', 'past'], '1']
#      [['chance', 'particular'], '1']
#      [['change', 'agents'], '1']
#      [['change', 'dalton'], '1']
#      [['change', 'development'], '1']
#      [['change', 'ganizatio'], '1']
#      [['change', 'ganizational'], '1']
#      [['change', 'organization'], '1']
#      [['change', 'read'], '1']
#      [['change', 'strategy'], '1']
#      [['change', 'well'], '1']
#      [['changes', 'complex'], '1']
#      [['changes', 'from'], '1']
#      [['changes', 'performance'], '1']
#      [['changes', 'plan'], '1']
#      [['changes', 'stimulated'], '1']
#      [['changes', 'thus'], '1']
#      [['changing', 'environment'], '1']
#      [['chaos', 'new'], '1']
#      [['check', 'ing'], '1']
#      [['checks', 'agreement'], '1']
#      [['checks', 'represent'], '1']
#      [['chicago', 'aldine'], '1']
#      [['chologists', 'vol'], '1']
#      [['churchman', 'c'], '1']
#      [['chy', 'objectives'], '1']
#      [['clasen', 'evaluation'], '1']
#      [['classi', 'cal'], '1']
#      [['classical', 'problem'], '1']
#      [['clear', 'cut'], '1']
#      [['client', 'buy'], '1']
#      [['client', 'participation'], '1']
#      [['clinical', 'judgments'], '1']
#      [['closely', 'associated'], '1']
#      [['coerce', 'planner'], '1']
#      [['col', 'lect'], '1']
#      [['college', 'adminis'], '1']
#      [['com', 'ponents'], '1']
#      [['combine', 'formation'], '1']
#      [['commissions', 'often'], '1']
#      [['common', 'example'], '1']
#      [['communicating', 'employees'], '1']
#      [['communication', 'systems'], '1']
#      [['company', 'found'], '1']
#      [['comparable', 'settings'], '1']
#      [['comparative', 'administration'], '1']
#      [['comparative', 'study'], '1']
#      [['comparatively', 'long'], '1']
#      [['comparison', 'adaptation'], '1']
#      [['comparison', 'effective'], '1']
#      [['competitors', 'has'], '1']
#      [['complex', 'among'], '1']
#      [['complex', 'because'], '1']
#      [['complex', 'conditions'], '1']
#      [['complex', 'marketing'], '1']
#      [['complex', 'p'], '1']
#      [['complex', 'plan'], '1']
#      [['complexity', 'de'], '1']
#      [['complexity', 'environmental'], '1']
#      [['complexity', 'example'], '1']
#      [['complexity', 'informa'], '1']
#      [['complexity', 'propositions'], '1']
#      [['complexity', 'terms'], '1']
#      [['complexity', 'used'], '1']
#      [['complexity', 'when'], '1']
#      [['component', 'defined'], '1']
#      [['components', 'builds'], '1']
#      [['components', 'morphol'], '1']
#      [['components', 'morphology'], '1']
#      [['components', 'new'], '1']
#      [['components', 'planning'], '1']
#      [['components', 'relationships'], '1']
#      [['components', 'two'], '1']
#      [['comprehensive', 'flow'], '1']
#      [['computer', 'simulation'], '1']
#      [['computerized', 'reports'], '1']
#      [['con', 'ceptualized'], '1']
#      [['con', 'fusion'], '1']
#      [['con', 'sidered'], '1']
#      [['con', 'sistency'], '1']
#      [['con', 'sistent'], '1']
#      [['con', 'trol'], '1']
#      [['concep', 'tual'], '1']
#      [['concept', 'stage'], '1']
#      [['conceptualization', 'complex'], '1']
#      [['conceptualization', 'planning'], '1']
#      [['conceptualize', 'innovative'], '1']
#      [['conceptualize', 'planning'], '1']
#      [['conceptualized', 'broken'], '1']
#      [['conceptualized', 'using'], '1']
#      [['conclusions', 'developing'], '1']
#      [['conclusions', 'drawn'], '1']
#      [['concurrence', 'among'], '1']
#      [['conditions', 'formulation'], '1']
#      [['conditions', 'repeated'], '1']
#      [['conditions', 'semi'], '1']
#      [['conduct', 'planning'], '1']
#      [['conference', 'board'], '1']
#      [['consider', 'attributes'], '1']
#      [['consider', 'demands'], '1']
#      [['consider', 'environment'], '1']
#      [['considered', 'article'], '1']
#      [['considered', 'design'], '1']
#      [['consis', 'tency'], '1']
#      [['consis', 'tent'], '1']
#      [['consistency', 'complex'], '1']
#      [['consistency', 'consistent'], '1']
#      [['consistency', 'precision'], '1']
#      [['consistency', 'represent'], '1']
#      [['consistency', 'stems'], '1']
#      [['consistency', 'timeli'], '1']
#      [['consistent', 'churchman'], '1']
#      [['consistent', 'example'], '1']
#      [['consistent', 'information'], '1']
#      [['consistent', 'than'], '1']
#      [['consistent', 'timely'], '1']
#      [['constant', 'conditions'], '1']
#      [['constraints', 'budget'], '1']
#      [['constraints', 'placed'], '1']
#      [['constructed', 'john'], '1']
#      [['constructed', 'which'], '1']
#      [['consultant', 'common'], '1']
#      [['consuming', 'strategies'], '1']
#      [['contact', 'plan'], '1']
#      [['contain', 'bias'], '1']
#      [['contains', 'information'], '1']
#      [['contends', 'unfreezing'], '1']
#      [['contextual', 'variables'], '1']
#      [['contin', 'ue'], '1']
#      [['contingencies', 'model'], '1']
#      [['contingent', 'model'], '1']
#      [['convenience', 'final'], '1']
#      [['cooptation', 'p'], '1']
#      [['cost', 'cost'], '1']
#      [['cost', 'incurred'], '1']
#      [['cost', 'one'], '1']
#      [['cost', 'settings'], '1']
#      [['cost', 'through'], '1']
#      [['cost', 'timeliness'], '1']
#      [['cost', 'using'], '1']
#      [['cost', 'variance'], '1']
#      [['costly', 'develop'], '1']
#      [['costs', 'automated'], '1']
#      [['costs', 'costs'], '1']
#      [['costs', 'forecasting'], '1']
#      [['costs', 'quality'], '1']
#      [['costs', 'up'], '1']
#      [['could', 'adapted'], '1']
#      [['could', 'described'], '1']
#      [['could', 'treated'], '1']
#      [['counts', 'major'], '1']
#      [['cpm', 'input'], '1']
#      [['cre', 'ativity'], '1']
#      [['creativ', 'ity'], '1']
#      [['creative', 'accurate'], '1']
#      [['creative', 'consistent'], '1']
#      [['creativity', 'because'], '1']
#      [['creativity', 'cost'], '1']
#      [['creativity', 'creativity'], '1']
#      [['creativity', 'diminishes'], '1']
#      [['creativity', 'individ'], '1']
#      [['creativity', 'lacking'], '1']
#      [['creativity', 'modest'], '1']
#      [['creativity', 're'], '1']
#      [['creativity', 'reduces'], '1']
#      [['creativity', 'refers'], '1']
#      [['creativity', 'reports'], '1']
#      [['creativity', 'seldom'], '1']
#      [['creativity', 'simple'], '1']
#      [['creativity', 'thus'], '1']
#      [['credibility', 'nature'], '1']
#      [['cretion', 'goals'], '1']
#      [['criteria', 'cause'], '1']
#      [['criteria', 'evaluate'], '1']
#      [['criteria', 'exception'], '1']
#      [['criteria', 'firms'], '1']
#      [['criteria', 'sketching'], '1']
#      [['criterion', 'checks'], '1']
#      [['criterion', 'decision'], '1']
#      [['critical', 'path'], '1']
#      [['critically', 'important'], '1']
#      [['cular', 'time'], '1']
#      [['curate', 'less'], '1']
#      [['cure', 'chaos'], '1']
#      [['currence', 'need'], '1']
#      [['current', 'ideal'], '1']
#      [['current', 'practices'], '1']
#      [['cut', 'solution'], '1']
#      [['cyert', 'r'], '1']
#      [['d', 'c'], '1']
#      [['d', 'h'], '1']
#      [['d', 'organizations'], '1']
#      [['d', 'r'], '1']
#      [['d', 'raisinghani'], '1']
#      [['d', 't'], '1']
#      [['dalton', 'g'], '1']
#      [['danger', 'change'], '1']
#      [['data', 'acquisition'], '1']
#      [['data', 'bases'], '1']
#      [['data', 'can'], '1']
#      [['data', 'evaluation'], '1']
#      [['data', 'files'], '1']
#      [['data', 'have'], '1']
#      [['data', 'processing'], '1']
#      [['data', 'reduction'], '1']
#      [['data', 'stable'], '1']
#      [['data', 'system'], '1']
#      [['davis', 'g'], '1']
#      [['dawes', 'r'], '1']
#      [['de', 'bono'], '1']
#      [['de', 'rived'], '1']
#      [['de', 'termine'], '1']
#      [['deal', 'one'], '1']
#      [['deal', 'planning'], '1']
#      [['dearden', 'j'], '1']
#      [['decision', 'based'], '1']
#      [['decision', 'mak'], '1']
#      [['decision', 'making'], '1']
#      [['decision', 'processed'], '1']
#      [['decision', 'rules'], '1']
#      [['decision', 'sci'], '1']
#      [['decision', 'sciences'], '1']
#      [['decision', 'social'], '1']
#      [['decision', 'style'], '1']
#      [['decision', 'variable'], '1']
#      [['decisions', 'henderson'], '1']
#      [['decisions', 'under'], '1']
#      [['decomposing', 'planning'], '1']
#      [['decomposition', 'strategy'], '1']
#      [['decree', 'can'], '1']
#      [['define', 'analy'], '1']
#      [['define', 'existing'], '1']
#      [['define', 'needs'], '1']
#      [['define', 'simple'], '1']
#      [['defined', 'data'], '1']
#      [['defined', 'discrepancy'], '1']
#      [['defined', 'models'], '1']
#      [['defined', 'plan'], '1']
#      [['defined', 'planning'], '1']
#      [['defined', 'problems'], '1']
#      [['defining', 'simple'], '1']
#      [['definition', 'solution'], '1']
#      [['degree', 'homo'], '1']
#      [['degree', 'stability'], '1']
#      [['delay', 'between'], '1']
#      [['delbecq', 'et'], '1']
#      [['delbecq', 'g'], '1']
#      [['delbecq', 'task'], '1']
#      [['dele', 'gated'], '1']
#      [['delegation', 'analysis'], '1']
#      [['delegation', 'im'], '1']
#      [['delegation', 'strat'], '1']
#      [['delimits', 'participation'], '1']
#      [['delphi', 'p'], '1']
#      [['delphi', 'panels'], '1']
#      [['delphi', 'surveys'], '1']
#      [['demand', 'factors'], '1']
#      [['demands', 'organization'], '1']
#      [['demands', 'planning'], '1']
#      [['demands', 'regression'], '1']
#      [['demonstrates', 'deci'], '1']
#      [['departures', 'from'], '1']
#      [['depending', 'upon'], '1']
#      [['depicts', 'nature'], '1']
#      [['derived', 'from'], '1']
#      [['describe', 'desirable'], '1']
#      [['describe', 'ideal'], '1']
#      [['describe', 'nodes'], '1']
#      [['described', 'highly'], '1']
#      [['described', 'i'], '1']
#      [['described', 'lewin'], '1']
#      [['described', 'one'], '1']
#      [['described', 'p'], '1']
#      [['described', 'person'], '1']
#      [['described', 'process'], '1']
#      [['described', 'proposition'], '1']
#      [['described', 'using'], '1']
#      [['describes', 'generation'], '1']
#      [['describes', 'node'], '1']
#      [['describes', 'one'], '1']
#      [['describes', 'use'], '1']
#      [['describing', 'its'], '1']
#      [['design', 'form'], '1']
#      [['design', 'georgetown'], '1']
#      [['design', 'has'], '1']
#      [['design', 'information'], '1']
#      [['design', 'inquiring'], '1']
#      [['design', 'nonperson'], '1']
#      [['design', 'p'], '1']
#      [['design', 'post'], '1']
#      [['design', 'proposed'], '1']
#      [['design', 'r'], '1']
#      [['design', 'related'], '1']
#      [['design', 'should'], '1']
#      [['design', 'specified'], '1']
#      [['designing', 'planning'], '1']
#      [['designing', 'viking'], '1']
#      [['designs', 'can'], '1']
#      [['designs', 'described'], '1']
#      [['designs', 'each'], '1']
#      [['designs', 'far'], '1']
#      [['designs', 'often'], '1']
#      [['designs', 'planning'], '1']
#      [['designs', 'required'], '1']
#      [['desirable', 'features'], '1']
#      [['desirable', 'information'], '1']
#      [['desirable', 'state'], '1']
#      [['detail', 'alter'], '1']
#      [['detail', 'example'], '1']
#      [['detail', 'plan'], '1']
#      [['detailing', 'stage'], '1']
#      [['details', 'each'], '1']
#      [['determinants', 'planning'], '1']
#      [['determine', 'how'], '1']
#      [['determine', 'why'], '1']
#      [['determined', 'information'], '1']
#      [['deterministic', 'features'], '1']
#      [['devel', 'oped'], '1']
#      [['develop', 'plan'], '1']
#      [['developed', 'illustrate'], '1']
#      [['developing', 'large'], '1']
#      [['development', 'homewood'], '1']
#      [['development', 'new'], '1']
#      [['development', 'time'], '1']
#      [['device', 'which'], '1']
#      [['devices', 'form'], '1']
#      [['devices', 'we'], '1']
#      [['diagnostic', 'information'], '1']
#      [['dialectic', 'information'], '1']
#      [['dialectical', 'approach'], '1']
#      [['dictable', 'past'], '1']
#      [['dictated', 'nature'], '1']
#      [['dif', 'ferences'], '1']
#      [['differ', 'low'], '1']
#      [['differences', 'p'], '1']
#      [['difficult', 'amortize'], '1']
#      [['difficult', 'ob'], '1']
#      [['diminishes', 'creativity'], '1']
#      [['diminishes', 'risk'], '1']
#      [['direct', 'systematic'], '1']
#      [['direction', 'magnitude'], '1']
#      [['dis', 'cretion'], '1']
#      [['disability', 'mortality'], '1']
#      [['disaggregated', 'systems'], '1']
#      [['discovery', 'invention'], '1']
#      [['discrepancy', 'between'], '1']
#      [['discretion', 'who'], '1']
#      [['discussion', 'another'], '1']
#      [['discussion', 'perhaps'], '1']
#      [['disproportion', 'ate'], '1']
#      [['distributed', 'all'], '1']
#      [['distribution', 'problem'], '1']
#      [['divided', 'form'], '1']
#      [['do', 'apply'], '1']
#      [['does', 'deal'], '1']
#      [['domain', 'its'], '1']
#      [['down', 'sponsor'], '1']
#      [['draw', 'his'], '1']
#      [['drawn', 'simple'], '1']
#      [['duce', 'amibiguity'], '1']
#      [['duce', 'risk'], '1']
#      [['duffy', 'j'], '1']
#      [['dures', 'known'], '1']
#      [['during', 'detailing'], '1']
#      [['during', 'formalization'], '1']
#      [['during', 'plan'], '1']
#      [['dynamics', 'environment'], '1']
#      [['e', 'b'], '1']
#      [['e', 'clasen'], '1']
#      [['e', 'evaluation'], '1']
#      [['e', 'g'], '1']
#      [['e', 'new'], '1']
#      [['e', 'patterns'], '1']
#      [['each', 'basic'], '1']
#      [['each', 'component'], '1']
#      [['each', 'criteria'], '1']
#      [['each', 'criterion'], '1']
#      [['each', 'design'], '1']
#      [['each', 'influenced'], '1']
#      [['each', 'phase'], '1']
#      [['each', 'planning'], '1']
#      [['each', 'qualification'], '1']
#      [['each', 'should'], '1']
#      [['each', 'terms'], '1']
#      [['economic', 'business'], '1']
#      [['education', 'background'], '1']
#      [['education', 'itasca'], '1']
#      [['effect', 'relations'], '1']
#      [['effective', 'ness'], '1']
#      [['effectiveness', 'complex'], '1']
#      [['effectiveness', 'literature'], '1']
#      [['efficient', 'task'], '1']
#      [['effort', 'particular'], '1']
#      [['effort', 'should'], '1']
#      [['effort', 'similarly'], '1']
#      [['efforts', 'can'], '1']
#      [['egy', 'assumes'], '1']
#      [['el', 'feasible'], '1']
#      [['el', 'personalized'], '1']
#      [['el', 'problem'], '1']
#      [['elementary', 'nodes'], '1']
#      [['els', 'often'], '1']
#      [['emery', 'purposefulsystem'], '1']
#      [['empha', 'sized'], '1']
#      [['employees', 'studies'], '1']
#      [['en', 'hances'], '1']
#      [['ence', 'type'], '1']
#      [['ences', 'high'], '1']
#      [['end', 'implicit'], '1']
#      [['enhance', 'intuitive'], '1']
#      [['enhances', 'creativity'], '1']
#      [['enhancing', 'implementation'], '1']
#      [['enironmental', 'personal'], '1']
#      [['envi', 'ronment'], '1']
#      [['environment', 'assumed'], '1']
#      [['environment', 'attributes'], '1']
#      [['environment', 'can'], '1']
#      [['environment', 'complex'], '1']
#      [['environment', 'formulation'], '1']
#      [['environment', 'has'], '1']
#      [['environment', 'make'], '1']
#      [['environment', 'personal'], '1']
#      [['environment', 'planning'], '1']
#      [['environment', 'pre'], '1']
#      [['environment', 'relationship'], '1']
#      [['environment', 'requires'], '1']
#      [['environment', 'results'], '1']
#      [['environment', 'well'], '1']
#      [['environmental', 'dif'], '1']
#      [['environmental', 'differences'], '1']
#      [['environmental', 'enironmental'], '1']
#      [['environmental', 'features'], '1']
#      [['environmental', 'settings'], '1']
#      [['environments', 'ambiguity'], '1']
#      [['environments', 'analytical'], '1']
#      [['environments', 'attrib'], '1']
#      [['environments', 'because'], '1']
#      [['environments', 'can'], '1']
#      [['environments', 'complex'], '1']
#      [['environments', 'data'], '1']
#      [['environments', 'designs'], '1']
#      [['environments', 'evaluation'], '1']
#      [['environments', 'implementation'], '1']
#      [['environments', 'interactive'], '1']
#      [['environments', 'lack'], '1']
#      [['environments', 'non'], '1']
#      [['environments', 'permit'], '1']
#      [['environments', 'planners'], '1']
#      [['environments', 'predictability'], '1']
#      [['environments', 'proposition'], '1']
#      [['environments', 'provide'], '1']
#      [['environments', 'purpose'], '1']
#      [['environments', 'quantitative'], '1']
#      [['environments', 'reports'], '1']
#      [['environments', 'requires'], '1']
#      [['environments', 'see'], '1']
#      [['environments', 'stages'], '1']
#      [['environments', 'synthesis'], '1']
#      [['environments', 'we'], '1']
#      [['eoq', 'models'], '1']
#      [['erogeneous', 'subject'], '1']
#      [['error', 'free'], '1']
#      [['error', 'part'], '1']
#      [['es', 'tablished'], '1']
#      [['essential', 'changes'], '1']
#      [['essential', 'enhancing'], '1']
#      [['essential', 'further'], '1']
#      [['essential', 'preferred'], '1']
#      [['essentially', 'person'], '1']
#      [['esteem', 'reinforces'], '1']
#      [['estimates', 'made'], '1']
#      [['etc', 'p'], '1']
#      [['etc', 'reports'], '1']
#      [['etc', 'table'], '1']
#      [['ethnic', 'group'], '1']
#      [['eval', 'uated'], '1']
#      [['evaluate', 'formal'], '1']
#      [['evaluate', 'plan'], '1']
#      [['evaluation', 'analytic'], '1']
#      [['evaluation', 'complex'], '1']
#      [['evaluation', 'education'], '1']
#      [['evaluation', 'information'], '1']
#      [['evaluation', 'plan'], '1']
#      [['evaluation', 'planning'], '1']
#      [['evaluation', 'policy'], '1']
#      [['evaluation', 'research'], '1']
#      [['evaluation', 'review'], '1']
#      [['evaluation', 'stage'], '1']
#      [['evaluation', 'stages'], '1']
#      [['evaluation', 'tends'], '1']
#      [['even', 'general'], '1']
#      [['even', 'sophisti'], '1']
#      [['ex', 'ist'], '1']
#      [['ex', 'perts'], '1']
#      [['ex', 'ploited'], '1']
#      [['exam', 'ple'], '1']
#      [['examined', 'terms'], '1']
#      [['example', 'broker'], '1']
#      [['example', 'consider'], '1']
#      [['example', 'formation'], '1']
#      [['example', 'groups'], '1']
#      [['example', 'habbe'], '1']
#      [['example', 'health'], '1']
#      [['example', 'multidisciplinary'], '1']
#      [['example', 'opinions'], '1']
#      [['example', 'personal'], '1']
#      [['example', 'tends'], '1']
#      [['example', 'when'], '1']
#      [['examples', 'information'], '1']
#      [['examples', 'mason'], '1']
#      [['excep', 'tion'], '1']
#      [['exception', 'checks'], '1']
#      [['exception', 'reports'], '1']
#      [['executive', 'information'], '1']
#      [['existing', 'state'], '1']
#      [['existing', 'states'], '1']
#      [['expand', 'upon'], '1']
#      [['expected', 'performance'], '1']
#      [['expensive', 'time'], '1']
#      [['experi', 'ences'], '1']
#      [['experience', 'build'], '1']
#      [['experience', 'contains'], '1']
#      [['experience', 'criterion'], '1']
#      [['experience', 'diagnostic'], '1']
#      [['experience', 'j'], '1']
#      [['experience', 'neighbor'], '1']
#      [['experience', 'pi'], '1']
#      [['experience', 'reduce'], '1']
#      [['experience', 'training'], '1']
#      [['experiences', 'comparable'], '1']
#      [['experiences', 'education'], '1']
#      [['experiences', 'similar'], '1']
#      [['experimental', 'comparison'], '1']
#      [['experiments', 'reporting'], '1']
#      [['expert', 'groups'], '1']
#      [['experts', 'can'], '1']
#      [['experts', 'data'], '1']
#      [['experts', 'higher'], '1']
#      [['experts', 'provided'], '1']
#      [['explain', 'qualify'], '1']
#      [['explore', 'ill'], '1']
#      [['exploring', 're'], '1']
#      [['extent', 'authority'], '1']
#      [['extent', 'possible'], '1']
#      [['extent', 'solution'], '1']
#      [['f', 'applied'], '1']
#      [['f', 'discovery'], '1']
#      [['f', 'emery'], '1']
#      [['f', 'problem'], '1']
#      [['f', 'process'], '1']
#      [['f', 'q'], '1']
#      [['f', 'u'], '1']
#      [['fac', 'tors'], '1']
#      [['factors', 'also'], '1']
#      [['factors', 'factors'], '1']
#      [['factors', 'may'], '1']
#      [['factors', 'planner'], '1']
#      [['factors', 'planning'], '1']
#      [['factors', 'quantifiability'], '1']
#      [['factors', 'used'], '1']
#      [['fail', 'address'], '1']
#      [['far', 'more'], '1']
#      [['feasible', 'only'], '1']
#      [['features', 'information'], '1']
#      [['features', 'prior'], '1']
#      [['features', 'simple'], '1']
#      [['features', 'stable'], '1']
#      [['federal', 'evaluation'], '1']
#      [['ferences', 'instance'], '1']
#      [['ferred', 'because'], '1']
#      [['ferred', 'information'], '1']
#      [['few', 'competitors'], '1']
#      [['fewer', 'constraints'], '1']
#      [['files', 'books'], '1']
#      [['filley', 'c'], '1']
#      [['final', 'p'], '1']
#      [['financial', 'analysis'], '1']
#      [['find', 'optimum'], '1']
#      [['find', 'programs'], '1']
#      [['finding', 'indus'], '1']
#      [['fined', 'terms'], '1']
#      [['fined', 'thus'], '1']
#      [['firm', 'new'], '1']
#      [['firms', 'simple'], '1']
#      [['five', 'planning'], '1']
#      [['flexibility', 'cre'], '1']
#      [['flow', 'components'], '1']
#      [['flow', 'organization'], '1']
#      [['focusing', 'creativity'], '1']
#      [['followed', 'discussion'], '1']
#      [['following', 'proposi'], '1']
#      [['follows', 'p'], '1']
#      [['force', 'coerce'], '1']
#      [['force', 'report'], '1']
#      [['forces', 'commissions'], '1']
#      [['forecasting', 'sales'], '1']
#      [['forecasts', 'new'], '1']
#      [['fores', 'man'], '1']
#      [['foresman', 'co'], '1']
#      [['form', 'several'], '1']
#      [['form', 'transportation'], '1']
#      [['formal', 'analy'], '1']
#      [['formal', 'informal'], '1']
#      [['formal', 'information'], '1']
#      [['formal', 'manipulation'], '1']
#      [['formalization', 'stage'], '1']
#      [['formance', 'organization'], '1']
#      [['formation', 'about'], '1']
#      [['formation', 'accurate'], '1']
#      [['formation', 'environments'], '1']
#      [['formation', 'from'], '1']
#      [['formation', 'generating'], '1']
#      [['formation', 'needed'], '1']
#      [['formation', 'notational'], '1']
#      [['formation', 'permits'], '1']
#      [['formation', 'sets'], '1']
#      [['formation', 'simple'], '1']
#      [['formation', 'sources'], '1']
#      [['formation', 'those'], '1']
#      [['formation', 'use'], '1']
#      [['formed', 'explore'], '1']
#      [['formed', 'using'], '1']
#      [['formu', 'lation'], '1']
#      [['formulate', 'plan'], '1']
#      [['formulated', 'when'], '1']
#      [['formulation', 'planning'], '1']
#      [['formulation', 'stage'], '1']
#      [['found', 'appropriate'], '1']
#      [['found', 'complex'], '1']
#      [['found', 'nearly'], '1']
#      [['found', 'overcome'], '1']
#      [['found', 'preferred'], '1']
#      [['found', 'simple'], '1']
#      [['found', 'top'], '1']
#      [['foundations', 'structure'], '1']
#      [['four', 'ways'], '1']
#      [['framework', 'historical'], '1']
#      [['framework', 'management'], '1']
#      [['framework', 'suggested'], '1']
#      [['framework', 'suggests'], '1']
#      [['free', 'standardization'], '1']
#      [['frequency', 'occurrence'], '1']
#      [['frequent', 'unique'], '1']
#      [['from', 'analysis'], '1']
#      [['from', 'concurrence'], '1']
#      [['from', 'cost'], '1']
#      [['from', 'experience'], '1']
#      [['from', 'hierar'], '1']
#      [['from', 'i'], '1']
#      [['from', 'manipulative'], '1']
#      [['from', 'non'], '1']
#      [['from', 'past'], '1']
#      [['from', 'planners'], '1']
#      [['from', 'predicta'], '1']
#      [['from', 'simple'], '1']
#      [['from', 'standardization'], '1']
#      [['from', 'synthesis'], '1']
#      [['from', 'variety'], '1']
#      [['from', 'various'], '1']
#      [['full', 'client'], '1']
#      [['fully', 'describing'], '1']
#      [['fully', 'ex'], '1']
#      [['funkumoto', 'l'], '1']
#      [['further', 'unex'], '1']
#      [['fusion', 'insure'], '1']
#      [['g', 'b'], '1']
#      [['g', 'duffy'], '1']
#      [['g', 'h'], '1']
#      [['g', 'linear'], '1']
#      [['g', 'march'], '1']
#      [['g', 'miller'], '1']
#      [['g', 'p'], '1']
#      [['g', 'w'], '1']
#      [['g', 'wallester'], '1']
#      [['g', 'work'], '1']
#      [['gain', 'plan'], '1']
#      [['gained', 'through'], '1']
#      [['gaither', 'n'], '1']
#      [['ganizatio', 'nal'], '1']
#      [['ganization', 'extent'], '1']
#      [['ganizational', 'change'], '1']
#      [['gated', 'planner'], '1']
#      [['gathered', 'talking'], '1']
#      [['gating', 'model'], '1']
#      [['geneity', 'its'], '1']
#      [['geneous', 'goals'], '1']
#      [['general', 'categorizing'], '1']
#      [['general', 'form'], '1']
#      [['generally', 'planning'], '1']
#      [['generate', 'planning'], '1']
#      [['generated', 'from'], '1']
#      [['generated', 'via'], '1']
#      [['generating', 'activity'], '1']
#      [['generating', 'devices'], '1']
#      [['generating', 'information'], '1']
#      [['generation', 'complex'], '1']
#      [['generation', 'general'], '1']
#      [['generation', 'information'], '1']
#      [['generation', 'sequence'], '1']
#      [['generation', 'should'], '1']
#      [['georgetown', 'ontario'], '1']
#      [['get', 'others'], '1']
#      [['given', 'partic'], '1']
#      [['given', 'set'], '1']
#      [['given', 'stocks'], '1']
#      [['gleaned', 'from'], '1']
#      [['glenview', 'iii'], '1']
#      [['glenview', 'ill'], '1']
#      [['goals', 'change'], '1']
#      [['goals', 'stable'], '1']
#      [['goldberg', 'l'], '1']
#      [['gories', 'information'], '1']
#      [['gorry', 's'], '1']
#      [['gottman', 'j'], '1']
#      [['graduate', 'admissions'], '1']
#      [['graduate', 'pro'], '1']
#      [['gram', 'hospital'], '1']
#      [['gramming', 'accounting'], '1']
#      [['grei', 'ner'], '1']
#      [['greiner', 'l'], '1']
#      [['group', 'decision'], '1']
#      [['group', 'has'], '1']
#      [['group', 'pro'], '1']
#      [['group', 'process'], '1']
#      [['group', 'processes'], '1']
#      [['group', 'techniques'], '1']
#      [['group', 'through'], '1']
#      [['groups', 'attempt'], '1']
#      [['groups', 'de'], '1']
#      [['groups', 'delphi'], '1']
#      [['groups', 'experts'], '1']
#      [['groups', 'have'], '1']
#      [['groups', 'information'], '1']
#      [['groups', 'input'], '1']
#      [['groups', 'multiattributes'], '1']
#      [['groups', 'new'], '1']
#      [['groups', 'nominal'], '1']
#      [['groups', 'organizational'], '1']
#      [['groups', 'p'], '1']
#      [['groups', 'should'], '1']
#      [['groups', 'technique'], '1']
#      [['guide', 'planning'], '1']
#      [['guides', 'known'], '1']
#      [['guides', 'suc'], '1']
#      [['guides', 'users'], '1']
#      [['gustafson', 'd'], '1']
#      [['gustafson', 'group'], '1']
#      [['h', 'd'], '1']
#      [['h', 'g'], '1']
#      [['h', 'gustafson'], '1']
#      [['h', 'j'], '1']
#      [['h', 'nature'], '1']
#      [['h', 'newell'], '1']
#      [['h', 'r'], '1']
#      [['h', 'sciences'], '1']
#      [['h', 'simon'], '1']
#      [['habbe', 's'], '1']
#      [['had', 'successful'], '1']
#      [['half', 'information'], '1']
#      [['hances', 'implementation'], '1']
#      [['harper', 'row'], '1']
#      [['harvard', 'business'], '1']
#      [['has', 'attri'], '1']
#      [['has', 'disproportion'], '1']
#      [['has', 'high'], '1']
#      [['has', 'known'], '1']
#      [['has', 'simple'], '1']
#      [['have', 'also'], '1']
#      [['have', 'both'], '1']
#      [['have', 'clear'], '1']
#      [['have', 'credibility'], '1']
#      [['have', 'form'], '1']
#      [['have', 'had'], '1']
#      [['have', 'high'], '1']
#      [['have', 'higher'], '1']
#      [['have', 'histori'], '1']
#      [['have', 'less'], '1']
#      [['have', 'per'], '1']
#      [['have', 'similar'], '1']
#      [['have', 'tributes'], '1']
# ...
#      [['style', 'its'], '1']
#      [['style', 'other'], '1']
#      [['sub', 'stantially'], '1']
#      [['subdivided', 'provide'], '1']
#      [['subject', 'many'], '1']
#      [['subjective', 'aspects'], '1']
#      [['subjective', 'data'], '1']
#      [['subjective', 'likelihood'], '1']
#      [['subjective', 'prob'], '1']
#      [['substan', 'tial'], '1']
#      [['suc', 'cessful'], '1']
#      [['successful', 'implementation'], '1']
#      [['successful', 'outcome'], '1']
#      [['successful', 'plans'], '1']
#      [['suchman', 'e'], '1']
#      [['suggest', 'four'], '1']
#      [['suggest', 'inappropriate'], '1']
#      [['suggest', 'various'], '1']
#      [['suggested', 'here'], '1']
#      [['suggests', 'several'], '1']
#      [['suggests', 'unilateral'], '1']
#      [['sults', 'interaction'], '1']
#      [['summarize', 'results'], '1']
#      [['summarized', 'performance'], '1']
#      [['sup', 'port'], '1']
#      [['superior', 'plan'], '1']
#      [['superior', 'planning'], '1']
#      [['supplier', 'very'], '1']
#      [['supporting', 'boundary'], '1']
#      [['surrendered', 'get'], '1']
#      [['survey', 'can'], '1']
#      [['survey', 'indicates'], '1']
#      [['survey', 'p'], '1']
#      [['surveys', 'should'], '1']
#      [['swanson', 'e'], '1']
#      [['sym', 'bol'], '1']
#      [['synthesis', 'nonperson'], '1']
#      [['synthesis', 'nonpersonal'], '1']
#      [['synthesis', 'partially'], '1']
#      [['synthesize', 'less'], '1']
#      [['sys', 'tem'], '1']
#      [['sys', 'tematize'], '1']
#      [['sys', 'tems'], '1']
#      [['system', 'attrib'], '1']
#      [['system', 'can'], '1']
#      [['system', 'com'], '1']
#      [['system', 'including'], '1']
#      [['system', 'interactive'], '1']
#      [['system', 'introspection'], '1']
#      [['system', 'produce'], '1']
#      [['system', 'propositions'], '1']
#      [['system', 'r'], '1']
#      [['system', 'used'], '1']
#      [['system', 'working'], '1']
#      [['systematic', 'contact'], '1']
#      [['systematic', 'error'], '1']
#      [['systematically', 'recombines'], '1']
#      [['systems', 'aggregate'], '1']
#      [['systems', 'apply'], '1']
#      [['systems', 'can'], '1']
#      [['systems', 'col'], '1']
#      [['systems', 'complexity'], '1']
#      [['systems', 'concep'], '1']
#      [['systems', 'criteria'], '1']
#      [['systems', 'depicts'], '1']
#      [['systems', 'design'], '1']
#      [['systems', 'john'], '1']
#      [['systems', 'letters'], '1']
#      [['systems', 'management'], '1']
#      [['systems', 'new'], '1']
#      [['systems', 'nonperson'], '1']
#      [['systems', 'obsolete'], '1']
#      [['systems', 'often'], '1']
#      [['systems', 'out'], '1']
#      [['systems', 'produce'], '1']
#      [['systems', 'production'], '1']
#      [['systems', 'relying'], '1']
#      [['systems', 'simple'], '1']
#      [['systems', 'sloan'], '1']
#      [['systems', 'sluggish'], '1']
#      [['systems', 'summarized'], '1']
#      [['systems', 'table'], '1']
#      [['systems', 'tem'], '1']
#      [['systems', 'timely'], '1']
#      [['systems', 'use'], '1']
#      [['systems', 'used'], '1']
#      [['systems', 'working'], '1']
#      [['t', 'systematic'], '1']
#      [['tablished', 'information'], '1']
#      [['tain', 'some'], '1']
#      [['tained', 'modest'], '1']
#      [['take', 'increased'], '1']
#      [['talking', 'people'], '1']
#      [['tant', 'contingencies'], '1']
#      [['target', 'groups'], '1']
#      [['targets', 'preferred'], '1']
#      [['task', 'contingent'], '1']
#      [['task', 'envi'], '1']
#      [['task', 'environ'], '1']
#      [['task', 'environment'], '1']
#      [['task', 'factors'], '1']
#      [['task', 'features'], '1']
#      [['task', 'force'], '1']
#      [['task', 'forces'], '1']
#      [['task', 'simple'], '1']
#      [['tasks', 'group'], '1']
#      [['tasks', 'reoccurring'], '1']
#      [['tech', 'niques'], '1']
#      [['technique', 'e'], '1']
#      [['technique', 'i'], '1']
#      [['technique', 'pert'], '1']
#      [['techniques', 'mathematical'], '1']
#      [['techniques', 'program'], '1']
#      [['techniques', 'represent'], '1']
#      [['techniques', 'used'], '1']
#      [['tem', 'based'], '1']
#      [['tem', 'error'], '1']
#      [['tematize', 'solution'], '1']
#      [['temporal', 'frequent'], '1']
#      [['temporal', 'procedural'], '1']
#      [['tems', 'matrices'], '1']
#      [['ten', 'qualifications'], '1']
#      [['tency', 'low'], '1']
#      [['tend', 'avoid'], '1']
#      [['tend', 'less'], '1']
#      [['tend', 'mallea'], '1']
#      [['tendency', 'person'], '1']
#      [['tends', 'creative'], '1']
#      [['tends', 'expensive'], '1']
#      [['tends', 'inconsistent'], '1']
#      [['tends', 'situational'], '1']
#      [['tent', 'than'], '1']
#      [['teraction', 'between'], '1']
#      [['term', 'describes'], '1']
#      [['termine', 'expected'], '1']
#      [['terms', 'describe'], '1']
#      [['terms', 'describes'], '1']
#      [['terms', 'its'], '1']
#      [['terms', 'needs'], '1']
#      [['terms', 'planning'], '1']
#      [['terms', 'temporal'], '1']
#      [['terms', 'well'], '1']
#      [['terms', 'where'], '1']
#      [['terms', 'which'], '1']
#      [['texas', 'aus'], '1']
#      [['th', 'person'], '1']
#      [['th', 'report'], '1']
#      [['than', 'informa'], '1']
#      [['than', 'nonperson'], '1']
#      [['than', 'person'], '1']
#      [['them', 'consistently'], '1']
#      [['them', 'designing'], '1']
#      [['them', 'type'], '1']
#      [['theoret', 'structure'], '1']
#      [['theory', 'firm'], '1']
#      [['theory', 'practice'], '1']
#      [['think', 'new'], '1']
#      [['thompson', 'j'], '1']
#      [['those', 'affected'], '1']
#      [['those', 'experience'], '1']
#      [['those', 'planning'], '1']
#      [['thought', 'simple'], '1']
#      [['three', 'planning'], '1']
#      [['three', 'principles'], '1']
#      [['through', 'analysis'], '1']
#      [['through', 'application'], '1']
#      [['through', 'discussion'], '1']
#      [['through', 'interpretation'], '1']
#      [['through', 'involvement'], '1']
#      [['through', 'morphological'], '1']
#      [['through', 'person'], '1']
#      [['through', 'pro'], '1']
#      [['through', 'process'], '1']
#      [['thus', 'complex'], '1']
#      [['thus', 'new'], '1']
#      [['thus', 'nonper'], '1']
#      [['thus', 'nonperson'], '1']
#      [['thus', 'pira'], '1']
#      [['thus', 'tend'], '1']
#      [['thus', 'would'], '1']
#      [['tial', 'departures'], '1']
#      [['tic', 'information'], '1']
#      [['tice', 'public'], '1']
#      [['ticular', 'age'], '1']
#      [['ties', 'self'], '1']
#      [['time', 'consuming'], '1']
#      [['time', 'heuristic'], '1']
#      [['time', 'interac'], '1']
#      [['time', 'ly'], '1']
#      [['time', 'meas'], '1']
#      [['time', 'often'], '1']
#      [['time', 'period'], '1']
#      [['time', 'plan'], '1']
#      [['timeli', 'ness'], '1']
#      [['timeliness', 'creativity'], '1']
#      [['timeliness', 'delay'], '1']
#      [['timeliness', 'low'], '1']
#      [['timely', 'accuracy'], '1']
#      [['timely', 'accurate'], '1']
#      [['timely', 'consistent'], '1']
#      [['timely', 'creative'], '1']
#      [['timely', 'extent'], '1']
#      [['timely', 'information'], '1']
#      [['timely', 'large'], '1']
#      [['timely', 'may'], '1']
#      [['timely', 'tends'], '1']
#      [['tin', 'assistant'], '1']
#      [['tion', 'accurately'], '1']
#      [['tion', 'attributes'], '1']
#      [['tion', 'between'], '1']
#      [['tion', 'built'], '1']
#      [['tion', 'example'], '1']
#      [['tion', 'generated'], '1']
#      [['tion', 'information'], '1']
#      [['tion', 'levels'], '1']
#      [['tion', 'models'], '1']
#      [['tion', 'modes'], '1']
#      [['tion', 'reports'], '1']
#      [['tion', 's'], '1']
#      [['tion', 'sources'], '1']
#      [['tion', 'system'], '1']
#      [['tions', 'articulate'], '1']
#      [['tions', 'set'], '1']
#      [['tions', 'some'], '1']
#      [['tive', 'information'], '1']
#      [['tive', 'planning'], '1']
#      [['tive', 'plans'], '1']
#      [['tive', 'reports'], '1']
#      [['tivities', 'like'], '1']
#      [['top', 'management'], '1']
#      [['top', 'managers'], '1']
#      [['torical', 'models'], '1']
#      [['tors', 'consider'], '1']
#      [['traditionally', 'associated'], '1']
#      [['training', 'interpret'], '1']
#      [['transportation', 'model'], '1']
#      [['trate', 'impact'], '1']
#      [['trates', 'some'], '1']
#      [['trative', 'science'], '1']
#      [['treated', 'terms'], '1']
#      [['trial', 'management'], '1']
#      [['trials', 'like'], '1']
#      [['tribute', 'models'], '1']
#      [['tributes', 'timeliness'], '1']
#      [['trol', 'vol'], '1']
#      [['true', 'only'], '1']
#      [['tual', 'foundations'], '1']
#      [['tween', 'each'], '1']
#      [['two', 'basic'], '1']
#      [['two', 'types'], '1']
#      [['type', 'design'], '1']
#      [['type', 'formation'], '1']
#      [['type', 'il'], '1']
#      [['type', 'informa'], '1']
#      [['type', 'information'], '1']
#      [['type', 'used'], '1']
#      [['types', 'environments'], '1']
#      [['types', 'excep'], '1']
#      [['typical', 'sources'], '1']
#      [['typically', 'terms'], '1']
#      [['u', 'used'], '1']
#      [['uals', 'groups'], '1']
#      [['uated', 'determine'], '1']
#      [['ue', 'seek'], '1']
#      [['ular', 'environmental'], '1']
#      [['un', 'certainty'], '1']
#      [['uncertainty', 'risk'], '1']
#      [['under', 'conditions'], '1']
#      [['under', 'constant'], '1']
#      [['under', 'risk'], '1']
#      [['under', 'semi'], '1']
#      [['under', 'un'], '1']
#      [['understood', 'making'], '1']
#      [['unex', 'plained'], '1']
#      [['unfreezing', 'needed'], '1']
#      [['unilateral', 'decree'], '1']
#      [['unilateral', 'power'], '1']
#      [['unique', 'priori'], '1']
#      [['unique', 'procedural'], '1']
#      [['unit', 'fully'], '1']
#      [['unit', 'structures'], '1']
#      [['university', 'california'], '1']
#      [['university', 'columbus'], '1']
#      [['university', 'system'], '1']
#      [['university', 'texas'], '1']
#      [['university', 'wiscon'], '1']
#      [['unknown', 'procedures'], '1']
#      [['unknown', 'states'], '1']
#      [['unknown', 'thompson'], '1']
#      [['unstructured', 'decision'], '1']
#      [['up', 'quality'], '1']
#      [['up', 'smaller'], '1']
#      [['upon', 'another'], '1']
#      [['upon', 'information'], '1']
#      [['upon', 'stage'], '1']
#      [['urban', 'institute'], '1']
#      [['ure', 'timeliness'], '1']
#      [['usage', 'sales'], '1']
#      [['use', 'academy'], '1']
#      [['use', 'approach'], '1']
#      [['use', 'data'], '1']
#      [['use', 'detailing'], '1']
#      [['use', 'experience'], '1']
#      [['use', 'infor'], '1']
#      [['use', 'information'], '1']
#      [['use', 'large'], '1']
#      [['use', 'patterns'], '1']
#      [['use', 'personal'], '1']
#      [['use', 'reports'], '1']
#      [['used', 'because'], '1']
#      [['used', 'complex'], '1']
#      [['used', 'conceptualize'], '1']
#      [['used', 'detail'], '1']
#      [['used', 'develop'], '1']
#      [['used', 'enhance'], '1']
#      [['used', 'experts'], '1']
#      [['used', 'formation'], '1']
#      [['used', 'generate'], '1']
#      [['used', 'help'], '1']
#      [['used', 'illus'], '1']
#      [['used', 'illustrate'], '1']
#      [['used', 'improve'], '1']
#      [['used', 'individual'], '1']
#      [['used', 'judge'], '1']
#      [['used', 'list'], '1']
#      [['used', 'nonpersonal'], '1']
#      [['used', 'nutt'], '1']
#      [['used', 'obtain'], '1']
#      [['used', 'planning'], '1']
#      [['used', 'preferred'], '1']
#      [['used', 'prescribe'], '1']
#      [['used', 'promote'], '1']
#      [['used', 'propositions'], '1']
#      [['used', 'provide'], '1']
#      [['used', 'reoccurring'], '1']
#      [['used', 'select'], '1']
#      [['used', 'simple'], '1']
#      [['used', 'specify'], '1']
#      [['used', 'stress'], '1']
#      [['used', 'sup'], '1']
#      [['used', 'support'], '1']
#      [['useful', 'complex'], '1']
#      [['useful', 'essential'], '1']
#      [['useful', 'generating'], '1']
#      [['user', 'always'], '1']
#      [['user', 'services'], '1']
#      [['users', 'insure'], '1']
#      [['users', 'through'], '1']
#      [['uses', 'analytic'], '1']
#      [['uses', 'k'], '1']
#      [['uses', 'nonperson'], '1']
#      [['using', 'analytic'], '1']
#      [['using', 'classi'], '1']
#      [['using', 'historical'], '1']
#      [['using', 'interactive'], '1']
#      [['using', 'methodologies'], '1']
#      [['using', 'model'], '1']
#      [['using', 'nonpersonal'], '1']
#      [['using', 'past'], '1']
#      [['using', 'person'], '1']
#      [['using', 'two'], '1']
#      [['utes', 'considered'], '1']
#      [['utes', 'known'], '1']
#      [['utilities', 'decision'], '1']
#      [['utilities', 'persuasion'], '1']
#      [['utility', 'intended'], '1']
#      [['utility', 'models'], '1']
#      [['utility', 'than'], '1']
#      [['value', 'judgment'], '1']
#      [['value', 'planning'], '1']
#      [['variability', 'frequency'], '1']
#      [['variable', 'available'], '1']
#      [['variable', 'consistent'], '1']
#      [['variable', 'p'], '1']
#      [['variables', 'para'], '1']
#      [['variables', 'which'], '1']
#      [['variance', 'reports'], '1']
#      [['variety', 'sources'], '1']
#      [['various', 'neighborhood'], '1']
#      [['various', 'person'], '1']
#      [['various', 'planning'], '1']
#      [['vary', 'decisions'], '1']
#      [['vary', 'depending'], '1']
#      [['ven', 'd'], '1']
#      [['ven', 'group'], '1']
#      [['verbal', 'interaction'], '1']
#      [['very', 'few'], '1']
#      [['vestigated', 'sources'], '1']
#      [['via', 'i'], '1']
#      [['via', 'interac'], '1']
#      [['vides', 'information'], '1']
#      [['vidual', 'example'], '1']
#      [['view', 'complexity'], '1']
#      [['view', 'how'], '1']
#      [['view', 'planning'], '1']
#      [['viewing', 'method'], '1']
#      [['viewpoints', 'plan'], '1']
#      [['viking', 'mars'], '1']
#      [['visit', 'organizations'], '1']
#      [['vogt', 'federal'], '1']
#      [['volume', 'occur'], '1']
#      [['w', 'backoff'], '1']
#      [['w', 'design'], '1']
#      [['w', 'f'], '1']
#      [['w', 'influence'], '1']
#      [['w', 'j'], '1']
#      [['wallester', 'comparative'], '1']
#      [['washington', 'd'], '1']
#      [['ways', 'generate'], '1']
#      [['we', 'pro'], '1']
#      [['wealth', 'formation'], '1']
#      [['weight', 'each'], '1']
#      [['well', 'higher'], '1']
#      [['well', 'reduce'], '1']
#      [['well', 'requirements'], '1']
#      [['well', 'timeliness'], '1']
#      [['were', 'found'], '1']
#      [['when', 'changes'], '1']
#      [['when', 'decision'], '1']
#      [['when', 'eoq'], '1']
#      [['when', 'i'], '1']
#      [['when', 'organization'], '1']
#      [['when', 'part'], '1']
#      [['when', 'person'], '1']
#      [['when', 'personal'], '1']
#      [['when', 'planner'], '1']
#      [['when', 'planning'], '1']
#      [['when', 'properly'], '1']
#      [['when', 'speed'], '1']
#      [['when', 'sponsor'], '1']
#      [['when', 'states'], '1']
#      [['when', 'survey'], '1']
#      [['when', 'use'], '1']
#      [['where', 'pirai'], '1']
#      [['where', 'represents'], '1']
#      [['which', 'aggregate'], '1']
#      [['which', 'alters'], '1']
#      [['which', 'assumes'], '1']
#      [['which', 'diminishes'], '1']
#      [['which', 'each'], '1']
#      [['which', 'enhances'], '1']
#      [['which', 'guide'], '1']
#      [['which', 'inexpensive'], '1']
#      [['which', 'stimulates'], '1']
#      [['which', 'stipulate'], '1']
#      [['which', 'true'], '1']
#      [['which', 'used'], '1']
#      [['while', 'i'], '1']
#      [['while', 'set'], '1']
#      [['while', 'shared'], '1']
#      [['who', 'guides'], '1']
#      [['who', 'participates'], '1']
#      [['wholey', 'j'], '1']
#      [['why', 'costs'], '1']
#      [['wider', 'view'], '1']
#      [['wiscon', 'sin'], '1']
#      [['without', 'accounting'], '1']
#      [['without', 'focusing'], '1']
#      [['work', 'because'], '1']
#      [['work', 'new'], '1']
#      [['work', 'rigid'], '1']
#      [['work', 'systems'], '1']
#      [['work', 'unit'], '1']
#      [['working', 'pa'], '1']
#      [['working', 'paper'], '1']
#      [['worth', 'given'], '1']
#      [['would', 'described'], '1']
#      [['yield', 'requisite'], '1']
#      [['yielding', 'i'], '1']
#      [['york', 'brooks'], '1']
#      [['york', 'harper'], '1']
#      [['york', 'holt'], '1']
#      [['york', 'macmillan'], '1']
#      [['york', 'mckay'], '1']
#      [['york', 'national'], '1']
#      [['york', 'prentice'], '1']
#      [['york', 'scrib'], '1']
#      [['york', 'wiley'], '1']
#      [['ysis', 'features'], '1']
#      [['zability', 'extent'], '1']
#      [['zwicky', 'f'], '1']

# %%
"""
Create Dataframe
""" 
# Data
data = []
for words, freq in freq_list:
    assert len(words) == 2
    data.append([words[0], words[1], freq])

# Columns
columns = ["word1", "word2", "freq"]

# Index
index = list(range(len(freq_list)))

# DataFrame
dataframe = pd.DataFrame(data, columns=columns, index=index)

# Print Test
dataframe.head()
# Out:
#          word1         word2 freq
# 0  information       systems   27
# 1            p             i   21
# 2      complex  environments   19
# 3     planning   information   16
# 4          new          york   15

# %%
"""
Run filtering for each file
"""
progress = list(range(0, len(filtered_list), len(filtered_list) // 99))

for file_num in range(0, len(filtered_list)):
    
    file = filtered_list[file_num]
    # Open file
    try:
        file_open = zip_file.open(file, mode="r")
    except IOError:
        print("Error opening file {0}".format(file))
        exit(0)
    
    # Create output file
    output_name = mypath + "Results_2/" + file[len("/ngram" + str(N_number)):]
    # Note: Output file encoding set to UTF-8
    output_file = open(output_name, mode="w+", encoding="utf-8")
    
    # Track for max length word
    # Used for formatting output data
    max_length = [float("-inf")] * 2
        
    # Initiate freq_list -> [[words0, freq0], [words1, freq1]]
    freq_list = []
    
    # Read by line
    for line in file_open:
        # Line decode using UTF-8
        line = line.decode("utf-8")
        assert isinstance(line, str)
        pair = line.strip().split()
    
        # Separate word/freq
        words, freq = pair[:-1], pair[-1]
        assert len(words) == 2
        assert freq.isdigit()
        
        # Filter by word's attribute
        if check_words(words):
            continue
        
        # Update max_length
        for i in range(len(words)):
            if len(words[i]) > max_length[i]:
                max_length[i] = len(words[i])
            
            
        # Append new pair to freq_list
        freq_list.append([words, freq])
    
    # Close reading file
    file_open.close()
    
    # Create Dataframe
    # Data
    data = []
    for words, freq in freq_list:
        assert len(words) == 2
        data.append([words[0], words[1], freq])

    # Columns
    columns = ["word1", "word2", "freq"]

    # Index
    index = list(range(len(freq_list)))

    # DataFrame
    dataframe = pd.DataFrame(data, columns=columns, index=index)
    
    # Write to output file
    for words, freq in freq_list:
        output_file.write(words[0].ljust(max_length[0] + 5))
        output_file.write(words[1].ljust(max_length[1] + 5))
        output_file.write(freq + "\n")
    
    # Close output_file
    output_file.close()

    # Track Progress
    if len(progress) > 0 and file_num >= progress[0]:
        print("Progress: {}%".format(100 - len(progress)))
        progress.pop(0)
        
# Print Sample Output
print(dataframe.head())
