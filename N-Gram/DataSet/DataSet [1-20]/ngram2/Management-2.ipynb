# %%
"""
Error Code:
    0: Error opening file
"""

import pandas as pd
import numpy as np

# %%
def namestr(obj, namespace):
    return [name for name in namespace if namespace[name] is obj]

def display(items):
    print(namestr(items, globals()))
    for item in items:
        print("     {0}".format(item))

# Test display
test_dict = {"A": [1, 2, 3], "B": [4, 5, 6]}
display(test_dict)
# Out:
# ['test_dict']
#      A
#      B

# %%
from os import listdir
from os.path import isfile, join

mypath = "./"
files_list = [file for file in listdir(mypath) if isfile(join(mypath, file))]
print("{0} files detected under current directory. ".format(len(files_list)))
# Out:
# 41 files detected under current directory.

# %%
def filter_by_filename(files_list):
    """Function filtering files by filenames.
    Only accepts files starts with "journal-article"
    """
    filtered_list = []
    for filename in files_list:
        # Check if the filename starts with "journal-article"
        assert isinstance(filename, str)
        # Check the first 20 characters of the file name
        if filename.startswith("journal-article", 0, 20):
            filtered_list.append(filename)
    return filtered_list

# Run "filter_by_filename" for current directory
filtered_list = filter_by_filename(files_list)
print("{0} files remained after filename filtering. ".format(len(filtered_list)))
# Out:
# 20 files remained after filename filtering.

# %%
# Functions checking word attributes (single-letter, starts/ends with numebr)
def is_single_letter(word):
    assert isinstance(word, str)
    return len(word) <= 1

def starts_with_number(word):
    assert isinstance(word, str)
    try:
        return word[0].isdigit()
    except:
        return False

def ends_with_number(word):
    assert isinstance(word, str)
    try:
        return word[len(word) - 1].isdigit()
    except:
        return False

# Summary of check functions
check_funcs = [
#     is_single_letter, # Only applies for 1-gram
    starts_with_number, 
    ends_with_number,
]

# Summary of checking mechanisms
def check_words(words):
    for word in words:
        check_result = [check_func(word) for check_func in check_funcs]
        if any(check_result):
            return True
    return False

# %%
file_0 = filtered_list[0]
try:
    journal_0 = open(file_0, mode="r")
except IOError:
    print("Error opening file {0}".format(file_0))
    exit(0)
    
# Track the meaningful dictonaries
freq_list = []

# Read file line by line
for line in journal_0:
    assert isinstance(line, str)
    pair = line.strip().split()
    
    assert len(pair) == 3
    
    # Separate word/freq
    words, freq = pair[:-1], pair[-1]
    assert len(words) == 2
    assert freq.isdigit()
    
    # Filter by word's attribute
    if check_words(words):
        continue
    freq_list.append([words, freq])

journal_0.close()
display(freq_list)
# Out:
# ['freq_list']
#      [['e', 'program'], '34']
#      [['mentally', 'ill'], '34']
#      [['e', 'group'], '33']
#      [['mental', 'health'], '33']
#      [['costs', 'benefits'], '17']
#      [['human', 'resources'], '16']
#      [['c', 'group'], '15']
#      [['journal', 'human'], '15']
#      [['benefit', 'cost'], '14']
#      [['patient', 's'], '13']
#      [['per', 'patient'], '13']
#      [['e', 'c'], '12']
#      [['treatment', 'costs'], '12']
#      [['have', 'been'], '11']
#      [['treatment', 'program'], '11']
#      [['b', 'c'], '9']
#      [['benefits', 'costs'], '9']
#      [['community', 'based'], '9']
#      [['cost', 'analysis'], '9']
#      [['group', 'patients'], '9']
#      [['law', 'enforcement'], '9']
#      [['maintenance', 'costs'], '9']
#      [['mental', 'illness'], '9']
#      [['sheltered', 'workshops'], '9']
#      [['c', 'program'], '8']
#      [['dane', 'county'], '8']
#      [['rather', 'than'], '8']
#      [['family', 'members'], '7']
#      [['treating', 'mentally'], '7']
#      [['c', 'analysis'], '6']
#      [['e', 'g'], '6']
#      [['health', 'status'], '6']
#      [['hospital', 'based'], '6']
#      [['improved', 'mental'], '6']
#      [['significant', 'differences'], '6']
#      [['treatment', 'approach'], '6']
#      [['university', 'wisconsin'], '6']
#      [['we', 'were'], '6']
#      [['would', 'have'], '6']
#      [['average', 'cost'], '5']
#      [['been', 'made'], '5']
#      [['cost', 'data'], '5']
#      [['costs', 'per'], '5']
#      [['decision', 'making'], '5']
#      [['enforcement', 'costs'], '5']
#      [['follow', 'up'], '5']
#      [['global', 'illness'], '5']
#      [['group', 'significantly'], '5']
#      [['long', 'run'], '5']
#      [['mendota', 'mental'], '5']
#      [['patient', 'reports'], '5']
#      [['person', 's'], '5']
#      [['secondary', 'treatment'], '5']
#      [['social', 'costs'], '5']
#      [['treatment', 'mentally'], '5']
#      [['treatment', 'mode'], '5']
#      [['agencies', 'were'], '4']
#      [['ann', 'test'], '4']
#      [['based', 'approach'], '4']
#      [['c', 'e'], '4']
#      [['community', 'agencies'], '4']
#      [['competitive', 'employment'], '4']
#      [['consumer', 'decision'], '4']
#      [['data', 'were'], '4']
#      [['derived', 'from'], '4']
#      [['diem', 'cost'], '4']
#      [['difference', 'between'], '4']
#      [['e', 'e'], '4']
#      [['e', 'patients'], '4']
#      [['experimental', 'control'], '4']
#      [['family', 'burden'], '4']
#      [['forms', 'costs'], '4']
#      [['four', 'months'], '4']
#      [['group', 'e'], '4']
#      [['group', 'had'], '4']
#      [['group', 'members'], '4']
#      [['group', 'staff'], '4']
#      [['he', 'she'], '4']
#      [['health', 'institute'], '4']
#      [['help', 'patients'], '4']
#      [['his', 'her'], '4']
#      [['labor', 'market'], '4']
#      [['mary', 'ann'], '4']
#      [['may', 'well'], '4']
#      [['other', 'people'], '4']
#      [['patient', 'year'], '4']
#      [['patients', 'e'], '4']
#      [['patients', 'were'], '4']
#      [['per', 'diem'], '4']
#      [['per', 'year'], '4']
#      [['percent', 'c'], '4']
#      [['primary', 'treatment'], '4']
#      [['probation', 'parole'], '4']
#      [['resources', 'table'], '4']
#      [['s', 'illness'], '4']
#      [['significant', 'difference'], '4']
#      [['statistically', 'significant'], '4']
#      [['subject', 's'], '4']
#      [['u', 's'], '4']
#      [['were', 'able'], '4']
#      [['were', 'also'], '4']
#      [['were', 'made'], '4']
#      [['were', 'obtained'], '4']
#      [['wisconsin', 'madison'], '4']
#      [['agencies', 'other'], '3']
#      [['analysis', 'controlled'], '3']
#      [['average', 'total'], '3']
#      [['based', 'treatment'], '3']
#      [['benefit', 'analysis'], '3']
#      [['better', 'less'], '3']
#      [['between', 'e'], '3']
#      [['between', 'two'], '3']
#      [['burden', 'costs'], '3']
#      [['c', 'groups'], '3']
#      [['c', 'type'], '3']
#      [['capacity', 'utilization'], '3']
#      [['change', 'level'], '3']
#      [['control', 'mental'], '3']
#      [['controlled', 'experiment'], '3']
#      [['cost', 'benefit'], '3']
#      [['cost', 'e'], '3']
#      [['costs', 'which'], '3']
#      [['court', 'contacts'], '3']
#      [['data', 'from'], '3']
#      [['differences', 'e'], '3']
#      [['direct', 'treatment'], '3']
#      [['director', 'research'], '3']
#      [['disutility', 'work'], '3']
#      [['due', 'patient'], '3']
#      [['e', 'treatment'], '3']
#      [['each', 'group'], '3']
#      [['estimates', 'have'], '3']
#      [['even', 'negative'], '3']
#      [['experi', 'control'], '3']
#      [['experimental', 'center'], '3']
#      [['experimental', 'design'], '3']
#      [['favor', 'e'], '3']
#      [['from', 'agency'], '3']
#      [['from', 'patient'], '3']
#      [['from', 'social'], '3']
#      [['group', 'c'], '3']
#      [['had', 'significantly'], '3']
#      [['higher', 'level'], '3']
#      [['i', 'stein'], '3']
#      [['ill', 'may'], '3']
#      [['illness', 'other'], '3']
#      [['improved', 'consumer'], '3']
#      [['including', 'global'], '3']
#      [['indirect', 'treatment'], '3']
#      [['institute', 'mmhi'], '3']
#      [['institute', 'research'], '3']
#      [['job', 'changes'], '3']
#      [['leonard', 'i'], '3']
#      [['less', 'symptomatic'], '3']
#      [['marginal', 'product'], '3']
#      [['measures', 'costs'], '3']
#      [['measures', 'including'], '3']
#      [['medical', 'providers'], '3']
#      [['mental', 'group'], '3']
#      [['mental', 'hospitals'], '3']
#      [['mmhi', 'inpatient'], '3']
#      [['mmhi', 'sheltered'], '3']
#      [['monetary', 'estimates'], '3']
#      [['monetary', 'values'], '3']
#      [['months', 'following'], '3']
#      [['more', 'effective'], '3']
#      [['more', 'efficient'], '3']
#      [['more', 'than'], '3']
#      [['net', 'benefits'], '3']
#      [['number', 'beneficial'], '3']
#      [['number', 'patients'], '3']
#      [['obtained', 'from'], '3']
#      [['one', 'year'], '3']
#      [['only', 'about'], '3']
#      [['opportunity', 'cost'], '3']
#      [['other', 'hospitals'], '3']
#      [['patients', 'also'], '3']
#      [['patients', 'more'], '3']
#      [['patients', 'who'], '3']
#      [['per', 'month'], '3']
#      [['per', 'se'], '3']
#      [['percent', 'e'], '3']
#      [['persons', 'who'], '3']
#      [['poverty', 'university'], '3']
#      [['presence', 'absence'], '3']
#      [['present', 'value'], '3']
#      [['private', 'medical'], '3']
#      [['program', 'patient'], '3']
#      [['program', 's'], '3']
#      [['program', 'were'], '3']
#      [['random', 'assignment'], '3']
#      [['research', 'poverty'], '3']
#      [['run', 'marginal'], '3']
#      [['satisfaction', 'life'], '3']
#      [['service', 'agencies'], '3']
#      [['sheltered', 'workshop'], '3']
#      [['social', 'service'], '3']
#      [['than', 'c'], '3']
#      [['time', 'admission'], '3']
#      [['treatment', 'modes'], '3']
#      [['treatment', 'programs'], '3']
#      [['turn', 'now'], '3']
#      [['two', 'treatment'], '3']
#      [['unable', 'obtain'], '3']
#      [['up', 'period'], '3']
#      [['used', 'only'], '3']
#      [['utility', 'functions'], '3']
#      [['value', 'future'], '3']
#      [['variables', 'which'], '3']
#      [['viewed', 'from'], '3']
#      [['we', 'had'], '3']
#      [['we', 'have'], '3']
#      [['we', 'turn'], '3']
#      [['we', 'would'], '3']
#      [['were', 'unable'], '3']
#      [['were', 'used'], '3']
#      [['which', 'monetary'], '3']
#      [['who', 'were'], '3']
#      [['wide', 'range'], '3']
#      [['wide', 'variety'], '3']
#      [['willingness', 'pay'], '3']
#      [['able', 'obtain'], '2']
#      [['able', 'provide'], '2']
#      [['absence', 'various'], '2']
#      [['actions', 'than'], '2']
#      [['acute', 'treatment'], '2']
#      [['added', 'earnings'], '2']
#      [['admission', 'experiment'], '2']
#      [['admission', 'were'], '2']
#      [['agencies', 'dane'], '2']
#      [['all', 'benefits'], '2']
#      [['all', 'patients'], '2']
#      [['american', 'economic'], '2']
#      [['among', 'alternative'], '2']
#      [['analysis', 'chicago'], '2']
#      [['any', 'increase'], '2']
#      [['any', 'treatment'], '2']
#      [['ap', 'proaches'], '2']
#      [['assignment', 'experiment'], '2']
#      [['associate', 'director'], '2']
#      [['attention', 'future'], '2']
#      [['attitudes', 'toward'], '2']
#      [['average', 'costs'], '2']
#      [['based', 'program'], '2']
#      [['behavior', 'mentally'], '2']
#      [['being', 'used'], '2']
#      [['benefits', 'form'], '2']
#      [['benefits', 'table'], '2']
#      [['benefits', 'viewed'], '2']
#      [['benefits', 'which'], '2']
#      [['better', 'health'], '2']
#      [['better', 'more'], '2']
#      [['between', 'groups'], '2']
#      [['both', 'which'], '2']
#      [['burdens', 'other'], '2']
#      [['burton', 'weisbrod'], '2']
#      [['c', 'patients'], '2']
#      [['c', 'programs'], '2']
#      [['can', 'reason'], '2']
#      [['carried', 'out'], '2']
#      [['cases', 'when'], '2']
#      [['cases', 'which'], '2']
#      [['center', 'program'], '2']
#      [['changed', 'various'], '2']
#      [['changes', 'e'], '2']
#      [['close', 'zero'], '2']
#      [['community', 'living'], '2']
#      [['competitively', 'employed'], '2']
#      [['conceptually', 'relevant'], '2']
#      [['concern', 'about'], '2']
#      [['constitute', 'gross'], '2']
#      [['contacts', 'probation'], '2']
#      [['continued', 'experi'], '2']
#      [['contrary', 'community'], '2']
#      [['control', 'groups'], '2']
#      [['controlled', 'random'], '2']
#      [['coping', 'stress'], '2']
#      [['cost', 'analyses'], '2']
#      [['cost', 'estimate'], '2']
#      [['cost', 'treatment'], '2']
#      [['costly', 'obtain'], '2']
#      [['costs', 'e'], '2']
#      [['costs', 'even'], '2']
#      [['costs', 'expenditures'], '2']
#      [['costs', 'incurred'], '2']
#      [['costs', 'mendota'], '2']
#      [['costs', 'mental'], '2']
#      [['costs', 'only'], '2']
#      [['costs', 'overnights'], '2']
#      [['costs', 'percentage'], '2']
#      [['costs', 'social'], '2']
#      [['costs', 'some'], '2']
#      [['costs', 'treatment'], '2']
#      [['county', 'mental'], '2']
#      [['county', 'social'], '2']
#      [['county', 'wisconsin'], '2']
#      [['d', 'mary'], '2']
#      [['data', 'about'], '2']
#      [['days', 'missed'], '2']
#      [['debate', 'over'], '2']
#      [['depreciated', 'replacement'], '2']
#      [['detrimental', 'job'], '2']
#      [['discount', 'rate'], '2']
#      [['discussion', 'above'], '2']
#      [['discussion', 'see'], '2']
#      [['dollar', 'costs'], '2']
#      [['dr', 'leonard'], '2']
#      [['dr', 'mary'], '2']
#      [['duration', 'experiment'], '2']
#      [['during', 'period'], '2']
#      [['during', 'subsequent'], '2']
#      [['each', 'patient'], '2']
#      [['earnings', 'from'], '2']
#      [['earnings', 'were'], '2']
#      [['economic', 'analysis'], '2']
#      [['economic', 'review'], '2']
#      [['employment', 'per'], '2']
#      [['employment', 'service'], '2']
#      [['estimates', 'costs'], '2']
#      [['example', 'e'], '2']
#      [['excessively', 'costly'], '2']
#      [['experi', 'ment'], '2']
#      [['experiment', 'conducted'], '2']
#      [['experiment', 'mental'], '2']
#      [['experiment', 'only'], '2']
#      [['experiment', 'treating'], '2']
#      [['experimental', 'program'], '2']
#      [['experiments', 'which'], '2']
#      [['external', 'costs'], '2']
#      [['families', 'community'], '2']
#      [['families', 'were'], '2']
#      [['far', 'below'], '2']
#      [['following', 'admission'], '2']
#      [['from', 'costs'], '2']
#      [['from', 'interviews'], '2']
#      [['from', 'sheltered'], '2']
#      [['from', 'work'], '2']
#      [['from', 'working'], '2']
#      [['g', 'neighbors'], '2']
#      [['goal', 'treatment'], '2']
#      [['goods', 'services'], '2']
#      [['greater', 'increase'], '2']
#      [['h', 'haveman'], '2']
#      [['have', 'found'], '2']
#      [['hawthorne', 'effects'], '2']
#      [['health', 'field'], '2']
#      [['health', 'per'], '2']
#      [['health', 'professionals'], '2']
#      [['his', 'behavior'], '2']
#      [['hospital', 'treatment'], '2']
#      [['hospitals', 'non'], '2']
#      [['human', 'capital'], '2']
#      [['ill', 'can'], '2']
#      [['ill', 'person'], '2']
#      [['improved', 'health'], '2']
#      [['increase', 'earnings'], '2']
#      [['increased', 'earnings'], '2']
#      [['increased', 'patient'], '2']
#      [['increased', 'productivity'], '2']
#      [['indicator', 'mental'], '2']
#      [['information', 'all'], '2']
#      [['information', 'from'], '2']
#      [['inpatient', 'outpatient'], '2']
#      [['institute', 'mental'], '2']
#      [['institutions', 'other'], '2']
#      [['insurance', 'expenditures'], '2']
#      [['inter', 'views'], '2']
#      [['its', 'costs'], '2']
#      [['its', 'treatment'], '2']
#      [['land', 'depreciated'], '2']
#      [['less', 'than'], '2']
#      [['level', 'maintenance'], '2']
#      [['living', 'situation'], '2']
#      [['m', 'd'], '2']
#      [['marginal', 'average'], '2']
#      [['marital', 'status'], '2']
#      [['market', 'behavior'], '2']
#      [['maximize', 'utility'], '2']
#      [['may', 'interpreted'], '2']
#      [['measure', 'benefits'], '2']
#      [['measured', 'earnings'], '2']
#      [['might', 'have'], '2']
#      [['might', 'well'], '2']
#      [['missed', 'from'], '2']
#      [['monetary', 'terms'], '2']
#      [['months', 'after'], '2']
#      [['months', 'e'], '2']
#      [['more', 'costly'], '2']
#      [['more', 'satisfied'], '2']
#      [['more', 'social'], '2']
#      [['national', 'institute'], '2']
#      [['natural', 'causes'], '2']
#      [['neighbors', 'coworkers'], '2']
#      [['new', 'treatment'], '2']
#      [['non', 'ill'], '2']
#      [['non', 'mmhi'], '2']
#      [['number', 'arrests'], '2']
#      [['number', 'contacts'], '2']
#      [['obtain', 'relevant'], '2']
#      [['obtain', 'useful'], '2']
#      [['often', 'far'], '2']
#      [['one', 'potential'], '2']
#      [['one', 'treatment'], '2']
#      [['only', 'when'], '2']
#      [['other', 'aspects'], '2']
#      [['other', 'community'], '2']
#      [['other', 'persons'], '2']
#      [['other', 'psychotics'], '2']
#      [['other', 'than'], '2']
#      [['otherwise', 'have'], '2']
#      [['outpatient', 'experimental'], '2']
#      [['over', 'time'], '2']
#      [['overnights', 'jail'], '2']
#      [['part', 'experiment'], '2']
#      [['patient', 'costs'], '2']
#      [['patient', 'e'], '2']
#      [['patient', 'experimental'], '2']
#      [['patient', 'mortality'], '2']
#      [['patient', 'population'], '2']
#      [['patient', 'satisfaction'], '2']
#      [['patients', 'earnings'], '2']
#      [['patients', 'one'], '2']
#      [['patients', 'variety'], '2']
#      [['patients', 'would'], '2']
#      [['pay', 'treatment'], '2']
#      [['people', 'e'], '2']
#      [['per', 'contact'], '2']
#      [['percent', 'greater'], '2']
#      [['ph', 'd'], '2']
#      [['physical', 'health'], '2']
#      [['police', 'contacts'], '2']
#      [['possible', 'excessively'], '2']
#      [['potential', 'benefit'], '2']
#      [['preceding', 'interview'], '2']
#      [['presented', 'table'], '2']
#      [['pro', 'gram'], '2']
#      [['productive', 'potential'], '2']
#      [['productivity', 'would'], '2']
#      [['program', 'c'], '2']
#      [['program', 'cost'], '2']
#      [['program', 'mentally'], '2']
#      [['psychiatric', 'institutions'], '2']
#      [['public', 'private'], '2']
#      [['quality', 'life'], '2']
#      [['question', 'marks'], '2']
#      [['real', 'costs'], '2']
#      [['reason', 'ably'], '2']
#      [['regression', 'adjusted'], '2']
#      [['relevant', 'information'], '2']
#      [['replacement', 'cost'], '2']
#      [['reported', 'here'], '2']
#      [['reported', 'satisfaction'], '2']
#      [['research', 'mmhi'], '2']
#      [['reserva', 'tion'], '2']
#      [['resources', 'more'], '2']
#      [['result', 'from'], '2']
#      [['resulting', 'from'], '2']
#      [['robert', 'h'], '2']
#      [['s', 'admission'], '2']
#      [['s', 'behavior'], '2']
#      [['s', 'congress'], '2']
#      [['s', 'efforts'], '2']
#      [['s', 'own'], '2']
#      [['sample', 'size'], '2']
#      [['satisfaction', 'from'], '2']
#      [['services', 'provided'], '2']
#      [['should', 'noted'], '2']
#      [['shows', 'e'], '2']
#      [['single', 'year'], '2']
#      [['social', 'benefits'], '2']
#      [['social', 'experiments'], '2']
#      [['social', 'groups'], '2']
#      [['social', 'relationships'], '2']
#      [['social', 'services'], '2']
#      [['socially', 'approved'], '2']
#      [['some', 'evidence'], '2']
#      [['staff', 'help'], '2']
#      [['staff', 'time'], '2']
#      [['state', 'employment'], '2']
#      [['state', 'health'], '2']
#      [['status', 'judged'], '2']
#      [['steady', 'state'], '2']
#      [['stein', 'm'], '2']
#      [['stein', 'test'], '2']
#      [['study', 'period'], '2']
#      [['test', 'ph'], '2']
#      [['than', 'does'], '2']
#      [['than', 'would'], '2']
#      [['three', 'years'], '2']
#      [['thus', 'our'], '2']
#      [['time', 'community'], '2']
#      [['time', 'patterns'], '2']
#      [['tion', 'wage'], '2']
#      [['total', 'costs'], '2']
#      [['total', 'dollar'], '2']
#      [['traditional', 'c'], '2']
#      [['traditional', 'hospital'], '2']
#      [['treat', 'ment'], '2']
#      [['treatment', 'approaches'], '2']
#      [['treatment', 'can'], '2']
#      [['treatment', 'mmhi'], '2']
#      [['two', 'categories'], '2']
#      [['two', 'indicators'], '2']
#      [['two', 'programs'], '2']
#      [['two', 'types'], '2']
#      [['type', 'program'], '2']
#      [['useful', 'measure'], '2']
#      [['utility', 'function'], '2']
#      [['variety', 'other'], '2']
#      [['various', 'degrees'], '2']
#      [['visiting', 'nurse'], '2']
#      [['vocational', 'rehabilitation'], '2']
#      [['we', 'present'], '2']
#      [['were', 'available'], '2']
#      [['were', 'derived'], '2']
#      [['when', 'possible'], '2']
#      [['whether', 'had'], '2']
#      [['which', 'had'], '2']
#      [['which', 'included'], '2']
#      [['which', 'we'], '2']
#      [['willing', 'pay'], '2']
#      [['within', 'limits'], '2']
#      [['work', 'community'], '2']
#      [['work', 'stability'], '2']
#      [['worker', 's'], '2']
#      [['workshops', 'madison'], '2']
#      [['would', 'constitute'], '2']
#      [['would', 'desirable'], '2']
#      [['year', 'would'], '2']
#      [['ability', 'aid'], '1']
#      [['ability', 'function'], '1']
#      [['ability', 'manage'], '1']
#      [['ability', 'vary'], '1']
#      [['able', 'account'], '1']
#      [['able', 'do'], '1']
#      [['able', 'estimate'], '1']
#      [['able', 'judge'], '1']
#      [['ables', 'changed'], '1']
#      [['ably', 'considered'], '1']
#      [['ably', 'questioned'], '1']
#      [['about', 'advantages'], '1']
#      [['about', 'being'], '1']
#      [['about', 'both'], '1']
#      [['about', 'burden'], '1']
#      [['about', 'danger'], '1']
#      [['about', 'effects'], '1']
#      [['about', 'half'], '1']
#      [['about', 'his'], '1']
#      [['about', 'importance'], '1']
#      [['about', 'leave'], '1']
#      [['about', 'mental'], '1']
#      [['about', 'patient'], '1']
#      [['about', 'patients'], '1']
#      [['about', 'possibility'], '1']
#      [['about', 'quantitative'], '1']
#      [['about', 'research'], '1']
#      [['about', 'sharp'], '1']
#      [['about', 'total'], '1']
#      [['about', 'whether'], '1']
#      [['about', 'willingness'], '1']
#      [['above', 'e'], '1']
#      [['above', 'many'], '1']
#      [['above', 'pointed'], '1']
#      [['above', 'table'], '1']
#      [['absence', 'patient'], '1']
#      [['absence', 'perfectly'], '1']
#      [['absence', 'savingsweisbrod'], '1']
#      [['absences', 'disruption'], '1']
#      [['absent', 'second'], '1']
#      [['absenteeism', 'per'], '1']
#      [['absenteeism', 'rate'], '1']
#      [['abstract', 'study'], '1']
#      [['abstracting', 'from'], '1']
#      [['accept', 'providers'], '1']
#      [['acceptable', 'manner'], '1']
#      [['acceptance', 'proposition'], '1']
#      [['access', 'cost'], '1']
#      [['accompanied', 'reallocation'], '1']
#      [['accompany', 'patients'], '1']
#      [['according', 'leonard'], '1']
#      [['account', 'both'], '1']
#      [['account', 'exclude'], '1']
#      [['account', 'neither'], '1']
#      [['account', 'nor'], '1']
#      [['account', 'research'], '1']
#      [['accounting', 'increased'], '1']
#      [['accounts', 'ease'], '1']
#      [['accuracy', 'responses'], '1']
#      [['achievement', 'goal'], '1']
#      [['achievement', 'goals'], '1']
#      [['across', 'treatment'], '1']
#      [['action', 'implicitly'], '1']
#      [['action', 'washington'], '1']
#      [['active', 'support'], '1']
#      [['activities', 'g'], '1']
#      [['activities', 'police'], '1']
#      [['activities', 'which'], '1']
#      [['activity', 'costs'], '1']
#      [['activity', 'extent'], '1']
#      [['actual', 'imputed'], '1']
#      [['actual', 'values'], '1']
#      [['actually', 'counterproductive'], '1']
#      [['actually', 'more'], '1']
#      [['actually', 'rewarded'], '1']
#      [['acutely', 'ill'], '1']
#      [['added', 'benefits'], '1']
#      [['added', 'cost'], '1']
#      [['added', 'costs'], '1']
#      [['addi', 'tion'], '1']
#      [['additional', 'costs'], '1']
#      [['additional', 'detail'], '1']
#      [['additional', 'maintenance'], '1']
#      [['additional', 'sets'], '1']
#      [['additive', 'benefits'], '1']
#      [['adjust', 'ment'], '1']
#      [['adjust', 'size'], '1']
#      [['adjusted', 'estimate'], '1']
#      [['adjusted', 'experimental'], '1']
#      [['adjusted', 'slightly'], '1']
#      [['adjusted', 'socially'], '1']
#      [['adjusted', 'upward'], '1']
#      [['adjustment', 'patients'], '1']
#      [['adjustment', 'state'], '1']
#      [['adjustments', 'made'], '1']
#      [['adjustments', 'would'], '1']
#      [['admission', 'again'], '1']
#      [['admission', 'e'], '1']
#      [['admission', 'fact'], '1']
#      [['admission', 'mendota'], '1']
#      [['admission', 'most'], '1']
#      [['admissions', 'discharges'], '1']
#      [['admissions', 'however'], '1']
#      [['admitted', 'hospital'], '1']
#      [['adopted', 'experiment'], '1']
#      [['adults', 'improvement'], '1']
#      [['advances', 'pharmacology'], '1']
#      [['advantage', 'e'], '1']
#      [['advantages', 'benefits'], '1']
#      [['advantages', 'dis'], '1']
#      [['adverse', 'symptoms'], '1']
#      [['affect', 'mental'], '1']
#      [['affected', 'all'], '1']
#      [['affected', 'person'], '1']
#      [['after', 'admission'], '1']
#      [['after', 'care'], '1']
#      [['after', 'experiment'], '1']
#      [['after', 'four'], '1']
#      [['after', 'which'], '1']
#      [['again', 'four'], '1']
#      [['again', 'psychiatrists'], '1']
#      [['again', 'table'], '1']
#      [['against', 'rather'], '1']
#      [['age', 'schooling'], '1']
#      [['age', 'sex'], '1']
#      [['agencies', 'also'], '1']
#      [['agencies', 'included'], '1']
#      [['agencies', 'institutions'], '1']
#      [['agencies', 'involved'], '1']
#      [['agencies', 'measures'], '1']
#      [['agencies', 'patients'], '1']
#      [['agencies', 'private'], '1']
#      [['agency', 'b'], '1']
#      [['agency', 'estimates'], '1']
#      [['agency', 'patient'], '1']
#      [['agency', 'question'], '1']
#      [['aggressive', 'costly'], '1']
#      [['agitation', 'motor'], '1']
#      [['aid', 'nonhospi'], '1']
#      [['aid', 'patients'], '1']
#      [['ailments', 'result'], '1']
#      [['alcoholism', 'beginning'], '1']
#      [['alice', 'm'], '1']
#      [['all', 'clear'], '1']
#      [['all', 'costs'], '1']
#      [['all', 'encompassing'], '1']
#      [['all', 'except'], '1']
#      [['all', 'excess'], '1']
#      [['all', 'findings'], '1']
#      [['all', 'following'], '1']
#      [['all', 'interactions'], '1']
#      [['all', 'law'], '1']
#      [['all', 'maintenance'], '1']
#      [['all', 'measures'], '1']
#      [['all', 'mental'], '1']
#      [['all', 'number'], '1']
#      [['all', 'planned'], '1']
#      [['all', 'satisfied'], '1']
#      [['all', 'them'], '1']
#      [['alleviation', 'monetary'], '1']
#      [['allow', 'opportunity'], '1']
#      [['ally', 'ordinary'], '1']
#      [['almost', 'all'], '1']
#      [['almost', 'equal'], '1']
#      [['alone', 'almost'], '1']
#      [['alone', 'monetary'], '1']
#      [['also', 'asked'], '1']
#      [['also', 'collected'], '1']
#      [['also', 'contacted'], '1']
#      [['also', 'contains'], '1']
#      [['also', 'evaluation'], '1']
#      [['also', 'examined'], '1']
#      [['also', 'excluded'], '1']
#      [['also', 'felt'], '1']
#      [['also', 'imposed'], '1']
#      [['also', 'increases'], '1']
#      [['also', 'interviewed'], '1']
#      [['also', 'led'], '1']
#      [['also', 'made'], '1']
#      [['also', 'operating'], '1']
#      [['also', 'provided'], '1']
#      [['also', 'require'], '1']
#      [['also', 'thank'], '1']
#      [['also', 'toward'], '1']
#      [['also', 'wide'], '1']
#      [['altered', 'simultaneously'], '1']
#      [['altering', 'entire'], '1']
#      [['alternative', 'ap'], '1']
#      [['alternative', 'approaches'], '1']
#      [['alternative', 'mental'], '1']
#      [['alternative', 'reflected'], '1']
#      [['alternative', 'therapies'], '1']
#      [['alternative', 'treatment'], '1']
#      [['alternative', 'types'], '1']
#      [['although', 'any'], '1']
#      [['although', 'differences'], '1']
#      [['although', 'operated'], '1']
#      [['although', 'significant'], '1']
#      [['always', 'admitted'], '1']
#      [['always', 'appropriate'], '1']
#      [['among', 'three'], '1']
#      [['amount', 'money'], '1']
#      [['amount', 'time'], '1']
#      [['amounts', 'shown'], '1']
#      [['analyses', 'beesley'], '1']
#      [['analyses', 'here'], '1']
#      [['analyses', 'measure'], '1']
#      [['analyses', 'public'], '1']
#      [['analysis', 'all'], '1']
#      [['analysis', 'benefits'], '1']
#      [['analysis', 'conjunction'], '1']
#      [['analysis', 'eco'], '1']
#      [['analysis', 'even'], '1']
#      [['analysis', 'have'], '1']
#      [['analysis', 'made'], '1']
#      [['analysis', 'multidimensional'], '1']
#      [['analysis', 'new'], '1']
#      [['analysis', 'period'], '1']
#      [['analysis', 'see'], '1']
#      [['analysis', 'seen'], '1']
#      [['analysis', 'simply'], '1']
#      [['analysis', 'survey'], '1']
#      [['analysis', 'tables'], '1']
#      [['analysis', 'two'], '1']
#      [['analysis', 'upward'], '1']
#      [['analysis', 'used'], '1']
#      [['analysis', 'viewed'], '1']
#      [['analysis', 'washing'], '1']
#      [['analysis', 'whether'], '1']
#      [['analysis', 'would'], '1']
#      [['analyst', 'underscores'], '1']
#      [['analysts', 'various'], '1']
#      [['analytical', 'special'], '1']
#      [['anger', 'social'], '1']
#      [['annual', 'average'], '1']
#      [['annual', 'cost'], '1']
#      [['annual', 'ed'], '1']
#      [['annually', 'e'], '1']
#      [['another', 'current'], '1']
#      [['another', 'indicator'], '1']
#      [['anothet', 'form'], '1']
#      [['answer', 'essential'], '1']
#      [['answer', 'questions'], '1']
#      [['answer', 'regrettably'], '1']
#      [['anticipate', 'finding'], '1']
#      [['anticipated', 'forms'], '1']
#      [['anxiety', 'fear'], '1']
#      [['any', 'associated'], '1']
#      [['any', 'case'], '1']
#      [['any', 'comparison'], '1']
#      [['any', 'diagnosis'], '1']
#      [['any', 'differential'], '1']
#      [['any', 'distorting'], '1']
#      [['any', 'education'], '1']
#      [['any', 'given'], '1']
#      [['any', 'higher'], '1']
#      [['any', 'i'], '1']
#      [['any', 'illness'], '1']
#      [['any', 'new'], '1']
#      [['any', 'observed'], '1']
#      [['any', 'ordinary'], '1']
#      [['any', 'out'], '1']
#      [['any', 'present'], '1']
#      [['any', 'realistic'], '1']
#      [['any', 'reasonable'], '1']
#      [['any', 'specific'], '1']
#      [['any', 'statistically'], '1']
#      [['anyone', 'else'], '1']
#      [['apartment', 'building'], '1']
#      [['apparent', 'assuming'], '1']
#      [['apparent', 'table'], '1']
#      [['appear', 'my'], '1']
#      [['appeared', 'bring'], '1']
#      [['appeared', 'change'], '1']
#      [['appears', 'behavior'], '1']
#      [['appears', 'primarily'], '1']
#      [['appears', 'sheltered'], '1']
#      [['application', 'community'], '1']
#      [['approach', 'adopted'], '1']
#      [['approach', 'being'], '1']
#      [['approach', 'characterized'], '1']
#      [['approach', 'emphasizes'], '1']
#      [['approach', 'involves'], '1']
#      [['approach', 'nontraditional'], '1']
#      [['approach', 'patients'], '1']
#      [['approach', 'study'], '1']
#      [['approach', 'treating'], '1']
#      [['approach', 'under'], '1']
#      [['approach', 'used'], '1']
#      [['approach', 'weisbrod'], '1']
#      [['approach', 'would'], '1']
#      [['approaches', 'example'], '1']
#      [['approaches', 'studied'], '1']
#      [['approaches', 'treating'], '1']
#      [['appropriate', 'should'], '1']
#      [['appropriate', 'three'], '1']
#      [['appropriately', 'includable'], '1']
#      [['approval', 'might'], '1']
#      [['approved', 'way'], '1']
#      [['approved', 'work'], '1']
#      [['approximately', 'equal'], '1']
#      [['approximation', 'value'], '1']
#      [['approximation', 'what'], '1']
#      [['arbitrary', 'methods'], '1']
#      [['archives', 'general'], '1']
#      [['area', 'can'], '1']
#      [['area', 'could'], '1']
#      [['area', 'dane'], '1']
#      [['area', 'do'], '1']
#      [['area', 'we'], '1']
#      [['areas', 'have'], '1']
#      [['arguable', 'maintenance'], '1']
#      [['around', 'home'], '1']
#      [['arrangements', 'therefore'], '1']
#      [['arrests', 'associated'], '1']
#      [['arrests', 'felony'], '1']
#      [['arrests', 'number'], '1']
#      [['ascertain', 'average'], '1']
#      [['ascertained', 'two'], '1']
#      [['asked', 'patient'], '1']
#      [['asked', 'treat'], '1']
#      [['asked', 'whether'], '1']
#      [['aspect', 'its'], '1']
#      [['aspects', 'experi'], '1']
#      [['aspects', 'responsible'], '1']
#      [['assess', 'effects'], '1']
#      [['assessed', 'work'], '1']
#      [['assessment', 'costs'], '1']
#      [['assessment', 'global'], '1']
#      [['assessment', 'how'], '1']
#      [['assessments', 'table'], '1']
#      [['assigned', 'c'], '1']
#      [['assigned', 'equal'], '1']
#      [['assignment', 'process'], '1']
#      [['assist', 'patients'], '1']
#      [['assistance', 'either'], '1']
#      [['assistance', 'helpful'], '1']
#      [['associate', 'professor'], '1']
#      [['associated', 'adjustment'], '1']
#      [['associated', 'laboratory'], '1']
#      [['associated', 'law'], '1']
#      [['associated', 'leisure'], '1']
#      [['assuming', 'b'], '1']
#      [['assuming', 'benefits'], '1']
#      [['assumption', 'low'], '1']
#      [['assumptions', 'consumers'], '1']
#      [['asymptoti', 'cally'], '1']
#      [['attached', 'person'], '1']
#      [['attempt', 'minimize'], '1']
#      [['attempted', 'measure'], '1']
#      [['attended', 'last'], '1']
#      [['attended', 'month'], '1']
#      [['attention', 'has'], '1']
#      [['attention', 'hospitals'], '1']
#      [['attention', 'ques'], '1']
#      [['attitudes', 'behavior'], '1']
#      [['attributable', 'e'], '1']
#      [['attributable', 'hence'], '1']
#      [['attributable', 'only'], '1']
#      [['attributable', 'treatment'], '1']
#      [['attribute', 'differ'], '1']
#      [['attrition', 'great'], '1']
#      [['augment', 'patients'], '1']
#      [['author', 'professor'], '1']
#      [['available', 'available'], '1']
#      [['available', 'both'], '1']
#      [['available', 'labor'], '1']
#      [['available', 'only'], '1']
#      [['available', 'resources'], '1']
#      [['available', 'under'], '1']
#      [['average', 'rate'], '1']
#      [['average', 'reduced'], '1']
#      [['averaged', 'fewer'], '1']
#      [['averaged', 'more'], '1']
#      [['avoid', 'any'], '1']
#      [['avoid', 'contamination'], '1']
#      [['avoid', 'costs'], '1']
#      [['avoid', 'cycle'], '1']
#      [['avoiding', 'effects'], '1']
#      [['aware', 'fact'], '1']
#      [['b', 'data'], '1']
#      [['b', 'live'], '1']
#      [['b', 'number'], '1']
#      [['b', 'showed'], '1']
#      [['b', 'what'], '1']
#      [['back', 'hospital'], '1']
#      [['balloon', 'likely'], '1']
#      [['based', 'alternative'], '1']
#      [['based', 'c'], '1']
#      [['based', 'compared'], '1']
#      [['based', 'e'], '1']
#      [['based', 'examination'], '1']
#      [['based', 'experimental'], '1']
#      [['based', 'historical'], '1']
#      [['based', 'productivity'], '1']
#      [['based', 'programs'], '1']
#      [['based', 'project'], '1']
#      [['baseline', 'admission'], '1']
#      [['baseline', 'time'], '1']
#      [['basis', 'collective'], '1']
#      [['basis', 'e'], '1']
#      [['basis', 'simple'], '1']
#      [['baumol', 'social'], '1']
#      [['bear', 'consequences'], '1']
#      [['became', 'less'], '1']
#      [['became', 'more'], '1']
#      [['because', 'illegal'], '1']
#      [['because', 'increase'], '1']
#      [['because', 'increased'], '1']
#      [['because', 'input'], '1']
#      [['because', 'likely'], '1']
#      [['because', 'mental'], '1']
#      [['because', 'much'], '1']
#      [['because', 'negative'], '1']
#      [['because', 'participation'], '1']
#      [['because', 'patient'], '1']
#      [['because', 'patients'], '1']
#      [['because', 'professional'], '1']
#      [['because', 'spent'], '1']
#      [['because', 'workshops'], '1']
#      [['become', 'ill'], '1']
#      [['becomes', 'apparent'], '1']
#      [['becoming', 'better'], '1']
#      [['been', 'able'], '1']
#      [['been', 'case'], '1']
#      [['been', 'disregarded'], '1']
#      [['been', 'examined'], '1']
#      [['been', 'given'], '1']
#      [['been', 'incurred'], '1']
#      [['been', 'quantified'], '1']
#      [['been', 'undertaken'], '1']
#      [['beesley', 'c'], '1']
#      [['beesley', 'foster'], '1']
#      [['begin', 'provide'], '1']
#      [['beginning', 'october'], '1']
#      [['behave', 'socially'], '1']
#      [['behavior', 'again'], '1']
#      [['behavior', 'against'], '1']
#      [['behavior', 'c'], '1']
#      [['behavior', 'days'], '1']
#      [['behavior', 'discussed'], '1']
#      [['behavior', 'discussion'], '1']
#      [['behavior', 'disrup'], '1']
#      [['behavior', 'either'], '1']
#      [['behavior', 'hallucinations'], '1']
#      [['behavior', 'hence'], '1']
#      [['behavior', 'imposes'], '1']
#      [['behavior', 'leads'], '1']
#      [['behavior', 'part'], '1']
#      [['behavior', 'patients'], '1']
#      [['behavior', 'quantitative'], '1']
#      [['behavior', 'rather'], '1']
#      [['behavior', 'recovery'], '1']
#      [['behavior', 'reflects'], '1']
#      [['behavior', 'teaches'], '1']
#      [['behavior', 'tell'], '1']
#      [['behavior', 'would'], '1']
#      [['behavioral', 'effects'], '1']
#      [['behind', 'pecuniary'], '1']
#      [['being', 'able'], '1']
#      [['being', 'altered'], '1']
#      [['being', 'concentrated'], '1']
#      [['being', 'fired'], '1']
#      [['being', 'involuntary'], '1']
#      [['being', 'kept'], '1']
#      [['being', 'other'], '1']
#      [['being', 'part'], '1']
#      [['being', 'placed'], '1']
#      [['being', 'spread'], '1']
#      [['being', 'treated'], '1']
#      [['belief', 'however'], '1']
#      [['believe', 'within'], '1']
#      [['believing', 'however'], '1']
#      [['below', 'capacity'], '1']
#      [['below', 'connection'], '1']
#      [['below', 'e'], '1']
#      [['below', 'information'], '1']
#      [['below', 'minimum'], '1']
#      [['below', 'pecuniary'], '1']
#      [['below', 'persons'], '1']
#      [['bene', 'ficiaries'], '1']
#      [['beneficial', 'changes'], '1']
#      [['beneficial', 'detrimental'], '1']
#      [['beneficial', 'job'], '1']
#      [['benefit', 'any'], '1']
#      [['benefit', 'both'], '1']
#      [['benefit', 'even'], '1']
#      [['benefit', 'from'], '1']
#      [['benefit', 'measures'], '1']
#      [['benefit', 'successful'], '1']
#      [['benefit', 'two'], '1']
#      [['benefit', 'variables'], '1']
#      [['benefit', 'whether'], '1']
#      [['benefits', 'additive'], '1']
#      [['benefits', 'being'], '1']
#      [['benefits', 'benefits'], '1']
#      [['benefits', 'between'], '1']
#      [['benefits', 'biased'], '1']
#      [['benefits', 'change'], '1']
#      [['benefits', 'comparison'], '1']
#      [['benefits', 'described'], '1']
#      [['benefits', 'during'], '1']
#      [['benefits', 'e'], '1']
#      [['benefits', 'easily'], '1']
#      [['benefits', 'expendi'], '1']
#      [['benefits', 'finances'], '1']
#      [['benefits', 'forms'], '1']
#      [['benefits', 'given'], '1']
#      [['benefits', 'i'], '1']
#      [['benefits', 'its'], '1']
#      [['benefits', 'let'], '1']
#      [['benefits', 'medical'], '1']
#      [['benefits', 'mentally'], '1']
#      [['benefits', 'must'], '1']
#      [['benefits', 'over'], '1']
#      [['benefits', 'patients'], '1']
#      [['benefits', 'per'], '1']
#      [['benefits', 'realized'], '1']
#      [['benefits', 'same'], '1']
#      [['benefits', 'social'], '1']
#      [['benefits', 'treatment'], '1']
#      [['benefits', 'well'], '1']
#      [['benefits', 'were'], '1']
#      [['benefits', 'would'], '1']
#      [['best', 'refrain'], '1']
#      [['better', 'adjusted'], '1']
#      [['better', 'results'], '1']
#      [['between', 'ages'], '1']
#      [['between', 'alternative'], '1']
#      [['between', 'experimentals'], '1']
#      [['between', 'figure'], '1']
#      [['between', 'hospital'], '1']
#      [['between', 'persons'], '1']
#      [['between', 'work'], '1']
#      [['beverly', 'hills'], '1']
#      [['beyond', 'period'], '1']
#      [['bias', 'behavior'], '1']
#      [['biased', 'any'], '1']
#      [['biased', 'upward'], '1']
#      [['boadway', 'welfare'], '1']
#      [['board', 'contacts'], '1']
#      [['both', 'any'], '1']
#      [['both', 'benefits'], '1']
#      [['both', 'conceptual'], '1']
#      [['both', 'costs'], '1']
#      [['both', 'e'], '1']
#      [['both', 'experimental'], '1']
#      [['both', 'from'], '1']
#      [['both', 'groups'], '1']
#      [['both', 'land'], '1']
#      [['both', 'mental'], '1']
#      [['both', 'number'], '1']
#      [['both', 'patients'], '1']
#      [['bound', 'program'], '1']
#      [['brain', 'syndrome'], '1']
#      [['brief', 'duration'], '1']
#      [['brief', 'hospitali'], '1']
#      [['bring', 'even'], '1']
#      [['bring', 'external'], '1']
#      [['bring', 'wide'], '1']
#      [['broad', 'perspective'], '1']
#      [['brook', 'ings'], '1']
#      [['brought', 'about'], '1']
#      [['bs', 'cs'], '1']
#      [['budget', 'constraint'], '1']
#      [['budget', 'constraints'], '1']
#      [['budget', 'makers'], '1']
#      [['budget', 'money'], '1']
#      [['budgetary', 'constraints'], '1']
#      [['budgets', 'does'], '1']
#      [['budgets', 'general'], '1']
#      [['building', 'equipment'], '1']
#      [['building', 'we'], '1']
#      [['buildings', 'based'], '1']
#      [['burden', 'from'], '1']
#      [['burden', 'imposed'], '1']
#      [['burden', 'interview'], '1']
#      [['burdens', 'can'], '1']
#      [['burdens', 'families'], '1']
#      [['burdens', 'family'], '1']
#      [['burdens', 'imposed'], '1']
#      [['burdens', 'property'], '1']
#      [['c', 'analyses'], '1']
#      [['c', 'analyst'], '1']
#      [['c', 'approach'], '1']
#      [['c', 'decreased'], '1']
#      [['c', 'figures'], '1']
#      [['c', 'foster'], '1']
#      [['c', 'new'], '1']
#      [['c', 'people'], '1']
#      [['c', 'pro'], '1']
#      [['c', 'relationship'], '1']
#      [['c', 'significant'], '1']
#      [['c', 'subjects'], '1']
#      [['ca', 'sage'], '1']
#      [['calculating', 'long'], '1']
#      [['california', 'interview'], '1']
#      [['call', 'particuarly'], '1']
#      [['called', 'here'], '1']
#      [['cally', 'while'], '1']
#      [['can', 'expected'], '1']
#      [['can', 'help'], '1']
#      [['can', 'interpreted'], '1']
#      [['can', 'mentally'], '1']
#      [['can', 'mistaken'], '1']
#      [['can', 'only'], '1']
#      [['can', 'provide'], '1']
#      [['can', 'regarded'], '1']
#      [['can', 'result'], '1']
#      [['can', 'serve'], '1']
#      [['can', 'show'], '1']
#      [['can', 'thus'], '1']
#      [['can', 'translated'], '1']
#      [['can', 'view'], '1']
#      [['can', 'viewed'], '1']
#      [['capacity', 'although'], '1']
#      [['capacity', 'between'], '1']
#      [['capacity', 'form'], '1']
#      [['capacity', 'given'], '1']
#      [['capacity', 'while'], '1']
#      [['capital', 'investment'], '1']
#      [['capital', 'perhaps'], '1']
#      [['care', 'because'], '1']
#      [['care', 'budgets'], '1']
#      [['care', 'deinstitutionalization'], '1']
#      [['care', 'improved'], '1']
#      [['care', 'mmhi'], '1']
#      [['care', 'provided'], '1']
#      [['care', 'work'], '1']
#      [['carl', 'dahlman'], '1']
#      [['case', 'any'], '1']
#      [['case', 'hospitalization'], '1']
#      [['case', 'however'], '1']
#      [['case', 'measures'], '1']
#      [['case', 'patients'], '1']
#      [['case', 'steady'], '1']
#      [['case', 'study'], '1']
#      [['case', 'whether'], '1']
#      [['cases', 'key'], '1']
#      [['cases', 'stop'], '1']
#      [['cash', 'large'], '1']
#      [['categories', 'both'], '1']
#      [['categories', 'individuals'], '1']
#      [['category', 'thus'], '1']
#      [['caused', 'patients'], '1']
#      [['causes', 'benefits'], '1']
#      [['causes', 'difference'], '1']
#      [['caution', 'derived'], '1']
#      [['caution', 'f'], '1']
#      [['caution', 'generalizing'], '1']
#      [['centage', 'days'], '1']
#      [['center', 'cost'], '1']
#      [['center', 'dane'], '1']
#      [['center', 'funds'], '1']
#      [['center', 'inc'], '1']
#      [['center', 'payments'], '1']
#      [['certain', 'we'], '1']
#      [['change', 'form'], '1']
#      [['change', 'inform'], '1']
#      [['change', 'thus'], '1']
#      [['change', 'working'], '1']
#      [['changed', 'response'], '1']
#      [['changed', 'social'], '1']
#      [['changes', 'made'], '1']
#      [['changes', 'number'], '1']
#      [['changes', 'over'], '1']
#      [['changes', 'state'], '1']
#      [['changing', 'institutional'], '1']
#      [['characteristics', 'e'], '1']
#      [['characteristics', 'various'], '1']
#      [['characterized', 'active'], '1']
#      [['charles', 'e'], '1']
#      [['check', 'accuracy'], '1']
#      [['check', 'basis'], '1']
#      [['checks', 'were'], '1']
#      [['chicago', 'press'], '1']
#      [['chicago', 'rand'], '1']
#      [['chicago', 'uni'], '1']
#      [['child', 'care'], '1']
#      [['children', 'likely'], '1']
#      [['choice', 'among'], '1']
#      [['choice', 'between'], '1']
#      [['choice', 'discount'], '1']
#      [['choices', 'addi'], '1']
#      [['chronic', 'patient'], '1']
#      [['city', 'madison'], '1']
#      [['city', 'might'], '1']
#      [['class', 'benefit'], '1']
#      [['clear', 'either'], '1']
#      [['clear', 'increment'], '1']
#      [['clear', 'were'], '1']
#      [['clearly', 'imperfect'], '1']
#      [['clearly', 'incomplete'], '1']
#      [['clients', 'also'], '1']
#      [['clinical', 'evaluation'], '1']
#      [['clinical', 'programs'], '1']
#      [['clinical', 'staff'], '1']
#      [['clinical', 'symptoma'], '1']
#      [['closer', 'approximation'], '1']
#      [['clothing', 'etc'], '1']
#      [['collected', 'data'], '1']
#      [['collected', 'during'], '1']
#      [['collection', 'data'], '1']
#      [['collection', 'evaluations'], '1']
#      [['collective', 'willing'], '1']
#      [['com', 'munity'], '1']
#      [['combination', 'vari'], '1']
#      [['combinations', 'answer'], '1']
#      [['combinations', 'variables'], '1']
#      [['come', 'contact'], '1']
#      [['come', 'phenomenon'], '1']
#      [['come', 'reduced'], '1']
#      [['commensurable', 'hence'], '1']
#      [['comments', 'about'], '1']
#      [['comments', 'earlier'], '1']
#      [['commercial', 'rental'], '1']
#      [['committee', 'economic'], '1']
#      [['commodity', 'judged'], '1']
#      [['community', 'acceptance'], '1']
#      [['community', 'adjustment'], '1']
#      [['community', 'c'], '1']
#      [['community', 'contrary'], '1']
#      [['community', 'lead'], '1']
#      [['community', 'mental'], '1']
#      [['community', 'punished'], '1']
#      [['community', 's'], '1']
#      [['community', 'setting'], '1']
#      [['community', 'settings'], '1']
#      [['community', 'table'], '1']
#      [['community', 'treatment'], '1']
#      [['community', 'were'], '1']
#      [['commuunity', 'agencies'], '1']
#      [['compa', 'rable'], '1']
#      [['companions', 'table'], '1']
#      [['compared', 'com'], '1']
#      [['compares', 'terms'], '1']
#      [['comparison', 'costs'], '1']
#      [['comparison', 'made'], '1']
#      [['comparison', 'means'], '1']
#      [['comparison', 'wage'], '1']
#      [['competi', 'tive'], '1']
#      [['competitive', 'market'], '1']
#      [['competitive', 'markets'], '1']
#      [['complaints', 'b'], '1']
#      [['complete', 'may'], '1']
#      [['complete', 'paper'], '1']
#      [['completed', 'additional'], '1']
#      [['completed', 'family'], '1']
#      [['complex', 'concept'], '1']
#      [['complicate', 'matter'], '1']
#      [['complicated', 'substantial'], '1']
#      [['component', 'e'], '1']
#      [['components', 'indirect'], '1']
#      [['comprehensive', 'b'], '1']
#      [['comprehensively', 'change'], '1']
#      [['comprehensively', 'forms'], '1']
#      [['comprehensiveness', 'accounts'], '1']
#      [['comprising', 'city'], '1']
#      [['concentrated', 'onset'], '1']
#      [['concept', 'appears'], '1']
#      [['conceptu', 'ally'], '1']
#      [['conceptual', 'foundations'], '1']
#      [['conceptual', 'goal'], '1']
#      [['conceptual', 'model'], '1']
#      [['conceptually', 'improving'], '1']
#      [['conceptually', 'we'], '1']
#      [['concern', 'future'], '1']
#      [['concern', 'non'], '1']
#      [['concern', 'real'], '1']
#      [['concerned', 'about'], '1']
#      [['concluding', 'remarks'], '1']
#      [['conclusions', 'can'], '1']
#      [['condi', 'tions'], '1']
#      [['conducted', 'following'], '1']
#      [['conducted', 'four'], '1']
#      [['conducted', 'one'], '1']
#      [['confron', 'tation'], '1']
#      [['confronts', 'patients'], '1']
#      [['congress', 'joint'], '1']
#      [['conjecture', 'regarding'], '1']
#      [['conjunction', 'experiment'], '1']
#      [['connection', 'analysis'], '1']
#      [['consequences', 'landlord'], '1']
#      [['consider', 'merely'], '1']
#      [['consider', 'possible'], '1']
#      [['considered', 'consisting'], '1']
#      [['considered', 'evidence'], '1']
#      [['considered', 'net'], '1']
#      [['consisted', 'progressive'], '1']
#      [['consistently', 'had'], '1']
#      [['consisting', 'following'], '1']
#      [['constant', 'level'], '1']
#      [['constitute', 'basis'], '1']
#      [['constitute', 'benefit'], '1']
#      [['constitute', 'measure'], '1']
#      [['constrained', 'utility'], '1']
#      [['constraint', 'conventional'], '1']
#      [['constraints', 'concern'], '1']
#      [['constraints', 'dictated'], '1']
#      [['constraints', 'limited'], '1']
#      [['consumer', 'behavior'], '1']
#      [['consumer', 'expenditure'], '1']
#      [['consumers', 'may'], '1']
#      [['consumers', 'patient'], '1']
#      [['consumers', 'successful'], '1']
#      [['consump', 'tion'], '1']
#      [['consumption', 'behavior'], '1']
#      [['contact', 'asked'], '1']
#      [['contact', 'estimated'], '1']
#      [['contact', 'experi'], '1']
#      [['contact', 'per'], '1']
#      [['contact', 'were'], '1']
#      [['contacted', 'ascertain'], '1']
#      [['contacts', 'arrests'], '1']
#      [['contacts', 'interpreted'], '1']
#      [['contacts', 'law'], '1']
#      [['contacts', 'madison'], '1']
#      [['contacts', 'more'], '1']
#      [['contacts', 'number'], '1']
#      [['contacts', 'patient'], '1']
#      [['contacts', 'total'], '1']
#      [['contacts', 'trusted'], '1']
#      [['contacts', 'various'], '1']
#      [['contains', 'more'], '1']
#      [['contamination', 'study'], '1']
#      [['context', 'continuing'], '1']
#      [['contexts', 'earnings'], '1']
#      [['continued', 'contrary'], '1']
#      [['continued', 'h'], '1']
#      [['continuing', 'cases'], '1']
#      [['continuing', 'national'], '1']
#      [['continuous', 'steady'], '1']
#      [['contrary', 'typically'], '1']
#      [['contrast', 'did'], '1']
#      [['contrast', 'persons'], '1']
#      [['contrast', 'variable'], '1']
#      [['contrasted', 'say'], '1']
#      [['contributions', 'susan'], '1']
#      [['contro', 'versial'], '1']
#      [['control', 'difference'], '1']
#      [['control', 'differences'], '1']
#      [['control', 'different'], '1']
#      [['control', 'group'], '1']
#      [['control', 'program'], '1']
#      [['control', 'programs'], '1']
#      [['controlled', 'experimentation'], '1']
#      [['controlled', 'income'], '1']
#      [['controlled', 'social'], '1']
#      [['controls', 'asymptoti'], '1']
#      [['controls', 'several'], '1']
#      [['conventional', 'assumptions'], '1']
#      [['conventional', 'c'], '1']
#      [['conversation', 'carl'], '1']
#      [['cooking', 'social'], '1']
#      [['cope', 'ordinary'], '1']
#      [['coping', 'skills'], '1']
#      [['cost', 'additional'], '1']
#      [['cost', 'assuming'], '1']
#      [['cost', 'b'], '1']
#      [['cost', 'burdens'], '1']
#      [['cost', 'change'], '1']
#      [['cost', 'contact'], '1']
#      [['cost', 'differed'], '1']
#      [['cost', 'empirical'], '1']
#      [['cost', 'figure'], '1']
#      [['cost', 'inpatient'], '1']
#      [['cost', 'land'], '1']
#      [['cost', 'one'], '1']
#      [['cost', 'only'], '1']
#      [['cost', 'our'], '1']
#      [['cost', 'per'], '1']
#      [['cost', 'physical'], '1']
#      [['cost', 'proved'], '1']
#      [['cost', 'rather'], '1']
#      [['cost', 'relationships'], '1']
#      [['cost', 'saving'], '1']
#      [['cost', 'section'], '1']
#      [['cost', 'simply'], '1']
#      [['cost', 'statistic'], '1']
#      [['cost', 'supervision'], '1']
#      [['cost', 'terms'], '1']
#      [['cost', 'work'], '1']
#      [['cost', 'worry'], '1']
# ...
#      [['types', 'delivery'], '1']
#      [['types', 'efforts'], '1']
#      [['types', 'mental'], '1']
#      [['typically', 'have'], '1']
#      [['typically', 'involves'], '1']
#      [['unable', 'develop'], '1']
#      [['unadjusted', 'difference'], '1']
#      [['uncertainties', 'psychiatrist'], '1']
#      [['uncommon', 'persons'], '1']
#      [['under', 'c'], '1']
#      [['under', 'e'], '1']
#      [['under', 'same'], '1']
#      [['under', 'way'], '1']
#      [['underestimated', 'c'], '1']
#      [['underestimating', 'e'], '1']
#      [['underlying', 'theory'], '1']
#      [['underscore', 'fact'], '1']
#      [['underscores', 'policy'], '1']
#      [['understood', 'ways'], '1']
#      [['undertake', 'because'], '1']
#      [['undertaken', 'interest'], '1']
#      [['undertaking', 'economic'], '1']
#      [['underutilized', 'staff'], '1']
#      [['unemployment', 'rate'], '1']
#      [['unfortunately', 'so'], '1']
#      [['unhappy', 'about'], '1']
#      [['uni', 'versity'], '1']
#      [['unique', 'time'], '1']
#      [['unit', 'staff'], '1']
#      [['unit', 'were'], '1']
#      [['units', 'which'], '1']
#      [['unlike', 'hospital'], '1']
#      [['unpaid', 'work'], '1']
#      [['unused', 'capacity'], '1']
#      [['unusual', 'manner'], '1']
#      [['unusually', 'wide'], '1']
#      [['unwilling', 'provide'], '1']
#      [['up', 'interviews'], '1']
#      [['up', 'phase'], '1']
#      [['up', 'quantiative'], '1']
#      [['upward', 'allow'], '1']
#      [['upward', 'bound'], '1']
#      [['upward', 'omission'], '1']
#      [['us', 'information'], '1']
#      [['use', 'available'], '1']
#      [['use', 'facilities'], '1']
#      [['use', 'resources'], '1']
#      [['use', 'today'], '1']
#      [['used', 'control'], '1']
#      [['used', 'evaluated'], '1']
#      [['used', 'far'], '1']
#      [['used', 'obtain'], '1']
#      [['used', 'secondary'], '1']
#      [['used', 'when'], '1']
#      [['useful', 'consider'], '1']
#      [['useful', 'data'], '1']
#      [['useful', 'though'], '1']
#      [['usual', 'response'], '1']
#      [['usually', 'has'], '1']
#      [['usually', 'though'], '1']
#      [['utility', 'from'], '1']
#      [['utility', 'func'], '1']
#      [['utility', 'maxi'], '1']
#      [['utility', 'maximization'], '1']
#      [['utility', 'maximizers'], '1']
#      [['utility', 'subject'], '1']
#      [['utilization', 'e'], '1']
#      [['utilization', 'its'], '1']
#      [['utilization', 'never'], '1']
#      [['utilized', 'cost'], '1']
#      [['utilized', 'methodology'], '1']
#      [['utilized', 'per'], '1']
#      [['utilized', 'were'], '1']
#      [['v', 'concluding'], '1']
#      [['v', 'glass'], '1']
#      [['valuable', 'i'], '1']
#      [['valuation', 'practical'], '1']
#      [['valuation', 'problems'], '1']
#      [['valuations', 'life'], '1']
#      [['value', 'any'], '1']
#      [['value', 'better'], '1']
#      [['value', 'household'], '1']
#      [['value', 'land'], '1']
#      [['value', 'leisure'], '1']
#      [['value', 'life'], '1']
#      [['value', 'lost'], '1']
#      [['value', 'marginal'], '1']
#      [['value', 'monetary'], '1']
#      [['value', 'physical'], '1']
#      [['value', 'stream'], '1']
#      [['value', 'summing'], '1']
#      [['value', 'worker'], '1']
#      [['valued', 'benefits'], '1']
#      [['valued', 'costs'], '1']
#      [['values', 'based'], '1']
#      [['values', 'have'], '1']
#      [['values', 'interviews'], '1']
#      [['values', 'particular'], '1']
#      [['values', 'rather'], '1']
#      [['values', 'state'], '1']
#      [['values', 'them'], '1']
#      [['vari', 'ables'], '1']
#      [['variable', 'capacity'], '1']
#      [['variable', 'discussed'], '1']
#      [['variable', 'time'], '1']
#      [['variables', 'any'], '1']
#      [['variables', 'b'], '1']
#      [['variables', 'being'], '1']
#      [['variables', 'conceptually'], '1']
#      [['variables', 'four'], '1']
#      [['variables', 'table'], '1']
#      [['variables', 'theoretic'], '1']
#      [['variation', 'both'], '1']
#      [['variation', 'rate'], '1']
#      [['variety', 'activities'], '1']
#      [['variety', 'benefit'], '1']
#      [['variety', 'diagnoses'], '1']
#      [['variety', 'perspectives'], '1']
#      [['variety', 'tangible'], '1']
#      [['various', 'adverse'], '1']
#      [['various', 'agencies'], '1']
#      [['various', 'ap'], '1']
#      [['various', 'other'], '1']
#      [['various', 'public'], '1']
#      [['various', 'stages'], '1']
#      [['various', 'symptoms'], '1']
#      [['various', 'ways'], '1']
#      [['vary', 'control'], '1']
#      [['vary', 'great'], '1']
#      [['vary', 'treatment'], '1']
#      [['verified', 'agencies'], '1']
#      [['verified', 'those'], '1']
#      [['verrill', 'also'], '1']
#      [['versial', 'measures'], '1']
#      [['versity', 'chicago'], '1']
#      [['versus', 'deinstitutional'], '1']
#      [['very', 'brief'], '1']
#      [['very', 'definition'], '1']
#      [['very', 'different'], '1']
#      [['very', 'much'], '1']
#      [['vested', 'interest'], '1']
#      [['via', 'education'], '1']
#      [['victor', 'halberstadt'], '1']
#      [['victoria', 'subway'], '1']
#      [['viders', 'were'], '1']
#      [['view', 'behavior'], '1']
#      [['viewed', 'comprehensively'], '1']
#      [['viewed', 'evaluated'], '1']
#      [['viewed', 'having'], '1']
#      [['views', 'number'], '1']
#      [['views', 'were'], '1']
#      [['violating', 'minor'], '1']
#      [['virtually', 'all'], '1']
#      [['virtually', 'eliminated'], '1']
#      [['virtually', 'identical'], '1']
#      [['visit', 'calculating'], '1']
#      [['voluntary', 'during'], '1']
#      [['w', 'boadway'], '1']
#      [['w', 'jones'], '1']
#      [['w', 'watts'], '1']
#      [['wage', 'determination'], '1']
#      [['wage', 'job'], '1']
#      [['wage', 'losses'], '1']
#      [['wage', 'may'], '1']
#      [['wage', 'might'], '1']
#      [['wage', 'more'], '1']
#      [['wage', 'rate'], '1']
#      [['wage', 'rates'], '1']
#      [['wage', 'records'], '1']
#      [['wage', 'state'], '1']
#      [['wage', 'which'], '1']
#      [['wages', 'do'], '1']
#      [['wages', 'either'], '1']
#      [['wages', 'paid'], '1']
#      [['wages', 'sheltered'], '1']
#      [['walter', 'i'], '1']
#      [['want', 'measure'], '1']
#      [['want', 'treatment'], '1']
#      [['ward', 'mmhi'], '1']
#      [['ware', 'housing'], '1']
#      [['warped', 'he'], '1']
#      [['washing', 'ton'], '1']
#      [['washington', 'brook'], '1']
#      [['watts', 'social'], '1']
#      [['way', 'certain'], '1']
#      [['way', 'improved'], '1']
#      [['way', 'may'], '1']
#      [['way', 'several'], '1']
#      [['ways', 'available'], '1']
#      [['ways', 'from'], '1']
#      [['ways', 'same'], '1']
#      [['we', 'able'], '1']
#      [['we', 'attempted'], '1']
#      [['we', 'can'], '1']
#      [['we', 'did'], '1']
#      [['we', 'do'], '1']
#      [['we', 'find'], '1']
#      [['we', 'obtained'], '1']
#      [['we', 'proxied'], '1']
#      [['we', 'seek'], '1']
#      [['we', 'should'], '1']
#      [['we', 'simply'], '1']
#      [['we', 'utilized'], '1']
#      [['we', 'want'], '1']
#      [['week', 'indeed'], '1']
#      [['weeks', 'preceding'], '1']
#      [['wei', 'hu'], '1']
#      [['weisbrod', 'abstract'], '1']
#      [['weisbrod', 'costs'], '1']
#      [['weisbrod', 'i'], '1']
#      [['welfare', 'benefits'], '1']
#      [['welfare', 'foundations'], '1']
#      [['welfare', 'pursuant'], '1']
#      [['well', 'close'], '1']
#      [['well', 'differ'], '1']
#      [['well', 'discount'], '1']
#      [['well', 'exceed'], '1']
#      [['well', 'founded'], '1']
#      [['well', 'from'], '1']
#      [['well', 'increase'], '1']
#      [['well', 'marginal'], '1']
#      [['well', 'money'], '1']
#      [['well', 'result'], '1']
#      [['were', 'about'], '1']
#      [['were', 'affected'], '1']
#      [['were', 'all'], '1']
#      [['were', 'any'], '1']
#      [['were', 'asked'], '1']
#      [['were', 'assigned'], '1']
#      [['were', 'becoming'], '1']
#      [['were', 'being'], '1']
#      [['were', 'between'], '1']
#      [['were', 'collected'], '1']
#      [['were', 'complete'], '1']
#      [['were', 'completed'], '1']
#      [['were', 'considered'], '1']
#      [['were', 'costs'], '1']
#      [['were', 'counted'], '1']
#      [['were', 'described'], '1']
#      [['were', 'designing'], '1']
#      [['were', 'diagnosed'], '1']
#      [['were', 'e'], '1']
#      [['were', 'effect'], '1']
#      [['were', 'examined'], '1']
#      [['were', 'experiencing'], '1']
#      [['were', 'felt'], '1']
#      [['were', 'found'], '1']
#      [['were', 'fully'], '1']
#      [['were', 'generally'], '1']
#      [['were', 'held'], '1']
#      [['were', 'included'], '1']
#      [['were', 'interviewed'], '1']
#      [['were', 'involved'], '1']
#      [['were', 'longer'], '1']
#      [['were', 'more'], '1']
#      [['were', 'often'], '1']
#      [['were', 'paid'], '1']
#      [['were', 'partially'], '1']
#      [['were', 'particularly'], '1']
#      [['were', 'permanent'], '1']
#      [['were', 'probably'], '1']
#      [['were', 'randomly'], '1']
#      [['were', 'realized'], '1']
#      [['were', 'resi'], '1']
#      [['were', 'respectively'], '1']
#      [['were', 'screened'], '1']
#      [['were', 'short'], '1']
#      [['were', 'significant'], '1']
#      [['were', 'some'], '1']
#      [['were', 'sometimes'], '1']
#      [['were', 'spending'], '1']
#      [['were', 'statistically'], '1']
#      [['were', 'taken'], '1']
#      [['were', 'unhappy'], '1']
#      [['were', 'unwilling'], '1']
#      [['were', 'usually'], '1']
#      [['were', 'verified'], '1']
#      [['were', 'virtually'], '1']
#      [['were', 'would'], '1']
#      [['what', 'cost'], '1']
#      [['what', 'instance'], '1']
#      [['what', 'kinds'], '1']
#      [['what', 'measure'], '1']
#      [['what', 'mentally'], '1']
#      [['what', 'nonmentally'], '1']
#      [['what', 'normative'], '1']
#      [['when', 'interviewer'], '1']
#      [['when', 'interviewers'], '1']
#      [['when', 'least'], '1']
#      [['when', 'mental'], '1']
#      [['when', 'multi'], '1']
#      [['when', 'need'], '1']
#      [['when', 'one'], '1']
#      [['when', 'patients'], '1']
#      [['when', 'realized'], '1']
#      [['when', 'those'], '1']
#      [['where', 'empirical'], '1']
#      [['where', 'former'], '1']
#      [['where', 'mentally'], '1']
#      [['where', 'were'], '1']
#      [['whereas', 'because'], '1']
#      [['whether', 'added'], '1']
#      [['whether', 'behavioral'], '1']
#      [['whether', 'e'], '1']
#      [['whether', 'hospitalization'], '1']
#      [['whether', 'measure'], '1']
#      [['whether', 'monetary'], '1']
#      [['whether', 'our'], '1']
#      [['whether', 'pecuniary'], '1']
#      [['whether', 'subject'], '1']
#      [['which', 'all'], '1']
#      [['which', 'appropriately'], '1']
#      [['which', 'approximation'], '1']
#      [['which', 'can'], '1']
#      [['which', 'carried'], '1']
#      [['which', 'demand'], '1']
#      [['which', 'each'], '1']
#      [['which', 'effects'], '1']
#      [['which', 'felt'], '1']
#      [['which', 'have'], '1']
#      [['which', 'hospital'], '1']
#      [['which', 'individual'], '1']
#      [['which', 'led'], '1']
#      [['which', 'lie'], '1']
#      [['which', 'makes'], '1']
#      [['which', 'measures'], '1']
#      [['which', 'most'], '1']
#      [['which', 'must'], '1']
#      [['which', 'one'], '1']
#      [['which', 'patient'], '1']
#      [['which', 'quantitative'], '1']
#      [['which', 'records'], '1']
#      [['which', 'reflect'], '1']
#      [['which', 'see'], '1']
#      [['which', 'time'], '1']
#      [['which', 'treatment'], '1']
#      [['which', 'were'], '1']
#      [['which', 'while'], '1']
#      [['whichever', 'treatment'], '1']
#      [['while', 'caution'], '1']
#      [['while', 'complex'], '1']
#      [['while', 'expenditures'], '1']
#      [['while', 'including'], '1']
#      [['while', 'increased'], '1']
#      [['while', 'most'], '1']
#      [['while', 'only'], '1']
#      [['while', 'person'], '1']
#      [['while', 'relevant'], '1']
#      [['while', 'sample'], '1']
#      [['while', 'underestimating'], '1']
#      [['while', 'we'], '1']
#      [['who', 'collected'], '1']
#      [['who', 'currently'], '1']
#      [['who', 'does'], '1']
#      [['who', 'frequently'], '1']
#      [['who', 'had'], '1']
#      [['who', 'have'], '1']
#      [['who', 'impose'], '1']
#      [['who', 'proposed'], '1']
#      [['who', 'served'], '1']
#      [['who', 'time'], '1']
#      [['whole', 'study'], '1']
#      [['whole', 'which'], '1']
#      [['whom', 'external'], '1']
#      [['whom', 'patients'], '1']
#      [['william', 'baumol'], '1']
#      [['willing', 'ness'], '1']
#      [['willingness', 'affected'], '1']
#      [['willingness', 'should'], '1']
#      [['willingnesses', 'pay'], '1']
#      [['wisconsin', 'area'], '1']
#      [['wisconsin', 'comprising'], '1']
#      [['wisconsin', 'cost'], '1']
#      [['wisconsin', 'during'], '1']
#      [['wisconsin', 'health'], '1']
#      [['withdraw', 'from'], '1']
#      [['withdrawal', 'motor'], '1']
#      [['within', 'hospital'], '1']
#      [['without', 'broad'], '1']
#      [['without', 'treatment'], '1']
#      [['wonder', 'whether'], '1']
#      [['work', 'appeared'], '1']
#      [['work', 'around'], '1']
#      [['work', 'became'], '1']
#      [['work', 'because'], '1']
#      [['work', 'being'], '1']
#      [['work', 'data'], '1']
#      [['work', 'decreased'], '1']
#      [['work', 'difficult'], '1']
#      [['work', 'etc'], '1']
#      [['work', 'experience'], '1']
#      [['work', 'he'], '1']
#      [['work', 'mentally'], '1']
#      [['work', 'nonwork'], '1']
#      [['work', 'one'], '1']
#      [['work', 'other'], '1']
#      [['work', 'participation'], '1']
#      [['work', 'patients'], '1']
#      [['work', 'presented'], '1']
#      [['work', 'receives'], '1']
#      [['work', 'school'], '1']
#      [['work', 'setting'], '1']
#      [['work', 'shop'], '1']
#      [['work', 'shorter'], '1']
#      [['work', 'time'], '1']
#      [['work', 'university'], '1']
#      [['work', 'would'], '1']
#      [['worked', 'directly'], '1']
#      [['worked', 'more'], '1']
#      [['worked', 'pilot'], '1']
#      [['worked', 'wages'], '1']
#      [['workers', 'efficiency'], '1']
#      [['workers', 'patients'], '1']
#      [['workers', 'were'], '1']
#      [['working', 'became'], '1']
#      [['working', 'e'], '1']
#      [['working', 'more'], '1']
#      [['working', 'result'], '1']
#      [['working', 'socially'], '1']
#      [['workshop', 'clients'], '1']
#      [['workshop', 'costs'], '1']
#      [['workshop', 'days'], '1']
#      [['workshop', 'employment'], '1']
#      [['workshop', 'programs'], '1']
#      [['workshops', 'determined'], '1']
#      [['workshops', 'example'], '1']
#      [['workshops', 'however'], '1']
#      [['workshops', 'other'], '1']
#      [['workshops', 'themselves'], '1']
#      [['workshops', 'total'], '1']
#      [['workshops', 'visiting'], '1']
#      [['workshops', 'were'], '1']
#      [['world', 'outside'], '1']
#      [['worry', 'disrup'], '1']
#      [['would', 'avoid'], '1']
#      [['would', 'because'], '1']
#      [['would', 'better'], '1']
#      [['would', 'case'], '1']
#      [['would', 'come'], '1']
#      [['would', 'differ'], '1']
#      [['would', 'different'], '1']
#      [['would', 'encompass'], '1']
#      [['would', 'encourage'], '1']
#      [['would', 'evicted'], '1']
#      [['would', 'hazardous'], '1']
#      [['would', 'hold'], '1']
#      [['would', 'identify'], '1']
#      [['would', 'justify'], '1']
#      [['would', 'least'], '1']
#      [['would', 'likely'], '1']
#      [['would', 'necessarily'], '1']
#      [['would', 'occur'], '1']
#      [['would', 'otherwise'], '1']
#      [['would', 'program'], '1']
#      [['would', 'promote'], '1']
#      [['would', 'reveal'], '1']
#      [['would', 'we'], '1']
#      [['would', 'willing'], '1']
#      [['year', 'analysis'], '1']
#      [['year', 'avoid'], '1']
#      [['year', 'days'], '1']
#      [['year', 'experiment'], '1']
#      [['year', 'figures'], '1']
#      [['year', 'percentage'], '1']
#      [['year', 'person'], '1']
#      [['year', 'recall'], '1']
#      [['year', 'return'], '1']
#      [['year', 'suicide'], '1']
#      [['year', 'treatment'], '1']
#      [['year', 'when'], '1']
#      [['year', 'whichever'], '1']
#      [['year', 'while'], '1']
#      [['years', 'during'], '1']
#      [['years', 'has'], '1']
#      [['years', 'since'], '1']
#      [['yielded', 'data'], '1']
#      [['yielded', 'dollar'], '1']
#      [['yielding', 'returns'], '1']
#      [['york', 'praeger'], '1']
#      [['zation', 'action'], '1']
#      [['zation', 'instead'], '1']
#      [['zero', 'each'], '1']
#      [['zero', 'implausible'], '1']
#      [['zero', 'may'], '1']
#      [['zero', 'patient'], '1']
#      [['zero', 'reserva'], '1']

# %%
"""
Create Dataframe
""" 
# Data
data = []
for words, freq in freq_list:
    assert len(words) == 2
    data.append([words[0], words[1], freq])

# Columns
columns = ["word1", "word2", "freq"]

# Index
index = list(range(len(freq_list)))

# DataFrame
dataframe = pd.DataFrame(data, columns=columns, index=index)

# Print Test
dataframe.head()
# Out:
#       word1     word2 freq
# 0         e   program   34
# 1  mentally       ill   34
# 2         e     group   33
# 3    mental    health   33
# 4     costs  benefits   17

# %%
"""
Run filtering for each file
"""
for file in filtered_list:
    # Open file
    try:
        file_open = open(file, mode="r")
    except IOError:
        print("Error opening file {0}".format(file))
        exit(0)
    
    # Create output file
    output_name = "Result_" + file
    output_file = open(output_name, mode="w+")
    
    # Track for max length word
    # Used for formatting output data
    max_length = [float("-inf")] * 2
        
    # Initiate freq_list -> [[words0, freq0], [words1, freq1]]
    freq_list = []
    
    # Read by line
    for line in file_open:
        assert isinstance(line, str)
        pair = line.strip().split()
    
        # Separate word/freq
        words, freq = pair[:-1], pair[-1]
        assert len(words) == 2
        assert freq.isdigit()
        
        # Filter by word's attribute
        if check_words(words):
            continue
        
        # Update max_length
        for i in range(len(words)):
            if len(words[i]) > max_length[i]:
                max_length[i] = len(words[i])
            
            
        # Append new pair to freq_list
        freq_list.append([words, freq])
    
    # Close reading file
    file_open.close()
    
    # Create Dataframe
    # Data
    data = []
    for words, freq in freq_list:
        assert len(words) == 2
        data.append([words[0], words[1], freq])

    # Columns
    columns = ["word1", "word2", "freq"]

    # Index
    index = list(range(len(freq_list)))

    # DataFrame
    dataframe = pd.DataFrame(data, columns=columns, index=index)
    
    # Write to output file
    for words, freq in freq_list:
        output_file.write(words[0].ljust(max_length[0] + 5))
        output_file.write(words[1].ljust(max_length[1] + 5))
        output_file.write(freq + "\n")
    
    # Close output_file
    output_file.close()
    
    print(dataframe.head())
# Out:
#       word1     word2 freq
# 0         e   program   34
# 1  mentally       ill   34
# 2         e     group   33
# 3    mental    health   33
# 4     costs  benefits   17
#           word1         word2 freq
# 0       written          test   17
# 1  occupational     licensing   12
# 2             i             i   11
# 3       written   examination   11
# 4     licensing  examinations   10
#         word1       word2 freq
# 0       price      listed   16
# 1      listed       paper   15
# 2         new        york    8
# 3    american  enterprise    7
# 4  enterprise   institute    7
#      word1      word2 freq
# 0      job     search   24
# 1     wage       rate   15
# 2    human  resources   10
# 3  journal      human   10
# 4    labor     market   10
#            word1       word2 freq
# 0    achievement  motivation   27
# 1         father           s   15
# 2       parental      income   14
# 3  socioeconomic  background   12
# 4    educational  attainment   11
#        word1        word2 freq
# 0        ses      schools   14
# 1   teachers          who   14
# 2  declining  enrollments   11
# 3    midcity       system   11
# 4    student  enrollments   11
#      word1      word2 freq
# 0    labor     market    5
# 1    human  resources    4
# 2  journal      human    4
# 3    keith          b    4
# 4     alan          p    3
#      word1        word2 freq
# 0   income  maintenance   34
# 1    split        rates   27
# 2  marital  dissolution   26
# 3   female     headship   22
# 4    human    resources   22
#       word1      word2 freq
# 0    social   security   18
# 1      high     school   11
# 2   college   students    8
# 3  relative   earnings    6
# 4   college  graduates    5
#     word1      word2 freq
# 0       b          m   21
# 1      ui   benefits   16
# 2  search     effort   13
# 3      ui  receivers   11
# 4       m          s    9
#       word1   word2 freq
# 0      quit   rates   39
# 1      firm    size   30
# 2      quit    rate   27
# 3  turnover   costs   25
# 4   private  sector   24
#         word1       word2 freq
# 0       price      listed   10
# 1         new        york    8
# 2    american  enterprise    5
# 3   cambridge          ma    5
# 4  enterprise   institute    5
#         word1      word2 freq
# 0  university  wisconsin    6
# 1   economics  wisconsin    5
# 2  industrial  relations    5
# 3       human  resources    4
# 4     journal      human    4
#        word1      word2 freq
# 0     mental     health   99
# 1     health   services   36
# 2     mental    illness   23
# 3    federal  employees   22
# 4  insurance   coverage   18
#         word1      word2 freq
# 0     journal      human    7
# 1  university  wisconsin    7
# 2       human  resources    6
# 3  industrial  relations    4
# 4   wisconsin      press    4
#      word1         word2 freq
# 0    labor        market   35
# 1  teenage  unemployment   26
# 2   market    experience   16
# 3    human     resources   14
# 4  journal         human   11
#         word1      word2 freq
# 0  university  wisconsin    6
# 1   economics  wisconsin    5
# 2  industrial  relations    5
# 3       human  resources    4
# 4     journal      human    4
#           word1    word2 freq
# 0  posttransfer  poverty   28
# 1         labor   supply   25
# 2      earnings  poverty   23
# 3      earnings     poor   14
# 4             t      aed   13
#      word1     word2 freq
# 0   mental    health   43
# 1   health      care   13
# 2   mental   illness   10
# 3  benefit      cost    9
# 4   health  services    9
#       word1       word2 freq
# 0    social    security   41
# 1  derthick           s    5
# 2     those         who    5
# 3   program  executives    4
# 4       who        were    4
