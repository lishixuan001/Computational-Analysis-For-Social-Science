# %%
"""
Exit Code:
    0: Error opening file
"""

import os
from os import listdir
from os.path import isfile, join

from parse import *
from collections import Counter

import pandas as pd
import numpy as np

# %%
"""
Define formatted display function
Used to replace regular print function
"""
# Get name of an object
def namestr(obj, namespace):
    return [name for name in namespace if namespace[name] is obj]

# Display with format
def display(items, func=None):
    print(namestr(items, globals()))
    for item in items:
        if func:
            item = func(item)
        print("     {0}".format(item))

# Test display
test_dict = {"A": [1, 2, 3], "B": [4, 5, 6]}
display(test_dict)
# Out:
# ['test_dict']
#      A
#      B

# %%
# Base on each folder (ngram-1, ngram-2, ngram-3).
# Create DataFrame: 
#    art_id; word_ngram_1; freq_ngram_1; word1_ngram_2; word2_ngram_2; freq_ngram_2; 
#    word1_ngram_3; word2_ngram_3; word3_ngram_3; freq_ngram_3;

# %%
"""
Define function to ilter out directories ngram-1, ngram-2, n-gram3
"""
def valid_direct(direct_name):
    assert isinstance(direct_name, str)
    
    # Eliminate the "../" in the front if there is one
    if direct_name.startswith("../"):
        direct_name = direct_name[3:]
    
    # Exculde if name starts with "."
    if direct_name.startswith("."):
        return False
    
    # Test if name starts with ngram
    if direct_name.startswith("ngram"):
        return True
    
    # Otherwise
    return False

# %%
"""
Get filtering results
"""
datapath = "../"
directories = sorted([direct for direct in os.listdir(datapath) if valid_direct(direct)])
print(directories)
# Out:
# ['ngram1', 'ngram2', 'ngram3']

# %%
"""
Function filtering files by filenames.
-- Only accepts files starts with "journal-article"
"""
def filter_by_filename(files_list):
    filtered_list = []
    for filename in files_list:
        # Check if the filename starts with "journal-article"
        assert isinstance(filename, str)
        # Check the first 20 characters of the file name
        if filename.startswith("journal-article", 0, 20):
            filtered_list.append(filename)
    return filtered_list

# %%
"""
Define function getting article ID from a filename by parsing pattern
"""
def parse_id(filename, pattern):
    return parse(pattern, filename)["art_id"]

# %%
"""
Define function extract article IDs from filenames
-- parsing tricks learned from "https://pypi.org/project/parse/"
"""
def extract_id(files_list, direct):
    # direct -> "ngram1" || "ngram2" || "ngram3"
    
    art_id_lst = []
    
    # Define Pattern
    pattern = "journal-article-10.2307_{art_id}-" + direct + ".txt"
    
    # Match filenames with pattern
    for filename in files_list:
        art_id_lst.append(parse_id(filename, pattern))
    
    return art_id_lst

# %%
"""
Define function extract all article IDs under a directory
"""
def get_id_lst(direct):
    directpath = join(datapath, direct)
    
    # Get files under a directory
    files_list = [file for file in listdir(directpath) if isfile(join(directpath, file))]
    
    # Filter files by filenames
    files_list = filter_by_filename(files_list)
    
    # Parsing the filenames to extract IDs
    art_id_lst = extract_id(files_list, direct)
    
    return art_id_lst

# %%
"""
Get ID lists for each ngram data set
"""
art_id_lsts = [get_id_lst(direct) for direct in directories]
display(art_id_lsts, sorted)
# Out:
# ['art_id_lsts']
#      ['145203', '145208', '145211', '145213', '145215', '145216', '145218', '145221', '145224', '145226', '145227', '145230', '145231', '145233', '145234', '145235', '145242', '145286', '145288', '145292']
#      ['145203', '145208', '145211', '145213', '145215', '145216', '145218', '145221', '145224', '145226', '145227', '145230', '145231', '145233', '145234', '145235', '145242', '145286', '145288', '145292']
#      ['145203', '145208', '145211', '145213', '145215', '145216', '145218', '145221', '145224', '145226', '145227', '145230', '145231', '145233', '145234', '145235', '145242', '145286', '145288', '145292']

# %%
"""
Check if all article IDs co-exist in three directorys
"""
# Define a function comparing list
def compare_lst(lst1, lst2):
    return Counter(lst1) == Counter(lst2)

# Check if all ngram data sets share same set of article IDs
check_co_exist = art_id_lsts and all(compare_lst(art_id_lsts[0], art_id_lst) for art_id_lst in art_id_lsts)

# Check result
print(check_co_exist)
# Out:
# True

# %%
"""
Collect ngram cleaning results by our indivisually analyzed results
Read data from "Result_journal-.....txt"
"""
# ngram = [ngram_1, ngram_2, ngram_3]
# ngram_1 = [words_ngram_1, freq_ngram_1]
# ...
# Out:
# '\nCollect ngram cleaning results by our indivisually analyzed results\nRead data from "Result_journal-.....txt"\n'

# %%
"""
Filter out Result files
-- Only save those starts with "Result_journal-article"
"""
def filter_for_results(files_list):
    filtered_list = []
    for filename in files_list:
        
        # Check if the filename starts with "Result_journal-article"
        assert isinstance(filename, str)
        
        # Check the first 20 characters of the file name
        if filename.startswith("Result_journal-article"):
            filtered_list.append(filename)
            
    return filtered_list

# %%
"""
Define a function to collect data from ngram results
-- Output [words_ngram_X, freq_ngram_X]
"""
def collect_data(direct):
    directpath = join(datapath, direct)
    
    # Get files under a directory
    files_list = [file for file in listdir(directpath) if isfile(join(directpath, file))]
    
    # Filter files by filenames
    filtered_list = filter_for_results(files_list)
    
    # Sum of freq lists
    # freq_lists -> {ID1: freq_list1, ID2: freq_list2}
    freq_lists = {}
    
    # Iterate through files
    for filename in filtered_list:
        # Open file
        try:
            file_open = open(join(directpath, filename), mode="r")
        except Exception as e:
            print("Error opening file {0}".format(filename))
            print("Error message: <{0}>".format(e))
            exit(0)
        
        # Initiate freq_list -> [[words0, freq0], [words1, freq1]]
        freq_list = []
        
        # Read by line
        for line in file_open:
            # line -> "word1 word2 word3 5"
            assert isinstance(line, str)
            
            # pair -> "["word1", "word2", "word3", "5"]
            pair = line.strip().split()
            assert len(pair) >= 2

            # Separate word/freq
            words, freq = pair[:-1], pair[-1]
            assert freq.isdigit()

            # Append new pair to freq_list
            freq_list.append([words, freq])
        
        # Close reading file
        file_open.close()
        
        # Get article/file ID
        pattern = "Result_journal-article-10.2307_{art_id}-" + direct + ".txt"
        art_id = parse_id(filename, pattern)
        
        # Append to overall list
        freq_lists.update({art_id : freq_list})
            
    return freq_lists

# %%
"""
Collect data from ngrams
"""
# Sequence is very important here since it matters the sequence we save data in "ngrams"
assert directories == sorted(directories)

ngrams = []
for direct in directories:
    # Collect data
    data = collect_data(direct)
    assert len(data) > 0

    ngrams.append(data)

"""
Test freq_lists
"""
index = 1
for key in ngrams[index]:
    print(key)
    display(ngrams[index][key])
# Out:
# 145208
# []
#      [['quit', 'rates'], '39']
#      [['firm', 'size'], '30']
#      [['quit', 'rate'], '27']
#      [['turnover', 'costs'], '25']
#      [['private', 'sector'], '24']
#      [['government', 'private'], '10']
#      [['relationship', 'between'], '10']
#      [['large', 'firms'], '9']
#      [['human', 'resources'], '8']
#      [['journal', 'human'], '8']
#      [['size', 'government'], '8']
#      [['size', 'earnings'], '7']
#      [['between', 'government'], '6']
#      [['cross', 'state'], '6']
#      [['difference', 'between'], '6']
#      [['differences', 'between'], '6']
#      [['federal', 'pay'], '6']
#      [['more', 'than'], '6']
#      [['pay', 'comparability'], '6']
#      [['blue', 'collar'], '5']
#      [['comparable', 'pay'], '5']
#      [['government', 'pay'], '5']
#      [['public', 'sector'], '5']
#      [['than', 'private'], '5']
#      [['turnover', 'statistics'], '5']
#      [['white', 'collar'], '5']
#      [['across', 'industries'], '4']
#      [['alexandria', 'va'], '4']
#      [['any', 'wage'], '4']
#      [['collar', 'workers'], '4']
#      [['compensation', 'levels'], '4']
#      [['correlations', 'quit'], '4']
#      [['cross', 'industry'], '4']
#      [['each', 'agency'], '4']
#      [['earnings', 'firm'], '4']
#      [['efficient', 'quit'], '4']
#      [['employment', 'stock'], '4']
#      [['federal', 'government'], '4']
#      [['general', 'schedule'], '4']
#      [['high', 'pay'], '4']
#      [['large', 'firm'], '4']
#      [['negative', 'relationship'], '4']
#      [['office', 'personnel'], '4']
#      [['pay', 'differentials'], '4']
#      [['pay', 'levels'], '4']
#      [['pay', 'more'], '4']
#      [['pay', 'setting'], '4']
#      [['public', 'private'], '4']
#      [['q', 'w'], '4']
#      [['quits', 'earnings'], '4']
#      [['rate', 'government'], '4']
#      [['affect', 'quit'], '3']
#      [['agency', 'size'], '3']
#      [['between', 'firm'], '3']
#      [['between', 'quit'], '3']
#      [['between', 'quits'], '3']
#      [['c', 'd'], '3']
#      [['can', 'explained'], '3']
#      [['census', 'manufactures'], '3']
#      [['costs', 'point'], '3']
#      [['data', 'firm'], '3']
#      [['difference', 'can'], '3']
#      [['effect', 'firm'], '3']
#      [['empirical', 'work'], '3']
#      [['equal', 'pay'], '3']
#      [['from', 'differences'], '3']
#      [['gov', 'ernment'], '3']
#      [['have', 'been'], '3']
#      [['higher', 'turnover'], '3']
#      [['human', 'capital'], '3']
#      [['labor', 'flows'], '3']
#      [['much', 'difference'], '3']
#      [['negative', 'function'], '3']
#      [['nonpermanent', 'employees'], '3']
#      [['other', 'differences'], '3']
#      [['other', 'hand'], '3']
#      [['p', 'r'], '3']
#      [['p', 't'], '3']
#      [['paid', 'more'], '3']
#      [['pay', 'comparable'], '3']
#      [['pay', 'rates'], '3']
#      [['pay', 'scales'], '3']
#      [['personnel', 'management'], '3']
#      [['points', 'like'], '3']
#      [['presented', 'here'], '3']
#      [['private', 'sectors'], '3']
#      [['public', 'research'], '3']
#      [['rates', 'earnings'], '3']
#      [['relative', 'pay'], '3']
#      [['research', 'institute'], '3']
#      [['size', 'coefficient'], '3']
#      [['size', 'quit'], '3']
#      [['small', 'firms'], '3']
#      [['state', 'data'], '3']
#      [['strong', 'negative'], '3']
#      [['va', 'public'], '3']
#      [['workers', 'paid'], '3']
#      [['absolute', 'values'], '2']
#      [['across', 'states'], '2']
#      [['appear', 'table'], '2']
#      [['appropriate', 'treat'], '2']
#      [['average', 'hourly'], '2']
#      [['average', 'monthly'], '2']
#      [['average', 'private'], '2']
#      [['background', 'paper'], '2']
#      [['because', 'government'], '2']
#      [['before', 'quit'], '2']
#      [['below', 'coefficients'], '2']
#      [['better', 'offer'], '2']
#      [['between', 'agencies'], '2']
#      [['between', 'earnings'], '2']
#      [['between', 'private'], '2']
#      [['between', 'public'], '2']
#      [['bls', 'average'], '2']
#      [['borjas', 's'], '2']
#      [['budget', 'office'], '2']
#      [['can', 'accounted'], '2']
#      [['can', 'found'], '2']
#      [['can', 'used'], '2']
#      [['capital', 'characteristics'], '2']
#      [['center', 'naval'], '2']
#      [['choice', 'set'], '2']
#      [['choose', 'low'], '2']
#      [['chosen', 'firm'], '2']
#      [['classen', 'utgoff'], '2']
#      [['coefficients', 'absolute'], '2']
#      [['collar', 'employees'], '2']
#      [['com', 'parability'], '2']
#      [['compen', 'sation'], '2']
#      [['compensation', 'efficient'], '2']
#      [['compensation', 'principle'], '2']
#      [['constant', 'data'], '2']
#      [['costs', 'fixed'], '2']
#      [['costs', 'hiring'], '2']
#      [['costs', 'may'], '2']
#      [['costs', 'relative'], '2']
#      [['costs', 'tc'], '2']
#      [['d', 'dissertation'], '2']
#      [['data', 'from'], '2']
#      [['data', 'trace'], '2']
#      [['department', 'health'], '2']
#      [['determinants', 'quit'], '2']
#      [['differences', 'across'], '2']
#      [['differences', 'must'], '2']
#      [['different', 'sizes'], '2']
#      [['digit', 'industries'], '2']
#      [['divided', 'number'], '2']
#      [['earn', 'bls'], '2']
#      [['earnings', 'data'], '2']
#      [['earnings', 'quits'], '2']
#      [['education', 'welfare'], '2']
#      [['efficient', 'government'], '2']
#      [['efficient', 'principle'], '2']
#      [['empirical', 'estimates'], '2']
#      [['equal', 'work'], '2']
#      [['firms', 'choose'], '2']
#      [['firms', 'different'], '2']
#      [['firms', 'have'], '2']
#      [['firms', 'must'], '2']
#      [['firms', 'which'], '2']
#      [['fixed', 'costs'], '2']
#      [['flows', 'private'], '2']
#      [['frank', 'brechling'], '2']
#      [['fringe', 'benefits'], '2']
#      [['function', 'firm'], '2']
#      [['george', 'borjas'], '2']
#      [['government', 'because'], '2']
#      [['government', 'can'], '2']
#      [['government', 'compared'], '2']
#      [['government', 'manufacturing'], '2']
#      [['government', 'one'], '2']
#      [['government', 'quit'], '2']
#      [['government', 's'], '2']
#      [['government', 'workers'], '2']
#      [['great', 'deal'], '2']
#      [['have', 'higher'], '2']
#      [['health', 'education'], '2']
#      [['high', 'quit'], '2']
#      [['high', 'wages'], '2']
#      [['higher', 'pay'], '2']
#      [['higher', 'than'], '2']
#      [['his', 'model'], '2']
#      [['hourly', 'earnings'], '2']
#      [['how', 'much'], '2']
#      [['however', 'because'], '2']
#      [['important', 'differences'], '2']
#      [['industrial', 'labor'], '2']
#      [['industries', 'particularly'], '2']
#      [['industries', 'quit'], '2']
#      [['industry', 'correlations'], '2']
#      [['intrafirm', 'transfer'], '2']
#      [['job', 'search'], '2']
#      [['judge', 'pay'], '2']
#      [['kathleen', 'classen'], '2']
#      [['labor', 'relations'], '2']
#      [['labor', 'turnover'], '2']
#      [['less', 'than'], '2']
#      [['levels', 'government'], '2']
#      [['like', 'points'], '2']
#      [['look', 'like'], '2']
#      [['low', 'turnover'], '2']
#      [['lower', 'less'], '2']
#      [['lower', 'than'], '2']
#      [['manufac', 'turing'], '2']
#      [['manufacturing', 'industries'], '2']
#      [['many', 'applicants'], '2']
#      [['many', 'people'], '2']
#      [['matched', 'bls'], '2']
#      [['may', 'appropriate'], '2']
#      [['measure', 'pay'], '2']
#      [['mechanically', 'related'], '2']
#      [['minimize', 'c'], '2']
#      [['model', 'empirical'], '2']
#      [['monthly', 'quit'], '2']
#      [['more', 'like'], '2']
#      [['much', 'lower'], '2']
#      [['must', 'also'], '2']
#      [['naval', 'analyses'], '2']
#      [['numbers', 'parentheses'], '2']
#      [['ols', 'estimates'], '2']
#      [['one', 'firm'], '2']
#      [['optimizing', 'procedure'], '2']
#      [['out', 'points'], '2']
#      [['p', 'q'], '2']
#      [['parentheses', 'below'], '2']
#      [['pay', 'equal'], '2']
#      [['pay', 'high'], '2']
#      [['pay', 'line'], '2']
#      [['pay', 'set'], '2']
#      [['pay', 'systems'], '2']
#      [['pay', 'total'], '2']
#      [['per', 'period'], '2']
#      [['per', 'slot'], '2']
#      [['permanent', 'employment'], '2']
#      [['personal', 'characteristics'], '2']
#      [['ph', 'd'], '2']
#      [['points', 'b'], '2']
#      [['points', 'c'], '2']
#      [['points', 'chosen'], '2']
#      [['positive', 'relationship'], '2']
#      [['private', 'industry'], '2']
#      [['private', 'jobs'], '2']
#      [['private', 'workers'], '2']
#      [['profit', 'maximizing'], '2']
#      [['quit', 'combinations'], '2']
#      [['rate', 'measure'], '2']
#      [['rate', 'mechanically'], '2']
#      [['rate', 'per'], '2']
#      [['rate', 'requires'], '2']
#      [['rates', 'adjusted'], '2']
#      [['rates', 'firm'], '2']
#      [['rates', 'function'], '2']
#      [['rates', 'manufacturing'], '2']
#      [['rates', 'may'], '2']
#      [['related', 'firm'], '2']
#      [['relations', 'review'], '2']
#      [['relatively', 'constant'], '2']
#      [['s', 'department'], '2']
#      [['sector', 'quit'], '2']
#      [['sector', 'size'], '2']
#      [['sector', 'workers'], '2']
#      [['see', 'brechling'], '2']
#      [['set', 'wages'], '2']
#      [['shown', 'table'], '2']
#      [['simple', 'model'], '2']
#      [['simultaneous', 'equation'], '2']
#      [['single', 'firm'], '2']
#      [['size', 'data'], '2']
#      [['state', 'correlations'], '2']
#      [['supposed', 'result'], '2']
#      [['tenure', 'differences'], '2']
#      [['than', 'average'], '2']
#      [['three', 'firms'], '2']
#      [['time', 'series'], '2']
#      [['total', 'manufacturing'], '2']
#      [['trace', 'out'], '2']
#      [['transfer', 'between'], '2']
#      [['transfer', 'large'], '2']
#      [['two', 'different'], '2']
#      [['u', 's'], '2']
#      [['unemployment', 'insurance'], '2']
#      [['use', 'quit'], '2']
#      [['values', 't'], '2']
#      [['variance', 'turnover'], '2']
#      [['w', 'fs'], '2']
#      [['w', 'w'], '2']
#      [['wage', 'determination'], '2']
#      [['wage', 'quit'], '2']
#      [['wages', 'firm'], '2']
#      [['when', 'quit'], '2']
#      [['which', 'turnover'], '2']
#      [['within', 'agency'], '2']
#      [['workers', 'public'], '2']
#      [['would', 'chosen'], '2']
#      [['x', 'y'], '2']
#      [['ability', 'federal'], '1']
#      [['about', 'five'], '1']
#      [['about', 'relative'], '1']
#      [['above', 'greater'], '1']
#      [['above', 'implies'], '1']
#      [['above', 'x'], '1']
#      [['abstract', 'many'], '1']
#      [['accept', 'jobs'], '1']
#      [['accept', 'low'], '1']
#      [['accepted', 'february'], '1']
#      [['accepts', 'any'], '1']
#      [['accepts', 'job'], '1']
#      [['accessions', 'average'], '1']
#      [['accessions', 'too'], '1']
#      [['according', 'estimates'], '1']
#      [['according', 'model'], '1']
#      [['according', 'procedures'], '1']
#      [['according', 'size'], '1']
#      [['according', 'surveys'], '1']
#      [['account', 'differences'], '1']
#      [['account', 'practice'], '1']
#      [['accounted', 'empirical'], '1']
#      [['accounted', 'large'], '1']
#      [['accounted', 'larger'], '1']
#      [['accurate', 'means'], '1']
#      [['accurate', 'measure'], '1']
#      [['across', 'agencies'], '1']
#      [['across', 'workers'], '1']
#      [['actual', 'military'], '1']
#      [['ad', 'justment'], '1']
#      [['addition', 'maintains'], '1']
#      [['addition', 'pay'], '1']
#      [['addition', 'positive'], '1']
#      [['adie', 'evaluation'], '1']
#      [['adie', 's'], '1']
#      [['adjust', 'all'], '1']
#      [['adjusted', 'annually'], '1']
#      [['adjusted', 'differences'], '1']
#      [['adjusted', 'nonpay'], '1']
#      [['adjustment', 'account'], '1']
#      [['adjustment', 'general'], '1']
#      [['administrative', 'unemployment'], '1']
#      [['affairs', 'logistics'], '1']
#      [['after', 'worker'], '1']
#      [['after', 'year'], '1']
#      [['again', 'reducing'], '1']
#      [['age', 'one'], '1']
#      [['age', 'sex'], '1']
#      [['agencies', 'according'], '1']
#      [['agencies', 'more'], '1']
#      [['agencies', 'p'], '1']
#      [['agencies', 'when'], '1']
#      [['agency', 'coefficient'], '1']
#      [['agency', 'coefficients'], '1']
#      [['agency', 'equation'], '1']
#      [['agency', 'figure'], '1']
#      [['agency', 'government'], '1']
#      [['agency', 'measure'], '1']
#      [['agency', 'one'], '1']
#      [['agency', 'same'], '1']
#      [['agency', 'utgoff'], '1']
#      [['agency', 'within'], '1']
#      [['agreement', 'compar'], '1']
#      [['aline', 'quester'], '1']
#      [['all', 'civilian'], '1']
#      [['all', 'difference'], '1']
#      [['all', 'equations'], '1']
#      [['all', 'factors'], '1']
#      [['all', 'labor'], '1']
#      [['all', 'same'], '1']
#      [['all', 'slots'], '1']
#      [['all', 'states'], '1']
#      [['all', 'tenure'], '1']
#      [['allow', 'comparison'], '1']
#      [['allow', 'declining'], '1']
#      [['allows', 'them'], '1']
#      [['alone', 'government'], '1']
#      [['along', 'q'], '1']
#      [['along', 'w'], '1']
#      [['already', 'determined'], '1']
#      [['already', 'out'], '1']
#      [['also', 'affect'], '1']
#      [['also', 'allow'], '1']
#      [['also', 'appropriate'], '1']
#      [['also', 'gov'], '1']
#      [['also', 'great'], '1']
#      [['also', 'influence'], '1']
#      [['also', 'linked'], '1']
#      [['also', 'pointed'], '1']
#      [['also', 'select'], '1']
#      [['also', 'strong'], '1']
#      [['also', 'taken'], '1']
#      [['altered', 'significantly'], '1']
#      [['alternate', 'measure'], '1']
#      [['alternate', 'oppor'], '1']
#      [['alternative', 'explanations'], '1']
#      [['although', 'com'], '1']
#      [['although', 'exclusion'], '1']
#      [['although', 'much'], '1']
#      [['although', 'quit'], '1']
#      [['always', 'considerably'], '1']
#      [['am', 'grateful'], '1']
#      [['amer', 'ican'], '1']
#      [['american', 'enterprise'], '1']
#      [['among', 'older'], '1']
#      [['among', 'other'], '1']
#      [['among', 'set'], '1']
#      [['among', 'wage'], '1']
#      [['analyses', 'de'], '1']
#      [['analyses', 'paper'], '1']
#      [['analysis', 'here'], '1']
#      [['analysis', 'labor'], '1']
#      [['analysis', 'treats'], '1']
#      [['annually', 'according'], '1']
#      [['another', 'implication'], '1']
#      [['answering', 'question'], '1']
#      [['any', 'given'], '1']
#      [['any', 'size'], '1']
#      [['appear', 'pay'], '1']
#      [['appear', 'want'], '1']
#      [['applicants', 'apply'], '1']
#      [['applicants', 'fill'], '1']
#      [['application', 'quit'], '1']
#      [['applies', 'more'], '1']
#      [['applies', 'only'], '1']
#      [['apply', 'government'], '1']
#      [['apply', 'same'], '1']
#      [['appropriate', 'adjust'], '1']
#      [['appropriate', 'grade'], '1']
#      [['appropriate', 'make'], '1']
#      [['area', 'firm'], '1']
#      [['arguments', 'alone'], '1']
#      [['ascribed', 'differences'], '1']
#      [['assistant', 'sec'], '1']
#      [['associated', 'comparable'], '1']
#      [['association', 'between'], '1']
#      [['assume', 'turnover'], '1']
#      [['assumption', 'probability'], '1']
#      [['attention', 'concentrated'], '1']
#      [['attractive', 'than'], '1']
#      [['author', 'economist'], '1']
#      [['available', 'all'], '1']
#      [['available', 'consistent'], '1']
#      [['available', 'request'], '1']
#      [['average', 'about'], '1']
#      [['average', 'firm'], '1']
#      [['average', 'observed'], '1']
#      [['average', 'tenure'], '1']
#      [['axis', 'slope'], '1']
#      [['b', 'figure'], '1']
#      [['b', 'fs'], '1']
#      [['b', 'lnearn'], '1']
#      [['b', 'negative'], '1']
#      [['b', 'permanent'], '1']
#      [['b', 'producing'], '1']
#      [['b', 'represent'], '1']
#      [['b', 'would'], '1']
#      [['b21nsize', 'quit'], '1']
#      [['base', 'agency'], '1']
#      [['based', 'assumption'], '1']
#      [['based', 'differences'], '1']
#      [['based', 'local'], '1']
#      [['based', 'personal'], '1']
#      [['based', 'political'], '1']
#      [['based', 'time'], '1']
#      [['basis', 'agency'], '1']
#      [['basis', 'economic'], '1']
#      [['basis', 'quit'], '1']
#      [['basis', 'quits'], '1']
#      [['because', 'creased'], '1']
#      [['because', 'have'], '1']
#      [['because', 'his'], '1']
#      [['because', 'large'], '1']
#      [['because', 'many'], '1']
#      [['because', 'provides'], '1']
#      [['because', 'quit'], '1']
#      [['because', 'reduced'], '1']
#      [['because', 'size'], '1']
#      [['because', 'some'], '1']
#      [['because', 'turnover'], '1']
#      [['because', 'workers'], '1']
#      [['becomes', 'dissatisfied'], '1']
#      [['been', 'accounted'], '1']
#      [['been', 'criticized'], '1']
#      [['been', 'explained'], '1']
#      [['been', 'noted'], '1']
#      [['been', 'suggested'], '1']
#      [['before', 'quitting'], '1']
#      [['behavior', 'equilibrium'], '1']
#      [['behavior', 'firm'], '1']
#      [['being', 'biased'], '1']
#      [['being', 'fired'], '1']
#      [['belief', 'supported'], '1']
#      [['believe', 'however'], '1']
#      [['believes', 'blue'], '1']
#      [['believes', 'pay'], '1']
#      [['below', 'private'], '1']
#      [['benefits', 'compensation'], '1']
#      [['benefits', 'tc'], '1']
#      [['better', 'blue'], '1']
#      [['better', 'job'], '1']
#      [['better', 'than'], '1']
#      [['between', 'federal'], '1']
#      [['between', 'points'], '1']
#      [['between', 'poles'], '1']
#      [['between', 'size'], '1']
#      [['between', 'turnover'], '1']
#      [['between', 'workers'], '1']
#      [['between', 'x'], '1']
#      [['bias', 'can'], '1']
#      [['bias', 'case'], '1']
#      [['bias', 'comparisons'], '1']
#      [['biased', 'favor'], '1']
#      [['big', 'firm'], '1']
#      [['billion', 'per'], '1']
#      [['bls', 'data'], '1']
#      [['bls', 'industry'], '1']
#      [['bls', 'monthly'], '1']
#      [['bls', 'state'], '1']
#      [['bls', 'straight'], '1']
#      [['bls', 'study'], '1']
#      [['bls', 'survey'], '1']
#      [['bo', 'b'], '1']
#      [['borjas', 'believes'], '1']
#      [['borjas', 'from'], '1']
#      [['borjas', 'paper'], '1']
#      [['borjas', 'wage'], '1']
#      [['both', 'because'], '1']
#      [['both', 'data'], '1']
#      [['both', 'equations'], '1']
#      [['both', 'quits'], '1']
#      [['both', 'separations'], '1']
#      [['both', 'sets'], '1']
#      [['both', 'survey'], '1']
#      [['bracketed', 'term'], '1']
#      [['brechling', 'jacobson'], '1']
#      [['brechling', 'louis'], '1']
#      [['brechling', 'time'], '1']
#      [['budgetary', 'impact'], '1']
#      [['burdett', 'theory'], '1']
#      [['bureau', 'economic'], '1']
#      [['bureau', 'labor'], '1']
#      [['bureaucrats', 'university'], '1']
#      [['c', 'cost'], '1']
#      [['c', 'each'], '1']
#      [['c', 'gd'], '1']
#      [['c', 'lnearn'], '1']
#      [['c', 'per'], '1']
#      [['c', 'point'], '1']
#      [['c', 'w'], '1']
#      [['c', 'which'], '1']
#      [['c1lnsize', 'variable'], '1']
#      [['calculate', 'pay'], '1']
#      [['calculate', 'than'], '1']
#      [['calculated', 'george'], '1']
#      [['california', 'santa'], '1']
#      [['can', 'altered'], '1']
#      [['can', 'ascribed'], '1']
#      [['can', 'considered'], '1']
#      [['can', 'continue'], '1']
#      [['can', 'justified'], '1']
#      [['can', 'linked'], '1']
#      [['can', 'made'], '1']
#      [['cannot', 'given'], '1']
#      [['capital', 'application'], '1']
#      [['case', 'because'], '1']
#      [['cause', 'differences'], '1']
#      [['causes', 'cycles'], '1']
#      [['ceilings', 'federal'], '1']
#      [['chance', 'receiving'], '1']
#      [['changes', 'background'], '1']
#      [['changes', 'relative'], '1']
#      [['characteristics', 'age'], '1']
#      [['characteristics', 'government'], '1']
#      [['characteristics', 'journal'], '1']
#      [['characteristics', 'search'], '1']
#      [['choice', 'enlistment'], '1']
#      [['choose', 'along'], '1']
#      [['choose', 'among'], '1']
#      [['choose', 'comparability'], '1']
#      [['choose', 'compensation'], '1']
#      [['choose', 'high'], '1']
#      [['choose', 'higher'], '1']
#      [['choose', 'point'], '1']
#      [['chooses', 'among'], '1']
#      [['chooses', 'optimum'], '1']
#      [['chosen', 'small'], '1']
#      [['chosen', 'three'], '1']
#      [['chosen', 'two'], '1']
#      [['circumvent', 'congressional'], '1']
#      [['circumventing', 'disputed'], '1']
#      [['civilian', 'compensation'], '1']
#      [['civilian', 'employment'], '1']
#      [['civilian', 'federal'], '1']
#      [['claims', 'pure'], '1']
#      [['classic', 'identification'], '1']
#      [['clear', 'basis'], '1']
#      [['clear', 'government'], '1']
#      [['clear', 'how'], '1']
#      [['clear', 'however'], '1']
#      [['coefficient', 'from'], '1']
#      [['coefficient', 'has'], '1']
#      [['coefficient', 'negative'], '1']
#      [['coefficient', 'smaller'], '1']
#      [['coefficients', 'appear'], '1']
#      [['coefficients', 'elasticities'], '1']
#      [['coefficients', 'table'], '1']
#      [['collar', 'based'], '1']
#      [['collar', 'blue'], '1']
#      [['collar', 'postal'], '1']
#      [['collar', 'white'], '1']
#      [['collected', 'turnover'], '1']
#      [['collective', 'bargaining'], '1']
#      [['com', 'pensation'], '1']
#      [['combination', 'equal'], '1']
#      [['combinations', 'long'], '1']
#      [['combinations', 'wages'], '1']
#      [['come', 'from'], '1']
#      [['comments', 'manuscript'], '1']
#      [['companion', 'direct'], '1']
#      [['compar', 'ability'], '1']
#      [['comparability', 'act'], '1']
#      [['comparability', 'always'], '1']
#      [['comparability', 'basis'], '1']
#      [['comparability', 'clear'], '1']
#      [['comparability', 'crc'], '1']
#      [['comparability', 'defined'], '1']
#      [['comparability', 'either'], '1']
#      [['comparability', 'may'], '1']
#      [['comparability', 'measure'], '1']
#      [['comparability', 'pay'], '1']
#      [['comparability', 'quit'], '1']
#      [['comparable', 'compensation'], '1']
#      [['comparable', 'private'], '1']
#      [['comparable', 'quit'], '1']
#      [['comparable', 'when'], '1']
#      [['comparable', 'workers'], '1']
#      [['compare', 'pay'], '1']
#      [['compared', 'manufac'], '1']
#      [['compared', 'size'], '1']
#      [['comparing', 'municipal'], '1']
#      [['comparison', 'equations'], '1']
#      [['comparisons', 'government'], '1']
#      [['comparisons', 'quit'], '1']
#      [['compensation', 'combination'], '1']
#      [['compensation', 'costs'], '1']
#      [['compensation', 'especially'], '1']
#      [['compensation', 'pack'], '1']
#      [['compensation', 'package'], '1']
#      [['competition', 'lower'], '1']
#      [['complex', 'controversial'], '1']
#      [['complex', 'however'], '1']
#      [['complex', 'major'], '1']
#      [['concentrated', 'government'], '1']
#      [['conclusion', 'although'], '1']
#      [['conclusions', 'borjas'], '1']
#      [['conclusions', 'very'], '1']
#      [['condition', 'expressed'], '1']
#      [['conference', 'volume'], '1']
#      [['confirmation', 'borjas'], '1']
#      [['conform', 'expectations'], '1']
#      [['congressional', 'budget'], '1']
#      [['congressional', 'ceilings'], '1']
#      [['congressoinal', 'budget'], '1']
#      [['consider', 'jobs'], '1']
#      [['considerably', 'below'], '1']
#      [['considerably', 'higher'], '1']
#      [['considered', 'single'], '1']
#      [['considering', 'each'], '1']
#      [['considering', 'whole'], '1']
#      [['consistent', 'basis'], '1']
#      [['constant', 'because'], '1']
#      [['constituency', 'each'], '1']
#      [['constituents', 'bureaucrats'], '1']
#      [['contains', 'simple'], '1']
#      [['contention', 'gov'], '1']
#      [['continue', 'after'], '1']
#      [['continue', 'same'], '1']
#      [['continues', 'seek'], '1']
#      [['contract', 'ph'], '1']
#      [['contrary', 'conclusions'], '1']
#      [['control', 'problems'], '1']
#      [['controversial', 'process'], '1']
#      [['coordinated', 'taxpayers'], '1']
#      [['cor', 'utgoff'], '1']
#      [['correlation', 'both'], '1']
#      [['correlations', 'do'], '1']
#      [['correlations', 'show'], '1']
#      [['correlations', 'table'], '1']
#      [['correlations', 'very'], '1']
#      [['cost', 'line'], '1']
#      [['cost', 'min'], '1']
#      [['cost', 'per'], '1']
#      [['cost', 'providing'], '1']
#      [['costs', 'according'], '1']
#      [['costs', 'because'], '1']
#      [['costs', 'c'], '1']
#      [['costs', 'compensation'], '1']
#      [['costs', 'conclusion'], '1']
#      [['costs', 'do'], '1']
#      [['costs', 'efficient'], '1']
#      [['costs', 'exceed'], '1']
#      [['costs', 'explanation'], '1']
#      [['costs', 'flattens'], '1']
#      [['costs', 'minimum'], '1']
#      [['costs', 'moreover'], '1']
#      [['costs', 'positively'], '1']
#      [['costs', 'preferences'], '1']
#      [['costs', 'produce'], '1']
#      [['costs', 'relatively'], '1']
#      [['costs', 'specialized'], '1']
#      [['costs', 'training'], '1']
#      [['costs', 'vary'], '1']
#      [['costs', 'wages'], '1']
#      [['costs', 'would'], '1']
#      [['could', 'even'], '1']
#      [['could', 'explained'], '1']
#      [['coun', 'terparts'], '1']
#      [['count', 'made'], '1']
#      [['counter', 'parts'], '1']
#      [['course', 'many'], '1']
#      [['covered', 'different'], '1']
#      [['creased', 'possibility'], '1']
#      [['criticized', 'being'], '1']
#      [['current', 'wage'], '1']
#      [['currently', 'occupied'], '1']
#      [['curve', 'point'], '1']
#      [['curve', 'points'], '1']
#      [['curves', 'fs'], '1']
#      [['cycle', 'quits'], '1']
#      [['cycles', 'quits'], '1']
#      [['cyclical', 'pattern'], '1']
#      [['cyclical', 'sensitivity'], '1']
#      [['cyclically', 'sensitive'], '1']
#      [['d', 'b'], '1']
#      [['d', 'chosen'], '1']
#      [['d', 'producing'], '1']
#      [['d', 'relationship'], '1']
#      [['d', 'represent'], '1']
#      [['data', 'both'], '1']
#      [['data', 'come'], '1']
#      [['data', 'look'], '1']
#      [['data', 'points'], '1']
#      [['data', 'provided'], '1']
#      [['data', 'see'], '1']
#      [['data', 'sets'], '1']
#      [['data', 'sources'], '1']
#      [['data', 'strong'], '1']
#      [['data', 'turnover'], '1']
#      [['data', 'types'], '1']
#      [['david', 'lewin'], '1']
#      [['dc', 'ow'], '1']
#      [['de', 'cember'], '1']
#      [['deal', 'data'], '1']
#      [['deal', 'easier'], '1']
#      [['decides', 'move'], '1']
#      [['declining', 'marginal'], '1']
#      [['defense', 'i'], '1']
#      [['defense', 'manpower'], '1']
#      [['defense', 'single'], '1']
#      [['defined', 'include'], '1']
#      [['definitions', 'cross'], '1']
#      [['definitions', 'numbers'], '1']
#      [['deliberately', 'choose'], '1']
#      [['demonstrates', 'optimum'], '1']
#      [['department', 'commerce'], '1']
#      [['department', 'defense'], '1']
#      [['department', 'labor'], '1']
#      [['depend', 'variance'], '1']
#      [['depends', 'among'], '1']
#      [['depends', 'tenure'], '1']
#      [['derives', 'similar'], '1']
#      [['described', 'above'], '1']
#      [['description', 'quit'], '1']
#      [['design', 'its'], '1']
#      [['desired', 'number'], '1']
#      [['desired', 'size'], '1']
#      [['despite', 'government'], '1']
#      [['detail', 'because'], '1']
#      [['determinants', 'should'], '1']
#      [['determination', 'federal'], '1']
#      [['determination', 'public'], '1']
#      [['determination', 'quits'], '1']
#      [['determine', 'pay'], '1']
#      [['determined', 'both'], '1']
#      [['determined', 'collective'], '1']
#      [['determined', 'desired'], '1']
#      [['determined', 'human'], '1']
#      [['determined', 'tc'], '1']
#      [['determined', 'turnover'], '1']
#      [['determining', 'comparable'], '1']
#      [['determining', 'quit'], '1']
#      [['developed', 'search'], '1']
#      [['dewald', 'washington'], '1']
#      [['dick', 'thaler'], '1']
#      [['differ', 'across'], '1']
#      [['differ', 'ences'], '1']
#      [['differences', 'also'], '1']
#      [['differences', 'firm'], '1']
#      [['differences', 'pay'], '1']
#      [['differences', 'personal'], '1']
#      [['differences', 'quality'], '1']
#      [['differences', 'quit'], '1']
#      [['differences', 'tenure'], '1']
#      [['different', 'agencies'], '1']
#      [['different', 'firms'], '1']
#      [['different', 'pay'], '1']
#      [['different', 'sources'], '1']
#      [['different', 'turnover'], '1']
#      [['different', 'two'], '1']
#      [['different', 'units'], '1']
#      [['differential', 'exists'], '1']
#      [['differential', 'government'], '1']
#      [['differential', 'quit'], '1']
#      [['differential', 'relative'], '1']
#      [['differentials', 'among'], '1']
#      [['differentials', 'based'], '1']
#      [['differentials', 'between'], '1']
#      [['differentials', 'produce'], '1']
#      [['differentials', 'size'], '1']
#      [['difficult', 'disputed'], '1']
#      [['digit', 'cross'], '1']
#      [['digit', 'levels'], '1']
#      [['direct', 'pay'], '1']
#      [['discussed', 'above'], '1']
#      [['discussion', 'problem'], '1']
#      [['disputed', 'exercise'], '1']
#      [['disputed', 'pay'], '1']
#      [['dissatisfied', 'decides'], '1']
#      [['dissatisfied', 'wants'], '1']
#      [['dissertation', 'johns'], '1']
#      [['dissertation', 'ohio'], '1']
#      [['dissertations', 'relationship'], '1']
#      [['distance', 'between'], '1']
#      [['distinctions', 'both'], '1']
#      [['diverse', 'cor'], '1']
#      [['diverse', 'results'], '1']
#      [['do', 'conform'], '1']
#      [['do', 'generally'], '1']
#      [['do', 'necessarily'], '1']
#      [['do', 'pay'], '1']
#      [['does', 'set'], '1']
#      [['does', 'signify'], '1']
#      [['donald', 'o'], '1']
#      [['douglas', 'k'], '1']
#      [['dq', 'figure'], '1']
#      [['dq', 'ofs'], '1']
#      [['dq', 'ow'], '1']
#      [['ductivity', 'due'], '1']
#      [['due', 'fact'], '1']
#      [['due', 'high'], '1']
#      [['due', 'higher'], '1']
#      [['due', 'other'], '1']
#      [['due', 'training'], '1']
#      [['during', 'period'], '1']
#      [['during', 'recessions'], '1']
#      [['dw', 'dq'], '1']
#      [['e', 'garen'], '1']
#      [['each', 'covered'], '1']
#      [['each', 'straight'], '1']
#      [['each', 'worker'], '1']
#      [['each', 'year'], '1']
#      [['earn', 'i'], '1']
#      [['earn', 'more'], '1']
#      [['earnings', 'also'], '1']
#      [['earnings', 'can'], '1']
#      [['earnings', 'differential'], '1']
#      [['earnings', 'from'], '1']
#      [['earnings', 'government'], '1']
#      [['earnings', 'has'], '1']
#      [['earnings', 'have'], '1']
#      [['earnings', 'manufacturing'], '1']
#      [['earnings', 'miller'], '1']
#      [['earnings', 'much'], '1']
#      [['earnings', 'other'], '1']
#      [['earnings', 'quit'], '1']
#      [['easier', 'calculate'], '1']
#      [['easy', 'reassign'], '1']
#      [['econo', 'mist'], '1']
#      [['economic', 'arguments'], '1']
#      [['economic', 'determinants'], '1']
#      [['economic', 'models'], '1']
#      [['economic', 'research'], '1']
#      [['economic', 'review'], '1']
#      [['economist', 'center'], '1']
#      [['ed', 'william'], '1']
#      [['effect', 'quit'], '1']
#      [['efficiencies', 'private'], '1']
#      [['efficient', 'compensation'], '1']
#      [['either', 'differences'], '1']
#      [['either', 'pay'], '1']
#      [['either', 'seek'], '1']
#      [['elaborate', 'federal'], '1']
#      [['elasticity', 'supply'], '1']
#      [['elected', 'officials'], '1']
#      [['em', 'ployees'], '1']
#      [['empirical', 'implications'], '1']
#      [['empirical', 'regularity'], '1']
#      [['empirical', 'studies'], '1']
#      [['empirically', 'observed'], '1']
#      [['employee', 'dissatisfied'], '1']
#      [['employee', 'job'], '1']
#      [['employee', 'slots'], '1']
#      [['employees', 'addition'], '1']
#      [['employees', 'continue'], '1']
#      [['employees', 'divided'], '1']
#      [['employees', 'each'], '1']
#      [['employees', 'general'], '1']
#      [['employees', 'government'], '1']
#      [['employees', 'may'], '1']
#      [['employees', 'within'], '1']
#      [['employer', 'chooses'], '1']
#      [['employer', 'minimize'], '1']
#      [['employer', 'we'], '1']
#      [['employers', 'choose'], '1']
#      [['employers', 'personal'], '1']
#      [['employing', 'unit'], '1']
#      [['employment', 'costs'], '1']
#      [['employment', 'earnings'], '1']
#      [['employment', 'ed'], '1']
#      [['employment', 'excludes'], '1']
#      [['employment', 'federal'], '1']
#      [['employment', 'manufacturing'], '1']
#      [['employment', 'sense'], '1']
#      [['employment', 'slot'], '1']
#      [['employment', 'workers'], '1']
#      [['ences', 'between'], '1']
#      [['endogenous', 'costs'], '1']
#      [['endogenous', 'simultaneously'], '1']
#      [['enlistment', 'retention'], '1']
#      [['enterprise', 'institute'], '1']
#      [['equal', 'comparable'], '1']
#      [['equal', 'intercept'], '1']
#      [['equal', 'size'], '1']
#      [['equation', 'bias'], '1']
#      [['equation', 'framework'], '1']
#      [['equation', 'ols'], '1']
#      [['equation', 'where'], '1']
#      [['equations', 'allow'], '1']
#      [['equations', 'estimated'], '1']
#      [['equations', 'inquit'], '1']
#      [['equations', 'table'], '1']
#      [['equations', 'were'], '1']
#      [['equilibrium', 'determination'], '1']
#      [['equilibrium', 'relationship'], '1']
#      [['equivalent', 'private'], '1']
#      [['ernment', 'jobs'], '1']
#      [['ernment', 'pays'], '1']
#      [['ernment', 'workers'], '1']
#      [['ers', 'must'], '1']
#      [['es', 'pecially'], '1']
#      [['especially', 'comparability'], '1']
#      [['establish', 'pay'], '1']
#      [['established', 'federal'], '1']
#      [['establishment', 'industrial'], '1']
#      [['establishments', 'earn'], '1']
#      [['estimate', 'earnings'], '1']
#      [['estimate', 'pure'], '1']
#      [['estimate', 'quit'], '1']
#      [['estimate', 'relative'], '1']
#      [['estimated', 'different'], '1']
#      [['estimated', 'equations'], '1']
#      [['estimated', 'logarithmic'], '1']
#      [['estimates', 'all'], '1']
#      [['estimates', 'based'], '1']
#      [['estimates', 'biased'], '1']
#      [['estimates', 'likely'], '1']
#      [['estimates', 'ols'], '1']
#      [['estimates', 'paper'], '1']
#      [['estimates', 'presented'], '1']
#      [['estimates', 'quit'], '1']
#      [['evaluate', 'many'], '1']
#      [['evaluated', 'basis'], '1']
#      [['evaluation', 'postal'], '1']
#      [['even', 'holding'], '1']
#      [['even', 'positive'], '1']
#      [['ever', 'agreement'], '1']
#      [['ever', 'payroll'], '1']
#      [['evidence', 'pre'], '1']
#      [['ex', 'tremely'], '1']
#      [['example', 'high'], '1']
#      [['example', 'lester'], '1']
#      [['except', 'highest'], '1']
#      [['excludes', 'workers'], '1']
#      [['exclusion', 'nonpermanent'], '1']
#      [['exercise', 'perhaps'], '1']
#      [['exists', 'only'], '1']
#      [['expectations', 'most'], '1']
#      [['expected', 'pattern'], '1']
#      [['expected', 'symp'], '1']
#      [['explained', 'detail'], '1']
#      [['explained', 'differences'], '1']
#      [['explained', 'fact'], '1']
#      [['explained', 'fol'], '1']
#      [['explained', 'model'], '1']
#      [['explains', 'how'], '1']
#      [['explanation', 'correlations'], '1']
#      [['explanation', 'figure'], '1']
#      [['explanation', 'observation'], '1']
#      [['explanation', 'seemingly'], '1']
#      [['explanation', 'sup'], '1']
#      [['explanation', 'would'], '1']
#      [['explanations', 'cyclical'], '1']
#      [['expressed', 'here'], '1']
#      [['expressed', 'terms'], '1']
#      [['extended', 'several'], '1']
#      [['extensions', 'before'], '1']
#      [['extreme', 'example'], '1']
#      [['f', 'quinn'], '1']
#      [['f', 's'], '1']
#      [['fact', 'cross'], '1']
#      [['fact', 'government'], '1']
#      [['factors', 'affect'], '1']
#      [['favor', 'higher'], '1']
#      [['feasible', 'wage'], '1']
#      [['federal', 'civilian'], '1']
#      [['federal', 'employment'], '1']
#      [['federal', 'hiring'], '1']
#      [['federal', 'wage'], '1']
#      [['federal', 'workers'], '1']
#      [['feel', 'despite'], '1']
#      [['feels', 'little'], '1']
#      [['figure', 'represent'], '1']
#      [['figures', 'accurate'], '1']
#      [['fill', 'vacancy'], '1']
#      [['findings', 'because'], '1']
#      [['finds', 'large'], '1']
#      [['fired', 'before'], '1']
#      [['firm', 'again'], '1']
#      [['firm', 'all'], '1']
#      [['firm', 'behavior'], '1']
#      [['firm', 'bracketed'], '1']
#      [['firm', 'chooses'], '1']
#      [['firm', 'considering'], '1']
#      [['firm', 'empirical'], '1']
#      [['firm', 'firm'], '1']
#      [['firm', 'fixed'], '1']
#      [['firm', 'given'], '1']
#      [['firm', 'gov'], '1']
#      [['firm', 'has'], '1']
#      [['firm', 'high'], '1']
#      [['firm', 'low'], '1']
#      [['firm', 'manufacturing'], '1']
#      [['firm', 'may'], '1']
#      [['firm', 'point'], '1']
#      [['firm', 'private'], '1']
#      [['firm', 'quit'], '1']
#      [['firm', 'results'], '1']
#      [['firm', 'since'], '1']
#      [['firm', 'sizes'], '1']
#      [['firm', 'thus'], '1']
#      [['firm', 'which'], '1']
#      [['firms', 'allows'], '1']
#      [['firms', 'appear'], '1']
#      [['firms', 'because'], '1']
#      [['firms', 'do'], '1']
#      [['firms', 'employee'], '1']
#      [['firms', 'equal'], '1']
#      [['firms', 'hire'], '1']
#      [['firms', 'large'], '1']
#      [['firms', 'pay'], '1']
#      [['firms', 'quit'], '1']
#      [['firms', 'straight'], '1']
#      [['firms', 'transferring'], '1']
#      [['firms', 'variation'], '1']
#      [['firms', 'where'], '1']
#      [['first', 'quarter'], '1']
#      [['five', 'times'], '1']
#      [['fixed', 'employment'], '1']
#      [['fixed', 'independent'], '1']
#      [['flattens', 'cost'], '1']
#      [['flatter', 'could'], '1']
#      [['flows', 'both'], '1']
#      [['flows', 'government'], '1']
#      [['flows', 'inconsistent'], '1']
#      [['flows', 'n'], '1']
#      [['flowsa', 'percents'], '1']
#      [['fogel', 'david'], '1']
#      [['fogel', 'lewin'], '1']
#      [['fol', 'lowing'], '1']
#      [['following', 'ols'], '1']
#      [['following', 'shift'], '1']
#      [['force', 'economic'], '1']
#      [['forcing', 'managers'], '1']
#      [['form', 'equations'], '1']
#      [['forms', 'choice'], '1']
#      [['forms', 'total'], '1']
#      [['forthcom', 'ing'], '1']
#      [['found', 'congressional'], '1']
#      [['found', 'longer'], '1']
#      [['found', 'most'], '1']
#      [['foundation', 'defense'], '1']
#      [['framework', 'efficient'], '1']
#      [['frederick', 'h'], '1']
#      [['from', 'administrative'], '1']
#      [['from', 'data'], '1']
#      [['from', 'employment'], '1']
#      [['from', 'logarithmic'], '1']
#      [['from', 'office'], '1']
#      [['from', 'optimizing'], '1']
#      [['from', 'paper'], '1']
#      [['from', 'semiannual'], '1']
#      [['from', 'simultaneous'], '1']
#      [['from', 'statistical'], '1']
#      [['from', 'two'], '1']
#      [['from', 'unemployment'], '1']
#      [['fs', 'curve'], '1']
#      [['fs', 'dq'], '1']
#      [['fs', 'given'], '1']
#      [['fsi', 'b'], '1']
#      [['function', 'agency'], '1']
#      [['function', 'pay'], '1']
#      [['function', 'w'], '1']
#      [['function', 'wages'], '1']
#      [['function', 'workers'], '1']
#      [['g', 'dewald'], '1']
#      [['garen', 'effect'], '1']
#      [['gd', 'fsi'], '1']
#      [['general', 'author'], '1']
#      [['general', 'identify'], '1']
#      [['generally', 'play'], '1']
#      [['generous', 'matter'], '1']
#      [['geographic', 'area'], '1']
#      [['george', 'j'], '1']
#      [['given', 'c'], '1']
#      [['given', 'description'], '1']
#      [['given', 'previous'], '1']
#      [['given', 'size'], '1']
#      [['given', 'time'], '1']
#      [['given', 'turnover'], '1']
#      [['govern', 'ment'], '1']
#      [['government', 'agencies'], '1']
#      [['government', 'also'], '1']
#      [['government', 'data'], '1']
#      [['government', 'does'], '1']
#      [['government', 'em'], '1']
#      [['government', 'empirical'], '1']
#      [['government', 'firm'], '1']
#      [['government', 'firms'], '1']
#      [['government', 'from'], '1']
#      [['government', 'jobs'], '1']
#      [['government', 'labor'], '1']
#      [['government', 'much'], '1']
#      [['government', 'must'], '1']
#      [['government', 'only'], '1']
#      [['government', 'preceding'], '1']
#      [['government', 'quits'], '1']
#      [['government', 'regression'], '1']
#      [['government', 'relationship'], '1']
#      [['government', 'role'], '1']
#      [['government', 'same'], '1']
#      [['government', 'sector'], '1']
#      [['government', 'should'], '1']
#      [['government', 'single'], '1']
#      [['government', 'size'], '1']
#      [['government', 'smaller'], '1']
#      [['government', 'statistics'], '1']
#      [['government', 'sup'], '1']
#      [['government', 'than'], '1']
#      [['government', 'undoubtedly'], '1']
#      [['government', 'well'], '1']
#      [['government', 'were'], '1']
#      [['government', 'workforce'], '1']
#      [['grade', 'distinctions'], '1']
#      [['grade', 'levels'], '1']
#      [['grateful', 'dick'], '1']
#      [['greater', 'across'], '1']
#      [['greater', 'large'], '1']
#      [['greater', 'possibility'], '1']
#      [['gs', 'permanentb'], '1']
#      [['guide', 'government'], '1']
#      [['h', 'miller'], '1']
#      [['h', 'perloff'], '1']
#      [['half', 'all'], '1']
#      [['hand', 'agencies'], '1']
#      [['hand', 'finds'], '1']
#      [['hand', 'turnover'], '1']
#      [['hard', 'imagine'], '1']
#      [['has', 'already'], '1']
#      [['has', 'been'], '1']
#      [['has', 'developed'], '1']
#      [['has', 'identified'], '1']
#      [['has', 'negative'], '1']
#      [['has', 'often'], '1']
#      [['has', 'two'], '1']
#      [['has', 'undoubtedly'], '1']
#      [['have', 'control'], '1']
#      [['have', 'shown'], '1']
#      [['have', 'signs'], '1']
#      [['have', 'substantial'], '1']
#      [['he', 'believes'], '1']
#      [['he', 'continues'], '1']
#      [['he', 'quits'], '1']
#      [['he', 'stops'], '1']
#      [['hence', 'increases'], '1']
#      [['hence', 'q'], '1']
#      [['here', 'do'], '1']
#      [['here', 'has'], '1']
#      [['here', 'indicates'], '1']
#      [['here', 'mean'], '1']
#      [['here', 'much'], '1']
#      [['here', 'one'], '1']
#      [['here', 'should'], '1']
#      [['here', 'whether'], '1']
#      [['hierarchy', 'ph'], '1']
#      [['high', 'discussion'], '1']
#      [['high', 'government'], '1']
#      [['high', 'turnover'], '1']
#      [['higher', 'compensation'], '1']
#      [['higher', 'current'], '1']
#      [['higher', 'private'], '1']
#      [['higher', 'quit'], '1']
#      [['higher', 'relative'], '1']
#      [['higher', 'screening'], '1']
#      [['highest', 'grade'], '1']
#      [['hire', 'better'], '1']
#      [['hired', 'circumvent'], '1']
#      [['hiring', 'costs'], '1']
#      [['hiring', 'plus'], '1']
#      [['hiring', 'procedures'], '1']
#      [['hiring', 'training'], '1']
#      [['his', 'measured'], '1']
#      [['holding', 'size'], '1']
#      [['homogeneous', 'more'], '1']
#      [['hopkins', 'university'], '1']
#      [['how', 'firm'], '1']
#      [['how', 'firms'], '1']
#      [['however', 'efficient'], '1']
#      [['however', 'except'], '1']
#      [['however', 'indicates'], '1']
#      [['however', 'public'], '1']
#      [['hundred', 'workers'], '1']
#      [['hypothesis', 'negative'], '1']
#      [['i', 'am'], '1']
#      [['i', 'cross'], '1']
#      [['i', 'journal'], '1']
#      [['i', 'know'], '1']
#      [['ican', 'economic'], '1']
#      [['identification', 'problem'], '1']
#      [['identified', 'single'], '1']
#      [['identify', 'equation'], '1']
#      [['ii', 'cross'], '1']
#      [['ii', 'industry'], '1']
#      [['illustrated', 'figure'], '1']
#      [['illustrates', 'classic'], '1']
#      [['illustrates', 'relationship'], '1']
#      [['imagine', 'ever'], '1']
#      [['imization', 'implies'], '1']
#      [['impact', 'international'], '1']
#      [['impact', 'one'], '1']
#      [['impacts', 'proposed'], '1']
#      [['implication', 'results'], '1']
#      [['implications', 'optimization'], '1']
#      [['implied', 'pay'], '1']
#      [['implies', 'dc'], '1']
#      [['implies', 'estimates'], '1']
#      [['imply', 'variance'], '1']
#      [['importance', 'two'], '1']
#      [['important', 'difference'], '1']
#      [['important', 'systems'], '1']
#      [['include', 'nonpecuniary'], '1']
#      [['includes', 'cost'], '1']
#      [['inconsistent', 'both'], '1']
#      [['increase', 'number'], '1']
#      [['increase', 'quits'], '1']
#      [['increase', 'turnover'], '1']
#      [['increases', 'average'], '1']
#      [['increases', 'turnover'], '1']
#      [['increasing', 'implied'], '1']
#      [['independent', 'agency'], '1']
#      [['independent', 'level'], '1']
#      [['indicate', 'pay'], '1']
#      [['indicates', 'firm'], '1']
#      [['indicates', 'government'], '1']
#      [['individuals', 'ever'], '1']
#      [['induced', 'efficiencies'], '1']
#      [['induced', 'tenure'], '1']
#      [['industrial', 'federal'], '1']
#      [['industrial', 're'], '1']
#      [['industries', 'adie'], '1']
#      [['industries', 'course'], '1']
#      [['industries', 'firm'], '1']
#      [['industries', 'firms'], '1']
#      [['industries', 'problem'], '1']
#      [['industries', 'than'], '1']
#      [['industry', 'data'], '1']
#      [['industry', 'have'], '1']
#      [['industry', 'just'], '1']
#      [['industry', 'quit'], '1']
#      [['industry', 'statistics'], '1']
#      [['influence', 'quit'], '1']
#      [['ing', 'national'], '1']
#      [['institute', 'august'], '1']
#      [['institute', 'jan'], '1']
#      [['institute', 'undated'], '1']
#      [['insurance', 'forms'], '1']
#      [['insurance', 'records'], '1']
#      [['intercept', 'along'], '1']
#      [['international', 'trade'], '1']
#      [['introducing', 'complexity'], '1']
#      [['investment', 'employment'], '1']
#      [['irrespective', 'turnover'], '1']
#      [['issue', 'here'], '1']
#      [['issues', 'navy'], '1']
#      [['its', 'competition'], '1']
#      [['its', 'operation'], '1']
#      [['its', 'quit'], '1']
#      [['its', 'use'], '1']
#      [['j', 'borjas'], '1']
#      [['jacobson', 'alternative'], '1']
#      [['jacobson', 'quit'], '1']
#      [['jan', 'uary'], '1']
#      [['job', 'any'], '1']
#      [['job', 'due'], '1']
#      [['job', 'higher'], '1']
#      [['job', 'opportunities'], '1']
#      [['job', 'seeker'], '1']
#      [['jobs', 'also'], '1']
#      [['jobs', 'firms'], '1']
#      [['jobs', 'more'], '1']
#      [['jobs', 'pay'], '1']
#      [['jobs', 'private'], '1']
#      [['jobs', 'turnover'], '1']
#      [['jobs', 'year'], '1']
#      [['john', 'e'], '1']
#      [['john', 't'], '1']
#      [['johns', 'hopkins'], '1']
#      [['joseph', 'f'], '1']
#      [['journal', 'political'], '1']
#      [['jr', 'wages'], '1']
#      [['just', 'due'], '1']
#      [['just', 'temporary'], '1']
#      [['justified', 'higher'], '1']
#      [['justify', 'high'], '1']
#      [['justment', 'procedures'], '1']
#      [['k', 'adie'], '1']
#      [['kenneth', 'burdett'], '1']
#      [['know', 'two'], '1']
#      [['knowledge', 'turnover'], '1']
#      [['labor', 'forthcom'], '1']
#      [['labor', 'his'], '1']
#      [['labor', 'market'], '1']
#      [['labor', 'markets'], '1']
#      [['labor', 'na'], '1']
#      [['labor', 'review'], '1']
#      [['labor', 'statistics'], '1']
#      [['labor', 'stocks'], '1']
#      [['ladder', 'alternate'], '1']
#      [['large', 'size'], '1']
#      [['larger', 'employing'], '1']
#      [['larger', 'firms'], '1']
#      [['larger', 'size'], '1']
#      [['law', 'federal'], '1']
#      [['layoff', 'rates'], '1']
#      [['less', 'cyclically'], '1']
#      [['less', 'lucrative'], '1']
#      [['lester', 'pay'], '1']
#      [['level', 'q'], '1']
#      [['levels', 'comparable'], '1']
#      [['levels', 'how'], '1']
#      [['levels', 'minimize'], '1']
#      [['levels', 'paper'], '1']
#      [['levels', 'public'], '1']
#      [['levels', 'quit'], '1']
#      [['levels', 'while'], '1']
#      [['lewin', 'wage'], '1']
#      [['lies', 'somewhere'], '1']
#      [['like', 'b'], '1']
#      [['like', 'c'], '1']
#      [['like', 'd'], '1']
#      [['like', 'firms'], '1']
#      [['like', 'q'], '1']
#      [['like', 'small'], '1']
#      [['likely', 'large'], '1']
#      [['likely', 'quit'], '1']
#      [['likely', 'suffer'], '1']
#      [['line', 'determined'], '1']
#      [['line', 'have'], '1']
#      [['line', 'problem'], '1']
#      [['line', 'set'], '1']
#      [['line', 'supposed'], '1']
#      [['lines', 'determined'], '1']
#      [['lines', 'figure'], '1']
#      [['linked', 'adjustment'], '1']
#      [['linked', 'quit'], '1']
#      [['little', 'chance'], '1']
#      [['lnearn', 'agency'], '1']
#      [['lnearn', 'b21nsize'], '1']
#      [['lnearn', 'borjas'], '1']
#      [['lnearn', 'c1lnsize'], '1']
#      [['lnearn', 'where'], '1']
#      [['lnquit', 'bo'], '1']
#      [['local', 'pay'], '1']
#      [['logarithmic', 'form'], '1']
#      [['logarithmic', 'wage'], '1']
#      [['logical', 'use'], '1']
#      [['logistics', 'views'], '1']
#      [['long', 'observed'], '1']
#      [['long', 'politics'], '1']
#      [['longer', 'version'], '1']
#      [['looking', 'rarely'], '1']
#      [['lost', 'pro'], '1']
#      [['louis', 'jacobson'], '1']
#      [['louis', 's'], '1']
#      [['low', 'during'], '1']
#      [['low', 'pay'], '1']
#      [['low', 'seniority'], '1']
#      [['low', 'separations'], '1']
#      [['low', 'wage'], '1']
#      [['low', 'wages'], '1']
#      [['lower', 'government'], '1']
#      [['lower', 'its'], '1']
#      [['lower', 'probability'], '1']
#      [['lower', 'quit'], '1']
#      [['lowing', 'simple'], '1']
#      [['lucrative', 'compensation'], '1']
#      [['made', 'although'], '1']
#      [['made', 'without'], '1']
#      [['main', 'overly'], '1']
#      [['maintains', 'appropriate'], '1']
#      [['major', 'difference'], '1']
#      [['major', 'objective'], '1']
# ...
#      [['economics', 'population'], '1']
#      [['economics', 'society'], '1']
#      [['ed', 'cambridge'], '1']
#      [['ed', 'drugs'], '1']
#      [['ed', 'prospective'], '1']
#      [['ed', 'setting'], '1']
#      [['ed', 'workplace'], '1']
#      [['eds', 'aggregate'], '1']
#      [['eds', 'exploring'], '1']
#      [['eds', 'housing'], '1']
#      [['eds', 'how'], '1']
#      [['eds', 'integrated'], '1']
#      [['eds', 'teenage'], '1']
#      [['education', 'developing'], '1']
#      [['education', 'training'], '1']
#      [['educational', 'career'], '1']
#      [['educational', 'development'], '1']
#      [['edward', 'm'], '1']
#      [['effective', 'aei'], '1']
#      [['egan', 'john'], '1']
#      [['egbert', 'gerken'], '1']
#      [['elder', 'walker'], '1']
#      [['emerging', 'synthesis'], '1']
#      [['employ', 'ment'], '1']
#      [['energy', 'environmental'], '1']
#      [['energy', 'security'], '1']
#      [['englewood', 'cliffs'], '1']
#      [['enter', 'prise'], '1']
#      [['entwicklunglandern', 'tubingen'], '1']
#      [['environmental', 'developments'], '1']
#      [['environmental', 'regulation'], '1']
#      [['equitable', 'job'], '1']
#      [['example', 'kibbutz'], '1']
#      [['executive', 'family'], '1']
#      [['experiment', 'public'], '1']
#      [['experiment', 'r'], '1']
#      [['experiment', 'washington'], '1']
#      [['exploring', 'relationship'], '1']
#      [['f', 'b'], '1']
#      [['f', 'foss'], '1']
#      [['f', 'furstenberg'], '1']
#      [['family', 'new'], '1']
#      [['father', 'leo'], '1']
#      [['fearn', 'labor'], '1']
#      [['fels', 'klaus'], '1']
#      [['fertility', 'voorburg'], '1']
#      [['findings', 'from'], '1']
#      [['fixed', 'capital'], '1']
#      [['fleischer', 'minimum'], '1']
#      [['floor', 'industrial'], '1']
#      [['foss', 'changes'], '1']
#      [['frank', 'f'], '1']
#      [['frank', 'wilkinson'], '1']
#      [['fred', 'best'], '1']
#      [['free', 'press'], '1']
#      [['from', 'national'], '1']
#      [['from', 'three'], '1']
#      [['furstenberg', 'jr'], '1']
#      [['galenson', 'international'], '1']
#      [['gan', 'simulation'], '1']
#      [['george', 'kozmetsky'], '1']
#      [['george', 'psacharopoulos'], '1']
#      [['georgia', 'state'], '1']
#      [['gerhard', 'fels'], '1']
#      [['gerken', 'arbeitsmarkte'], '1']
#      [['gladys', 'w'], '1']
#      [['glued', 'paper'], '1']
#      [['goodman', 'j'], '1']
#      [['gorcum', 'co'], '1']
#      [['government', 'programs'], '1']
#      [['gramlich', 'benefit'], '1']
#      [['gruenberg', 'labor'], '1']
#      [['guida', 'west'], '1']
#      [['guide', 'economic'], '1']
#      [['h', 'allan'], '1']
#      [['h', 'david'], '1']
#      [['hall', 'inc'], '1']
#      [['hammerman', 'stephen'], '1']
#      [['hanenberg', 'current'], '1']
#      [['harold', 's'], '1']
#      [['hartunian', 'charles'], '1']
#      [['health', 'economic'], '1']
#      [['health', 'impairments'], '1']
#      [['health', 'maintenance'], '1']
#      [['health', 'safety'], '1']
#      [['heart', 'disease'], '1']
#      [['heffernan', 'educational'], '1']
#      [['helbers', 'price'], '1']
#      [['helm', 'ltd'], '1']
#      [['helms', 'ed'], '1']
#      [['henderson', 'kitty'], '1']
#      [['henry', 'aaron'], '1']
#      [['herbert', 'simon'], '1']
#      [['higher', 'education'], '1']
#      [['home', 'life'], '1']
#      [['housing', 'cambridge'], '1']
#      [['housing', 'public'], '1']
#      [['housing', 'vouchers'], '1']
#      [['how', 'effective'], '1']
#      [['how', 'taxes'], '1']
#      [['hud', 'santa'], '1']
#      [['hunger', 'guide'], '1']
#      [['hunner', 'yvonne'], '1']
#      [['hunt', 'inflation'], '1']
#      [['hyman', 'ideology'], '1']
#      [['i', 'henderson'], '1']
#      [['ideology', 'shop'], '1']
#      [['im', 'strukturwan'], '1']
#      [['impact', 'minimum'], '1']
#      [['impairments', 'comparative'], '1']
#      [['incidence', 'economic'], '1']
#      [['increases', 'caused'], '1']
#      [['industrial', 'society'], '1']
#      [['industry', 'level'], '1']
#      [['inflation', 'protection'], '1']
#      [['injuries', 'coronary'], '1']
#      [['institute', 'employ'], '1']
#      [['institute', 'employment'], '1']
#      [['institute', 'energy'], '1']
#      [['institute', 'jesuit'], '1']
#      [['institute', 'press'], '1']
#      [['integrated', 'cooperatives'], '1']
#      [['interna', 'tional'], '1']
#      [['international', 'cooperation'], '1']
#      [['international', 'labor'], '1']
#      [['international', 'statistical'], '1']
#      [['investing', 'people'], '1']
#      [['issues', 'strategies'], '1']
#      [['j', 'armstrong'], '1']
#      [['j', 'behney'], '1']
#      [['j', 'd'], '1']
#      [['j', 'egan'], '1']
#      [['j', 'f'], '1']
#      [['j', 'hunner'], '1']
#      [['j', 'krumm'], '1']
#      [['j', 'quint'], '1']
#      [['j', 'st'], '1']
#      [['j', 'struyk'], '1']
#      [['james', 'm'], '1']
#      [['jane', 'menken'], '1']
#      [['jane', 'sisk'], '1']
#      [['jesuit', 'sources'], '1']
#      [['jill', 'rubery'], '1']
#      [['joan', 'carson'], '1']
#      [['job', 'classification'], '1']
#      [['job', 'pay'], '1']
#      [['job', 'worth'], '1']
#      [['john', 'carr'], '1']
#      [['john', 'e'], '1']
#      [['john', 'j'], '1']
#      [['john', 'roos'], '1']
#      [['john', 'wiley'], '1']
#      [['jr', 'eds'], '1']
#      [['jr', 'richard'], '1']
#      [['kegan', 'paul'], '1']
#      [['kibbutz', 'assen'], '1']
#      [['kieler', 'studien'], '1']
#      [['kitty', 'lewis'], '1']
#      [['klaus', 'bartolke'], '1']
#      [['klaus', 'dieter'], '1']
#      [['kozmetsky', 'making'], '1']
#      [['krumm', 'impact'], '1']
#      [['l', 'clark'], '1']
#      [['labor', 'economics'], '1']
#      [['labor', 'markets'], '1']
#      [['labor', 'organization'], '1']
#      [['labor', 'peacemaker'], '1']
#      [['labour', 'market'], '1']
#      [['lawrence', 'helbers'], '1']
#      [['leo', 'c'], '1']
#      [['lessons', 'from'], '1']
#      [['level', 'produc'], '1']
#      [['lewis', 'clarke'], '1']
#      [['lexing', 'ton'], '1']
#      [['ley', 'j'], '1']
#      [['liegle', 'eds'], '1']
#      [['life', 'what'], '1']
#      [['life', 'works'], '1']
#      [['lincoln', 'jane'], '1']
#      [['listed', 'walter'], '1']
#      [['london', 'mccorquodale'], '1']
#      [['louis', 'institute'], '1']
#      [['ludwig', 'liegle'], '1']
#      [['luft', 'health'], '1']
#      [['m', 'fearn'], '1']
#      [['m', 'fleischer'], '1']
#      [['m', 'gramlich'], '1']
#      [['m', 'heffernan'], '1']
#      [['m', 'masi'], '1']
#      [['m', 'quel'], '1']
#      [['ma', 'allen'], '1']
#      [['ma', 'winthrop'], '1']
#      [['madi', 'son'], '1']
#      [['maikowski', 'economics'], '1']
#      [['maintenance', 'organizations'], '1']
#      [['major', 'health'], '1']
#      [['making', 'together'], '1']
#      [['management', 'findings'], '1']
#      [['managing', 'equitable'], '1']
#      [['manpower', 'demonstration'], '1']
#      [['manual', 'executive'], '1']
#      [['marc', 'bendick'], '1']
#      [['mark', 's'], '1']
#      [['market', 'economics'], '1']
#      [['markets', 'aei'], '1']
#      [['masi', 'organizing'], '1']
#      [['mccorquodale', 'printers'], '1']
#      [['mediating', 'structures'], '1']
#      [['medicine', 'new'], '1']
#      [['menken', 'eds'], '1']
#      [['ment', 'aei'], '1']
#      [['ment', 'research'], '1']
#      [['michael', 'poole'], '1']
#      [['michi', 'gan'], '1']
#      [['monica', 'ca'], '1']
#      [['montclair', 'nj'], '1']
#      [['motor', 'vehicle'], '1']
#      [['mott', 'john'], '1']
#      [['movement', 'social'], '1']
#      [['mulford', 'lawrence'], '1']
#      [['murray', 'f'], '1']
#      [['n', 'smart'], '1']
#      [['nabil', 'r'], '1']
#      [['national', 'committee'], '1']
#      [['national', 'experiment'], '1']
#      [['national', 'priorities'], '1']
#      [['national', 'welfare'], '1']
#      [['nelson', 's'], '1']
#      [['netherlands', 'international'], '1']
#      [['netherlands', 'van'], '1']
#      [['nicole', 'ball'], '1']
#      [['nj', 'allanheld'], '1']
#      [['nj', 'croom'], '1']
#      [['nj', 'prentice'], '1']
#      [['nursing', 'home'], '1']
#      [['objectives', 'washington'], '1']
#      [['older', 'adult'], '1']
#      [['options', 'prospects'], '1']
#      [['organization', 'american'], '1']
#      [['organizations', 'dimensions'], '1']
#      [['organizing', 'wodnen'], '1']
#      [['p', 'j'], '1']
#      [['p', 'solomon'], '1']
#      [['paper', 'american'], '1']
#      [['paper', 'arthur'], '1']
#      [['paper', 'c'], '1']
#      [['paper', 'christine'], '1']
#      [['paper', 'clifford'], '1']
#      [['paper', 'david'], '1']
#      [['paper', 'egbert'], '1']
#      [['paper', 'frank'], '1']
#      [['paper', 'fred'], '1']
#      [['paper', 'harold'], '1']
#      [['paper', 'health'], '1']
#      [['paper', 'joan'], '1']
#      [['paper', 'joseph'], '1']
#      [['paper', 'michael'], '1']
#      [['paper', 'murray'], '1']
#      [['paper', 'nelson'], '1']
#      [['paper', 'p'], '1']
#      [['paper', 'peter'], '1']
#      [['paper', 'raymond'], '1']
#      [['paper', 'richard'], '1']
#      [['paper', 'ronya'], '1']
#      [['paper', 'theodore'], '1']
#      [['pay', 'job'], '1']
#      [['pay', 'system'], '1']
#      [['peacemaker', 'life'], '1']
#      [['pechman', 'ed'], '1']
#      [['pechman', 'eds'], '1']
#      [['pennsyl', 'vania'], '1']
#      [['people', 'economics'], '1']
#      [['performance', 'new'], '1']
#      [['perspectives', 'education'], '1']
#      [['perspectives', 'new'], '1']
#      [['peter', 'b'], '1']
#      [['peter', 'rydell'], '1']
#      [['philadelphia', 'university'], '1']
#      [['policy', 'objectives'], '1']
#      [['policy', 'options'], '1']
#      [['policy', 'role'], '1']
#      [['political', 'dimensions'], '1']
#      [['poole', 'theories'], '1']
#      [['poor', 'lessons'], '1']
#      [['poor', 'women'], '1']
#      [['population', 'energy'], '1']
#      [['population', 'quality'], '1']
#      [['praeger', 'publishers'], '1']
#      [['pregnancy', 'childbearing'], '1']
#      [['prentice', 'hall'], '1']
#      [['price', 'increases'], '1']
#      [['principal', 'authors'], '1']
#      [['printers', 'ltd'], '1']
#      [['prise', 'institute'], '1']
#      [['produc', 'tivity'], '1']
#      [['programs', 'englewood'], '1']
#      [['programs', 'housing'], '1']
#      [['prospective', 'city'], '1']
#      [['prospects', 'kalamazoo'], '1']
#      [['protection', 'workers'], '1']
#      [['protest', 'poor'], '1']
#      [['psacharopoulos', 'higher'], '1']
#      [['public', 'housing'], '1']
#      [['public', 'policy'], '1']
#      [['publishers', 'inc'], '1']
#      [['publishing', 'co'], '1']
#      [['quality', 'berkeley'], '1']
#      [['quel', 'ley'], '1']
#      [['quint', 's'], '1']
#      [['r', 'adams'], '1']
#      [['rand', 'corporation'], '1']
#      [['rational', 'technology'], '1']
#      [['raymond', 'j'], '1']
#      [['received', 'henry'], '1']
#      [['regional', 'labor'], '1']
#      [['regulation', 'how'], '1']
#      [['regulation', 'retail'], '1']
#      [['rehabilitation', 'international'], '1']
#      [['relations', 'boston'], '1']
#      [['relations', 'totowa'], '1']
#      [['relationship', 'between'], '1']
#      [['research', 'corporation'], '1']
#      [['research', 'paper'], '1']
#      [['resource', 'new'], '1']
#      [['resources', 'john'], '1']
#      [['resources', 'xvi'], '1']
#      [['retail', 'trade'], '1']
#      [['retire', 'ment'], '1']
#      [['retirement', 'policy'], '1']
#      [['reversing', 'trend'], '1']
#      [['richard', 'i'], '1']
#      [['richard', 'lincoln'], '1']
#      [['rights', 'movement'], '1']
#      [['robert', 'b'], '1']
#      [['robert', 'hanenberg'], '1']
#      [['robert', 'j'], '1']
#      [['robert', 'l'], '1']
#      [['robert', 'm'], '1']
#      [['roger', 'tarling'], '1']
#      [['role', 'mediating'], '1']
#      [['ronald', 'j'], '1']
#      [['ronya', 'george'], '1']
#      [['roos', 'housing'], '1']
#      [['routledge', 'kegan'], '1']
#      [['rubery', 'roger'], '1']
#      [['rydell', 'john'], '1']
#      [['s', 'hartunian'], '1']
#      [['s', 'j'], '1']
#      [['s', 'luft'], '1']
#      [['s', 'manufacturing'], '1']
#      [['s', 'thompson'], '1']
#      [['s', 'trazoff'], '1']
#      [['safety', 'environmental'], '1']
#      [['santa', 'barbara'], '1']
#      [['santa', 'monica'], '1']
#      [['sapsford', 'labour'], '1']
#      [['schmidt', 'die'], '1']
#      [['schultz', 'investing'], '1']
#      [['sciences', 'artificial'], '1']
#      [['security', 'can'], '1']
#      [['security', 'retirement'], '1']
#      [['services', 'adults'], '1']
#      [['services', 'lexington'], '1']
#      [['setting', 'national'], '1']
#      [['sewn', 'paper'], '1']
#      [['sexuality', 'pregnancy'], '1']
#      [['sharing', 'issues'], '1']
#      [['shop', 'floor'], '1']
#      [['simon', 'sciences'], '1']
#      [['simulation', 'study'], '1']
#      [['sisk', 'willems'], '1']
#      [['smart', 'mark'], '1']
#      [['social', 'protest'], '1']
#      [['social', 'security'], '1']
#      [['society', 'example'], '1']
#      [['society', 'series'], '1']
#      [['sociology', 'industrial'], '1']
#      [['solomon', 'ed'], '1']
#      [['son', 'university'], '1']
#      [['springer', 'publishing'], '1']
#      [['st', 'louis'], '1']
#      [['staff', 'working'], '1']
#      [['state', 'university'], '1']
#      [['statistical', 'institute'], '1']
#      [['stephen', 'maikowski'], '1']
#      [['strategies', 'services'], '1']
#      [['stroke', 'lexing'], '1']
#      [['structures', 'cambridge'], '1']
#      [['strukturwan', 'del'], '1']
#      [['struyk', 'marc'], '1']
#      [['studien', 'tubingen'], '1']
#      [['studies', 'social'], '1']
#      [['study', 'kalamazoo'], '1']
#      [['supply', 'experiment'], '1']
#      [['survival', 'manual'], '1']
#      [['susan', 'hammerman'], '1']
#      [['synthesis', 'cambridge'], '1']
#      [['system', 'atlanta'], '1']
#      [['t', 'barker'], '1']
#      [['tapped', 'resource'], '1']
#      [['tarling', 'frank'], '1']
#      [['taxes', 'affect'], '1']
#      [['technology', 'medicine'], '1']
#      [['teenage', 'sexuality'], '1']
#      [['tenant', 'management'], '1']
#      [['theodor', 'bergmann'], '1']
#      [['theodore', 'w'], '1']
#      [['theories', 'trade'], '1']
#      [['thompson', 'incidence'], '1']
#      [['three', 'year'], '1']
#      [['tional', 'perspectives'], '1']
#      [['tivity', 'analyses'], '1']
#      [['together', 'survival'], '1']
#      [['ton', 'ma'], '1']
#      [['ton', 'martinus'], '1']
#      [['totowa', 'nj'], '1']
#      [['toward', 'early'], '1']
#      [['toward', 'rational'], '1']
#      [['trade', 'aei'], '1']
#      [['trade', 'unionism'], '1']
#      [['training', 'bos'], '1']
#      [['trazoff', 'tenant'], '1']
#      [['trend', 'toward'], '1']
#      [['u', 's'], '1']
#      [['un', 'tapped'], '1']
#      [['unionism', 'sociology'], '1']
#      [['united', 'nations'], '1']
#      [['university', 'california'], '1']
#      [['university', 'cambridge'], '1']
#      [['university', 'pennsyl'], '1']
#      [['university', 'wisconsin'], '1']
#      [['urban', 'institute'], '1']
#      [['van', 'gorcum'], '1']
#      [['vania', 'press'], '1']
#      [['vehicle', 'injuries'], '1']
#      [['view', 'madi'], '1']
#      [['voorburg', 'netherlands'], '1']
#      [['vouchers', 'poor'], '1']
#      [['w', 'gruenberg'], '1']
#      [['w', 'schultz'], '1']
#      [['wage', 'regional'], '1']
#      [['wage', 'regulation'], '1']
#      [['wages', 'council'], '1']
#      [['walker', 'eds'], '1']
#      [['walter', 'galenson'], '1']
#      [['washington', 'urban'], '1']
#      [['washington', 'world'], '1']
#      [['we', 'cope'], '1']
#      [['welfare', 'rights'], '1']
#      [['west', 'national'], '1']
#      [['what', 'could'], '1']
#      [['what', 'what'], '1']
#      [['wiley', 'sons'], '1']
#      [['wilkinson', 'abolition'], '1']
#      [['willems', 'toward'], '1']
#      [['winchester', 'ma'], '1']
#      [['winthrop', 'publishers'], '1']
#      [['wirtschaft', 'im'], '1']
#      [['wisconsin', 'press'], '1']
#      [['wodnen', 'issues'], '1']
#      [['women', 'new'], '1']
#      [['workers', 'compensation'], '1']
#      [['working', 'paper'], '1']
#      [['working', 'sharing'], '1']
#      [['workplace', 'perspectives'], '1']
#      [['works', 'father'], '1']
#      [['workweek', 'fixed'], '1']
#      [['world', 'bank'], '1']
#      [['world', 'hunger'], '1']
#      [['worth', 'designing'], '1']
#      [['year', 'experiment'], '1']
#      [['york', 'academy'], '1']
#      [['york', 'free'], '1']
#      [['york', 'john'], '1']
#      [['york', 'praeger'], '1']
#      [['york', 'rehabilitation'], '1']
#      [['york', 'springer'], '1']
#      [['yvonne', 'elder'], '1']

# %%
"""
Create DataFrames:
    art_id; word_ngram_1; freq_ngram_1; 
    art_id; word1_ngram_2; word2_ngram_2; freq_ngram_2; 
    art_id; word1_ngram_3; word2_ngram_3; word3_ngram_3; freq_ngram_3; 
"""

# %%
"""
Define function to create DataFrame for N-Gram-X
"""
def create_DataFrame(columns):
    # An API variable indicating which ngram should be selected from ngrams
    # The calculation is because we eliminate the art_id and freq_ngram_x and then -1, totally 3
    ngram_num = len(columns) - 3

    """
    DATA
    """
    # Data
    data = []

    # Get article ID list
    # Review that we get art_id_lst in this way only if we are sure that ngram1/2/3 share same articles (IDs)
    assert check_co_exist
    art_id_lst = art_id_lsts[0]

    # Generate data by lines
    for art_id in art_id_lst:

        # Make sure the sequence is correct that matches the dataframe column titles
        # ngram -> {ID1: freq_list1, ID2: freq_list2}
        # freq_list -> [[words0, freq0], [words1, freq1]]
        ngram = ngrams[ngram_num]
        assert art_id in ngram.keys()

        # Get freq_list
        freq_list = ngram[art_id]
        assert len(freq_list) > 0
        assert len(freq_list[0]) >= 2

        # Treat unigram and others seperately
        for pair in freq_list:
            # dataline -> [art_id, word_ngram_1, freq_ngram_1] as section title comment issues
            dataline = []

            # Add art_id to dataline
            dataline.append(art_id)

            # pair -> [[words], freq]
            assert len(pair) == 2

            # Separate word/freq
            words, freq = pair[0], pair[1]
            assert freq.isdigit()
            for word in words:
                dataline.append(word)
            dataline.append(freq)
            
            # Now the dataline should be complete
            data.append(dataline)

    """
    Columns
    """
    columns = columns

    """
    Index
    """
    index = list(range(len(data)))

    """
    DataFrame
    """
    dataframe = pd.DataFrame(data, columns=columns, index=index)

    """
    Test DataFrame
    """
    print(dataframe.head())

# %%
"""
All Columns features for N-Gram [1-3]
"""
ngram_columns = [
    ["art_id", "word_ngram_1", "freq_ngram_1"],
    ["art_id", "word1_ngram_2", "word2_ngram_2", "freq_ngram_2"],
    ["art_id", "word1_ngram_3", "word2_ngram_3", "word3_ngram_3", "freq_ngram_3"]
]

# %%
"""
DataFrame Creation for N-Gram [1-3]
"""
dataframe1 = create_DataFrame(ngram_columns[0])
dataframe2 = create_DataFrame(ngram_columns[1])
dataframe3 = create_DataFrame(ngram_columns[2])
# Out:
#    art_id word_ngram_1 freq_ngram_1
# 0  145292    licensing           58
# 1  145292      written           40
# 2  145292  examination           32
# 3  145292         test           32
# 4  145292      workers           27
#    art_id word1_ngram_2 word2_ngram_2 freq_ngram_2
# 0  145292       written          test           17
# 1  145292  occupational     licensing           12
# 2  145292             i             i           11
# 3  145292       written   examination           11
# 4  145292     licensing  examinations           10
#    art_id word1_ngram_3 word2_ngram_3 word3_ngram_3 freq_ngram_3
# 0  145292             i             i             i            9
# 1  145292       journal         human     resources            6
# 2  145292       written     licensing  examinations            4
# 3  145292       attempt        obtain       license            2
# 4  145292    attributes     important       passing            2
